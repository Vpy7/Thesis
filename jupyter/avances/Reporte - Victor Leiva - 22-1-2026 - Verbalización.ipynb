# %% [markdown]
# # Objetivo
#
# * Explicar la relación jerarquica encontrada con el proceso de granularización de las clases
# * Verbalizar los resultados de la caracterización estadística del clustering.
# * Se presentan primero las variables más discriminante para cada k = {2, 3, 4, 5, 6}, luego la verbalización de sub y sobrerrepresentaciones de cada cluster individual

# %%
import utils as ut
import pandas as pd

# %%
df_etiquetas = pd.read_excel(r"data\preguntas_disc.xlsx")

# %% [markdown]
# # Análisis de Jerarquización de Clases (LCA: k=2 a k=6)
#
# ## Evolución Jerárquica de las Clases
#
# | k de Origen | Clase de Origen | Total Obs. | Destino Principal (k+1) [% → Clase(Obs.)] | Destino Secundario (k+1) [% → Clase(Obs.)] | Otros Destinos |
# |:-----------:|:-----------------:|:----------:|:-------------------------------------------:|:--------------------------------------------:|:--------------:|
# | **2 → 3**   | 0                 | 1417       | 68.3% → **1** (968)                         | 29.3% → **0** (415)                          | 2.4% → 2 (34)  |
# |             | 1                 | 141        | 61.0% → **2** (86)                          | 39.0% → **0** (55)                           | -              |
# | **3 → 4**   | 0                 | 470        | 90.6% → **0** (426)                         | 9.4% → **1** (44)                            | -              |
# |             | 1                 | 968        | 94.8% → **2** (918)                         | 3.3% → **0** (32)                            | 1.9% → 1 (18)  |
# |             | 2                 | 120        | 70.8% → **1** (85)                          | 29.2% → **3** (35)                           | -              |
# | **4 → 5**   | 0                 | 458        | 81.0% → **2** (371)                         | 8.3% → **4** (38)                            | 10.7% (0,1,3)  |
# |             | 1                 | 147        | 50.3% → **1** (74)                          | 48.3% → **3** (71)                           | 1.4% → 0 (2)   |
# |             | 2                 | 918        | 96.5% → **4** (886)                         | 1.7% → **1** (16)                            | 1.6% → 2 (15)  |
# |             | 3                 | 35         | 97.1% → **0** (34)                          | 2.9% → **3** (1)                             | -              |
# | **5 → 6**   | 0                 | 36         | 58.3% → **3** (21)                          | 33.3% → **5** (12)                           | 8.3% (1,4)     |
# |             | 1                 | 111        | 51.4% → **5** (57)                          | 29.7% → **0** (33)                           | 18.9% (1,4)    |
# |             | 2                 | 386        | 60.4% → **4** (233)                         | 32.1% → **0** (124)                          | 7.5% (1,5)     |
# |             | 3                 | 101        | 47.5% → **0** (48)                          | 33.7% → **1** (34)                           | 18.8% (3,5)    |
# |             | 4                 | 924        | 95.9% → **2** (886)                         | 2.9% → **4** (27)                            | 1.2% → 0 (11)  |
#
# **Interpretación resumida:**
# *   **k=2, Clase 0**: Es el mayor y se divide principalmente en las futuras Clase 1 (k=3) y luego 2 (k=4), que finalmente se consolida como la clase dominante **4** en k=5 y **2** en k=6.
# *   **k=2, Clase 1**: Es pequeño y su descendencia (k=3, Clase 2) da origen a un nuevo nicho (k=4, Clase 3) que se mantiene como un grupo reducido y estable (k=5, Clase 0).
# *   **Estabilidad**: Se observa una alta estabilidad en la clase mayoritaria a lo largo de las iteraciones (ej: k=3, CLase 1 → k=4, Clase 2 → k=5, Clase 4 → k=6, Clase 2), con porcentajes de retención superiores al 90%. Las divisiones son más complejas y mixtas al pasar de k=5 a k=6.

# %% [markdown]
# # Clasificación LCA k = 2
#
# ## Variables más discriminatorias:
#
# | Variable | Cramér's V | p-value   | χ²  | Discriminación |
# |----------|------------|-----------|-----|----------------|
# | psz012   | 0.6559     | 4.52e-146 | 669 | 0.993          |
# | psz014   | 0.4243     | 1.50e-61  | 280 | 0.993          |
# | pcd029   | 0.4157     | 2.04e-60  | 269 | 1.000          |
# | psz013   | 0.3356     | 8.96e-39  | 175 | 0.993          |
# | psz009   | 0.3235     | 4.39e-36  | 163 | 0.993          |
# | pcd019   | 0.3150     | 2.96e-34  | 154 | 0.996          |
# | pni001   | 0.3131     | 7.64e-34  | 153 | 0.992          |
# | psu003   | 0.2931     | 9.55e-30  | 134 | 0.996          |
# | pcd027   | 0.2853     | 3.12e-28  | 127 | 0.996          |
# | pcd012   | 0.2755     | 2.23e-26  | 118 | 0.996          |
# | pcd020   | 0.2738     | 4.63e-26  | 117 | 0.996          |
# | pmj001   | 0.2728     | 7.29e-26  | 116 | 0.996          |
# | pal001   | 0.2645     | 2.26e-24  | 109 | 0.996          |
# | pcd004   | 0.2568     | 5.25e-23  | 103 | 0.996          |
# | psz010   | 0.2540     | 1.61e-22  | 100 | 0.993          |
# | pcd013   | 0.2483     | 1.48e-21  | 96  | 0.996          |
# | psz011   | 0.2477     | 1.85e-21  | 95  | 0.993          |
# | pcd014   | 0.2457     | 3.95e-21  | 94  | 0.996          |
# | pcd039   | 0.2443     | 6.82e-21  | 93  | 0.996          |
# | pmd015   | 0.2443     | 6.94e-21  | 93  | 0.993          |
# | pcd002   | 0.2418     | 1.75e-20  | 91  | 0.996          |
# | pcd022   | 0.2327     | 4.99e-19  | 84  | 0.996          |
# | pcd028   | 0.2296     | 1.54e-18  | 82  | 0.996          |
# | pmd022   | 0.2219     | 2.33e-17  | 77  | 0.993          |
# | psz002   | 0.2210     | 3.20e-17  | 76  | 0.993          |

# %%
variables = [
    "psz012", "psz014", "pcd029", "psz013", "psz009", 
    "pcd019", "pni001", "psu003", "pcd027", "pcd012",
    "pcd020", "pmj001", "pal001", "pcd004", "psz010",
    "pcd013", "psz011", "pcd014", "pcd039", "pmd015",
    "pcd002", "pcd022", "pcd028", "pmd022", "psz002"
]

ut.imprimir_etiquetas(variables, df_etiquetas)
# Out:
# ...
# LISTADO DE ETIQUETAS (25 variables)
# ...
#   1. [psz012] - Convinced that strange thoughts were put into your mind
#   2. [psz014] - Convinced under the control of some power/force
#   3. [pcd029] - Ever hurt someone with a weapon (like a bat/brick/knife/g un)
#   4. [psz013] - Believe you alone were sent special messages through TV/radio
#   5. [psz009] - Believe people were spying on you
#   6. [pcd019] - Ever broken into a house/building/c ar
#   7. [pni001] - Ever smoked a cigarette
#   8. [psu003] - Ever use cocaine or "crack"
#   9. [pcd027] - Ever been in a physical fight in which someone was hurt/could have been hurt
#  10. [pcd012] - Ever gotten into trouble for staying out 2 hours past curfew
#  11. [pcd020] - Broken something/mes sed up a place on purpose (like breaking windows)
#  12. [pmj001] - Ever in whole life used marijuana
#  13. [pal001] - Not including sips from other peoples, ever had even one drink
# ...

# %% [markdown]
# ## Hallazgos principales:
#
# ### Variable más discriminante:
# - **`psz012`** – *"Convinced that strange thoughts were put into your mind"*
#     - **Cramér's V = 0.6559** (el más alto)
#     - **p = 4.52e-146**
#
# ###  Dimensiones temáticas predominantes:
#
# #### **Experiencias psicóticas o similares:**
# - `psz014` – Convencido/a de estar bajo control de algún poder/fuerza
# - `psz013` – Creer que recibía mensajes especiales a través de TV/radio
# - `psz009` – Creer que lo espiaban
# - `psz002` – Escuchar cosas que otros no podían escuchar
#
# #### **Conducta antisocial y agresiva:**
# - `pcd029` – Herir a alguien con un arma
# - `pcd019` – Allanamiento de vivienda/edificio/auto
# - `pcd027` – Participar en peleas físicas con lesiones
# - `pcd028` – Intentar lastimar gravemente a alguien
# - `pcd020` – Vandalismo
# - `pcd039` – Problemas con la policía
# - `pcd002` – Hurto en tiendas
# - `pcd022` – Iniciar incendios sin permiso
#
# #### **Consumo de sustancias:**
# - `psu003` – Uso de cocaína o crack
# - `pmj001` – Uso de marihuana
# - `pal001` – Consumo de alcohol
# - `pni001` – Tabaquismo
#
# #### **Sintomatología internalizante y depresiva:**
# - `pmd015` – Autorreproches por eventos pasados
# - `pmd022` – Intentos de suicidio

# %% [markdown]
# ## Categorías Sub y Sobre-Representadas
#
# ### Clase 0 (k = 2)
#  1417 observaciones (90.9%)
#
# ---
#   No se encontraron variables distintivas (diferencia >10% con global)
#
# ### Clase 1 (k = 2)
#
# 141 observaciones (9.1%)
#
# ---
# Variables distintivas:
#
#      1. psz012:
#         SOBRE 1: 'SI' - 43% (61/141) vs 4% (61/1558) global, +39pp
#         SUB 1: 'NO' - 54% (76/141) vs 96% (1493/1558) global, -42pp
#
#      2. pni001:
#         SOBRE 1: 'SI' - 57% (81/141) vs 20% (313/1558) global, +37pp
#         SUB 1: 'NO' - 40% (56/141) vs 80% (1240/1558) global, -40pp
#
#      3. pal001:
#         SOBRE 1: 'SI' - 58% (82/141) vs 25% (382/1558) global, +34pp
#         SUB 1: 'NO' - 40% (56/141) vs 75% (1173/1558) global, -36pp
#
#      4. psz009:
#         SOBRE 1: 'SI' - 42% (59/141) vs 12% (181/1558) global, +30pp
#         SUB 1: 'NO' - 55% (78/141) vs 88% (1373/1558) global, -33pp
#
#      5. pcd027:
#         SOBRE 1: 'SI' - 45% (64/141) vs 15% (233/1558) global, +30pp
#         SUB 1: 'NO' - 52% (74/141) vs 85% (1322/1558) global, -32pp
#
#      6. pmd015:
#         SOBRE 1: 'SI' - 53% (75/141) vs 25% (383/1558) global, +29pp
#         SUB 1: 'NO' - 44% (62/141) vs 75% (1171/1558) global, -31pp
#
#      7. psz010:
#         SOBRE 1: 'SI' - 49% (69/141) vs 21% (321/1558) global, +28pp
#         SUB 1: 'NO' - 48% (68/141) vs 79% (1233/1558) global, -31pp
#
#      8. pcd014:
#         SOBRE 1: 'SI' - 40% (57/141) vs 14% (222/1558) global, +26pp
#         SUB 1: 'NO' - 57% (81/141) vs 85% (1332/1558) global, -28pp
#
#      9. pcd012:
#         SOBRE 1: 'SI' - 34% (48/141) vs 10% (151/1558) global, +24pp
#         SUB 1: 'NO' - 64% (90/141) vs 90% (1404/1558) global, -26pp
#
#     10. pcd022:
#         SOBRE 1: 'SI' - 35% (50/141) vs 13% (199/1558) global, +23pp
#         SUB 1: 'NO' - 62% (88/141) vs 87% (1356/1558) global, -25pp
#
#     11. pmj001:
#         SOBRE 1: 'SI' - 26% (37/141) vs 6% (99/1558) global, +20pp
#         SUB 1: 'NO' - 72% (101/141) vs 93% (1456/1558) global, -22pp
#
#     12. pcd020:
#         SOBRE 1: 'SI' - 26% (36/141) vs 6% (94/1558) global, +19pp
#         SUB 1: 'NO' - 72% (102/141) vs 94% (1461/1558) global, -21pp
#
#     13. psz002:
#         SOBRE 1: 'SI' - 25% (35/141) vs 8% (132/1558) global, +16pp
#         SUB 1: 'NO' - 72% (102/141) vs 91% (1422/1558) global, -19pp
#
#     14. psz014:
#         SOBRE 1: 'SI' - 18% (25/141) vs 2% (25/1558) global, +16pp
#         SUB 1: 'NO' - 79% (112/141) vs 98% (1529/1558) global, -19pp
#
#     15. pcd029:
#         SOBRE 1: 'SI' - 19% (27/141) vs 2% (27/1558) global, +17pp
#         SUB 1: 'NO' - 79% (112/141) vs 98% (1529/1558) global, -19pp
#
#     16. pmd022:
#         SOBRE 1: 'SI' - 20% (28/141) vs 6% (92/1558) global, +14pp
#         SUB 1: 'NO' - 77% (109/141) vs 94% (1462/1558) global, -17pp
#
#     17. psz011:
#         SOBRE 1: 'SI' - 18% (25/141) vs 4% (64/1558) global, +14pp
#         SUB 1: 'NO' - 79% (112/141) vs 96% (1490/1558) global, -16pp
#
#     18. pcd002:
#         SOBRE 1: 'SI' - 18% (26/141) vs 4% (65/1558) global, +14pp
#         SUB 1: 'NO' - 79% (112/141) vs 96% (1490/1558) global, -16pp
#
#     19. pcd039:
#         SOBRE 1: 'SI' - 16% (23/141) vs 3% (52/1558) global, +13pp
#         SUB 1: 'NO' - 82% (115/141) vs 96% (1503/1558) global, -15pp
#
#     20. pcd013:
#         SOBRE 1: 'SI' - 16% (22/141) vs 3% (47/1558) global, +13pp
#         SUB 1: 'NO' - 82% (116/141) vs 97% (1508/1558) global, -15pp
#
#     21. pcd028:
#         SOBRE 1: 'SI' - 16% (22/141) vs 3% (53/1558) global, +12pp
#         SUB 1: 'NO' - 82% (116/141) vs 96% (1502/1558) global, -14pp
#
#     22. psz013:
#         SUB 1: 'NO' - 87% (122/141) vs 99% (1539/1558) global, -12pp
#
#     23. pcd019:
#         SUB 1: 'NO' - 88% (124/141) vs 99% (1541/1558) global, -11pp

# %% [markdown]
# #### Perfil general:
# La **Clase 1** representa un subgrupo minoritario pero clínicamente significativo (n=141, ~9% de la muestra) que muestra un **perfil de alta severidad psicopatológica y conductual**, caracterizado por la co-ocurrencia de múltiples problemas.
#
# #### Hallazgos principales:
#
# ###### **Alta prevalencia de experiencias psicóticas:**
# - **`psz012`**: 43% reporta "pensamientos extraños insertados" (vs 4% global) → **+39pp**
# - **`psz009`**: 42% cree que "lo espían" (vs 12% global) → **+30pp**
# - **`psz010`**: 49% tiene "pensamientos de que se ríen de él/ella" (vs 21% global) → **+28pp**
# - **`psz014`**: 18% se siente "bajo control de algún poder" (vs 2% global) → **+16pp**
#
# ##### **Consumo de sustancias elevado:**
# - **`pni001`**: 57% ha fumado cigarrillos (vs 20% global) → **+37pp**
# - **`pal001`**: 58% ha consumido alcohol (vs 25% global) → **+34pp**
# - **`pmj001`**: 26% ha usado marihuana (vs 6% global) → **+20pp**
#
# ##### **Conducta externalizante grave:**
# - **`pcd027`**: 45% ha estado en peleas físicas con lesiones (vs 15% global) → **+30pp**
# - **`pcd029`**: 19% ha herido a alguien con arma (vs 2% global) → **+17pp**
# - **`pcd022`**: 35% ha iniciado fuegos sin permiso (vs 13% global) → **+23pp**
# - **`pcd020`**: 26% ha cometido vandalismo (vs 6% global) → **+19pp**
#
# ##### **Transgresiones y problemas conductuales:**
# - **`pcd014`**: 40% ha mentido para obtener dinero/beneficios (vs 14% global) → **+26pp**
# - **`pcd012`**: 34% tuvo problemas por llegar tarde (vs 10% global) → **+24pp**
# - **`pcd002`**: 18% ha hurtado en tiendas (vs 4% global) → **+14pp**
#
# ##### **Sintomatología internalizante y depresiva:**
# - **`pmd015`**: 53% se autorreprocha por eventos pasados (vs 25% global) → **+29pp**
# - **`pmd022`**: 20% ha intentado suicidio (vs 6% global) → **+14pp**
#
# #### Variables más distintivas (diferencias >30pp):
#
# | Variable | Descripción | % Clase 1 | % Global | Diferencia |
# |----------|-------------|-----------|----------|------------|
# | **psz012** | Pensamientos insertados | 43% | 4% | **+39pp** |
# | **pni001** | Tabaquismo | 57% | 20% | **+37pp** |
# | **pal001** | Consumo alcohol | 58% | 25% | **+34pp** |
# | **psz009** | Creencia de ser espiado | 42% | 12% | **+30pp** |
# | **pcd027** | Peleas físicas con lesiones | 45% | 15% | **+30pp** |
#
# #### Síntesis interpretativa:
#
# La **Clase 1** representa un **perfil de comorbilidad compleja** que combina:
#
# 1. **Síntomas psicóticos significativos** (delirios, paranoia)
# 2. **Abuso de sustancias múltiples** (tabaco, alcohol, marihuana)
# 3. **Conducta agresiva y antisocial grave**
# 4. **Alta impulsividad y transgresiones**
# 5. **Sintomatología depresiva/autocrítica**
#
# Este patrón sugiere un **subgrupo de alta necesidad clínica** que probablemente requeriría intervenciones integradas y tratamiento preventivo que aborden simultáneamente:
# - Tratamiento de síntomas psicóticos
# - Manejo de adicciones
# - Control de impulsos y agresividad
# - Prevención de suicidio
# - Rehabilitación psicosocial

# %% [markdown]
# # Clasificación LCA k = 3
#
# ## Variables más discriminatorias:
#
# | Variable | Cramér's V | p-value | χ² | Discriminación |
# |----------|------------|---------|----|----------------|
# | pcd029 | 0.4639 | 1.95e-73 | 335 | 1.000 |
# | pcd013 | 0.3713 | 1.51e-91 | 429 | 0.997 |
# | pcd039 | 0.3510 | 1.07e-81 | 383 | 0.997 |
# | pcd027 | 0.3147 | 1.89e-65 | 308 | 0.997 |
# | pcd020 | 0.3132 | 8.27e-65 | 305 | 0.997 |
# | pod011 | 0.3060 | 7.65e-62 | 291 | 0.994 |
# | pcd015 | 0.3053 | 1.55e-61 | 290 | 0.997 |
# | pni001 | 0.2991 | 5.06e-59 | 278 | 0.994 |
# | pmj001 | 0.2964 | 5.97e-58 | 273 | 0.997 |
# | pod007 | 0.2956 | 3.04e-30 | 136 | 1.000 |
# | pcd012 | 0.2933 | 9.69e-57 | 268 | 0.997 |
# | pod010 | 0.2930 | 1.33e-56 | 267 | 0.994 |
# | pal001 | 0.2811 | 4.83e-52 | 246 | 0.997 |
# | pmd012 | 0.2734 | 5.60e-26 | 116 | 1.000 |
# | pod003 | 0.2722 | 1.01e-48 | 231 | 0.994 |
# | pcd014 | 0.2711 | 2.58e-48 | 229 | 0.996 |
# | pcd021 | 0.2707 | 3.36e-48 | 228 | 0.996 |
# | pcd002 | 0.2656 | 2.37e-46 | 220 | 0.997 |
# | pod005 | 0.2642 | 7.47e-46 | 217 | 0.994 |
# | pmd021 | 0.2600 | 2.16e-44 | 210 | 0.994 |
# | psz013 | 0.2594 | 3.48e-44 | 209 | 0.994 |
# | pcd028 | 0.2536 | 3.56e-42 | 200 | 0.997 |
# | pmd022 | 0.2483 | 2.12e-40 | 192 | 0.994 |
# | pcd019 | 0.2435 | 7.76e-39 | 185 | 0.997 |
# | pmd001 | 0.2412 | 2.19e-20 | 91 | 1.000 |

# %%
variables = ["pcd029","pcd013","pcd039","pcd027","pcd020","pod011","pcd015","pni001","pmj001","pod007","pcd012","pod010","pal001","pmd012","pod003","pcd014","pcd021","pcd002","pod005","pmd021","psz013","pcd028","pmd022","pcd019","pmd001"
]
ut.imprimir_etiquetas(variables, df_etiquetas)
# Out:
# ...
# LISTADO DE ETIQUETAS (25 variables)
# ...
#   1. [pcd029] - Ever hurt someone with a weapon (like a bat/brick/knife/g un)
#   2. [pcd013] - Age when first got into trouble for staying out too late
#   3. [pcd039] - Ever been in trouble with the police
#   4. [pcd027] - Ever been in a physical fight in which someone was hurt/could have been hurt
#   5. [pcd020] - Broken something/mes sed up a place on purpose (like breaking windows)
#   6. [pod011] - Gotten even with people in past year by messing up their things/hurting them/te
#   7. [pcd015] - Ever lied to not pay back money or to get out of doing something important
#   8. [pni001] - Ever smoked a cigarette
#   9. [pmj001] - Ever in whole life used marijuana
#  10. [pod007] - Grouchy/easily annoyed in past year
#  11. [pcd012] - Ever gotten into trouble for staying out 2 hours past curfew
#  12. [pod010] - Done mean things to people in past year on purpose
#  13. [pal001] - Not including sips from other peoples, ever had even one drink
# ...

# %% [markdown]
# ## Hallazgos principales:
#
# ### Variable más discriminante:
# - **`pcd029`** – *"Ever hurt someone with a weapon (like a bat/brick/knife/gun)"*
#     - **Cramér's V = 0.4639** (el más alto)
#     - **p = 1.95e-73**
#
# ### Dimensiones temáticas predominantes:
#
# #### **Conducta antisocial y agresiva grave:**
# - `pcd029` – Herir a alguien con un arma
# - `pcd027` – Participar en peleas físicas con lesiones
# - `pcd028` – Intentar lastimar gravemente a alguien
# - `pcd019` – Allanamiento de vivienda/edificio/auto
# - `pod011` – Vengarse de personas dañando sus cosas/hiriéndolas
#
# #### **Problemas con la autoridad y transgresiones:**
# - `pcd039` – Problemas con la policía
# - `pcd013` – Edad temprana de problemas por llegar tarde
# - `pcd012` – Problemas por incumplir toque de queda
# - `pod003` – Desobediencia intencional a cuidadores
# - `pcd014` – Mentir para obtener dinero/beneficios
#
# #### **Vandalismo y daño a propiedad:**
# - `pcd020` – Destruir/destrozar un lugar intencionalmente
# - `pcd021` – Dañar las cosas de otros a propósito
# - `pcd002` – Hurto en tiendas
#
# #### **Consumo de sustancias:**
# - `pni001` – Tabaquismo
# - `pmj001` – Uso de marihuana
# - `pal001` – Consumo de alcohol
#
# #### **Comportamiento oposicionista y disruptivo:**
# - `pod007` – Malhumorado/fácilmente irritable
# - `pod010` – Hacer cosas malas a personas intencionalmente
# - `pod005` – Molestar a personas para hacerlas enojar
# - `pcd015` – Mentir para evitar pagos u obligaciones
#
# #### **Sintomatología internalizante y depresiva:**
# - `pmd001` – Períodos de aparente gran malestar/depresión
# - `pmd012` – Menos energía en el último año
# - `pmd021` – Hablar seriamente de suicidarse
# - `pmd022` – Intentos de suicidio
#
# #### **Síntomas psicóticos (menos prominentes):**
# - `psz013` – Creer que recibía mensajes especiales por TV/radio

# %% [markdown]
# ## Categorías Sub y Sobre-Representadas
#
# ### Clase 0 (k = 3)
#
#  470 observaciones (30.2%)
#
#   ---
#   Variables distintivas:
#
#      1. pod003:
#         SOBRE 1: 'SI' - 50% (233/470) vs 29% (457/1558) global, +20pp
#         SUB 1: 'NO' - 50% (237/470) vs 70% (1097/1558) global, -20pp
#
#      2. pod007:
#         SOBRE 1: 'SI' - 61% (287/470) vs 42% (656/1558) global, +19pp
#         SUB 1: 'NO' - 39% (183/470) vs 58% (900/1558) global, -19pp
#
#      3. pod005:
#         SOBRE 1: 'SI' - 43% (201/470) vs 24% (371/1558) global, +19pp
#         SUB 1: 'NO' - 57% (269/470) vs 76% (1183/1558) global, -19pp
#
#      4. pod011:
#         SOBRE 1: 'SI' - 26% (122/470) vs 9% (139/1558) global, +17pp
#         SUB 1: 'NO' - 74% (348/470) vs 91% (1415/1558) global, -17pp
#
#      5. pod010:
#         SOBRE 1: 'SI' - 22% (105/470) vs 9% (134/1558) global, +14pp
#         SUB 1: 'NO' - 78% (365/470) vs 91% (1420/1558) global, -13pp
#
#      6. pcd015:
#         SOBRE 1: 'SI' - 21% (101/470) vs 9% (142/1558) global, +12pp
#         SUB 1: 'NO' - 79% (369/470) vs 91% (1413/1558) global, -12pp
#
#      7. pmd021:
#         SOBRE 1: 'SI' - 18% (85/470) vs 7% (105/1558) global, +11pp
#         SUB 1: 'NO' - 82% (385/470) vs 93% (1449/1558) global, -11pp
#
#      8. pmd012:
#         SOBRE 1: 'SI' - 39% (185/470) vs 28% (437/1558) global, +11pp
#         SUB 1: 'NO' - 61% (285/470) vs 72% (1119/1558) global, -11pp
#
#      9. pcd021:
#         SOBRE 1: 'SI' - 19% (89/470) vs 8% (120/1558) global, +11pp
#         SUB 1: 'NO' - 81% (380/470) vs 92% (1434/1558) global, -11pp
#
#     10. pcd014:
#         SOBRE 1: 'SI' - 24% (114/470) vs 14% (222/1558) global, +10pp
#
# #### Perfil general:
# La **Clase 0** muestra un **perfil de externalización moderada con sintomatología internalizante**, caracterizado por problemas conductuales y emocionales.
#
# #### Hallazgos principales:
#
# ##### **Comportamiento oposicionista y disruptivo:**
# - **`pod003`**: 50% ha hecho cosas que sus cuidadores le prohibieron (vs 29% global) → **+20pp**
# - **`pod007`**: 61% se muestra malhumorado/fácilmente irritable (vs 42% global) → **+19pp**
# - **`pod005`**: 43% hace cosas para molestar/enojar a otros (vs 24% global) → **+19pp**
# - **`pod011`**: 26% se ha vengado de personas dañando sus cosas (vs 9% global) → **+17pp**
# - **`pod010`**: 22% hace cosas malas a personas intencionalmente (vs 9% global) → **+13pp**
#
# ##### **Transgresiones y deshonestidad:**
# - **`pcd015`**: 21% ha mentido para evitar pagos u obligaciones (vs 9% global) → **+12pp**
# - **`pcd014`**: 24% ha mentido para obtener dinero o beneficios (vs 14% global) → **+10pp**
# - **`pcd021`**: 19% ha dañado las cosas de otros a propósito (vs 8% global) → **+11pp**
#
# ##### **Sintomatología depresiva y suicida:**
# - **`pmd021`**: 18% ha hablado seriamente de suicidarse (vs 7% global) → **+11pp**
# - **`pmd012`**: 39% reporta menos energía (vs 28% global) → **+11pp**
#
# #### Variables más distintivas (diferencias >15pp):
#
# | Variable | Descripción | % Clase 0 | % Global | Diferencia |
# |----------|-------------|-----------|----------|------------|
# | **pod003** | Desobediencia intencional | 50% | 29% | **+20pp** |
# | **pod007** | Irritabilidad/mal humor | 61% | 42% | **+19pp** |
# | **pod005** | Molestar a otros intencionalmente | 43% | 24% | **+19pp** |
# | **pod011** | Conducta vengativa | 26% | 9% | **+17pp** |
#
#
# Que correpsonden completamente a síntomas relacionados al diagnóstico de trastorno de oposición desafiante.
#
# #### Síntesis interpretativa:
#
# La **Clase 0** representa un **perfil de externalización moderada con comorbilidad internalizante** que se caracteriza por:
#
# 1. **Problemas de comportamiento externalizante** predominantemente oposicionistas y disruptivos
# 2. **Agresividad relacional** (venganza, molestar a otros)
# 3. **Deshonestidad y transgresiones menores**
# 4. **Sintomatología depresiva** (ideación suicida, baja energía)
#
# **Nota**: Se puede considerar que esta clase presenta problemas de **intensidad moderada**, con predominio de:
# - Conductas problemáticas más que antisociales graves
# - Agresividad indirecta/relacional más que física extrema
# - Sintomatología depresiva presente pero con menor prevalencia que en clases más graves
#
# Este patrón sugiere un **subgrupo que podría beneficiarse de intervenciones tempranas** centradas en:
# - Manejo de la irritabilidad y regulación emocional
# - Habilidades de resolución de conflictos sin agresión
# - Prevención de conductas de riesgo y deshonestidad
# - Apoyo para síntomas depresivos e ideación suicida
# - Intervenciones familiares para mejorar la dinámica y supervisión
#
# ### Clase 1 (k = 3)
#
# 968 observaciones (62.1%)
#
#   ---
#   Variables distintivas:
#
#      1. pod003:
#         SOBRE 1: 'NO' - 83% (808/968) vs 70% (1097/1558) global, +13pp
#         SUB 1: 'SI' - 17% (160/968) vs 29% (457/1558) global, -13pp
#
#      2. pod005:
#         SOBRE 1: 'NO' - 88% (850/968) vs 76% (1183/1558) global, +12pp
#         SUB 1: 'SI' - 12% (118/968) vs 24% (371/1558) global, -12pp
#
#      3. pod007:
#         SOBRE 1: 'NO' - 69% (670/968) vs 58% (900/1558) global, +11pp
#         SUB 1: 'SI' - 31% (298/968) vs 42% (656/1558) global, -11pp
#
#      4. pal001:
#         SOBRE 1: 'NO' - 85% (827/968) vs 75% (1173/1558) global, +10pp
#
# #### Perfil general:
# La **Clase 1** representa el subgrupo más numeroso identificado (n=968, ~62% de la muestra) y muestra un **perfil de baja psicopatología y ajuste adaptativo**, caracterizado por la ausencia o baja frecuencia de problemas conductuales, emocionales y de consumo.
#
# #### Hallazgos principales:
#
# ##### **Bajo comportamiento oposicionista y disruptivo:**
# - **`pod003`**: Solo 17% ha hecho cosas que sus cuidadores le prohibieron (vs 29% global) → **-13pp**
# - **`pod005`**: Solo 12% hace cosas para molestar/enojar a otros (vs 24% global) → **-12pp**
# - **`pod007`**: Solo 31% se muestra malhumorado/fácilmente irritable (vs 42% global) → **-11pp**
#
# ##### **Bajo consumo de alcohol:**
# - **`pal001`**: 85% NO ha consumido alcohol (vs 75% global) → **+10pp** (solo 15% ha probado alcohol vs 25% global)
#
# #### Síntesis interpretativa:
#
# La **Clase 1** representa un **perfil de ajuste saludable o normativo** que se caracteriza por:
#
# 1. **Baja prevalencia de comportamientos externalizantes** (oposicionismo, agresión, vandalismo)
# 2. **Menor irritabilidad y problemas emocionales**
# 3. **Bajo consumo de sustancias** (alcohol)
# 4. **Ausencia de problemas graves** como conductas antisociales severas o sintomatología psicótica
#
# Este patrón sugiere un **subgrupo de bajo riesgo o población normativa** que probablemente:
# - No requiere intervenciones clínicas específicas
# - Podría beneficiarse de programas de prevención universal para mantener su buen estado
# - Representa el grupo de comparación contra el cual se evalúan las otras clases con problemas
#
# Esta clase sirve como **grupo de control natural** dentro de la muestra, mostrando el nivel basal de funcionamiento adaptativo en esta población.
#
# ### Clase 2 (k = 3)
#
# 120 observaciones (7.7%)
#
#   ---
#
#   Variables distintivas:
#
#      1. pni001:
#         SOBRE 1: 'SI' - 70% (84/120) vs 20% (313/1558) global, +50pp
#         SUB 1: 'NO' - 27% (32/120) vs 80% (1240/1558) global, -53pp
#
#      2. pal001:
#         SOBRE 1: 'SI' - 74% (89/120) vs 25% (382/1558) global, +50pp
#         SUB 1: 'NO' - 23% (28/120) vs 75% (1173/1558) global, -52pp
#
#      3. pcd027:
#         SOBRE 1: 'SI' - 62% (75/120) vs 15% (233/1558) global, +48pp
#         SUB 1: 'NO' - 35% (42/120) vs 85% (1322/1558) global, -50pp
#
#      4. pcd012:
#         SOBRE 1: 'SI' - 48% (57/120) vs 10% (151/1558) global, +38pp
#         SUB 1: 'NO' - 50% (60/120) vs 90% (1404/1558) global, -40pp
#
#      5. pcd014:
#         SOBRE 1: 'SI' - 48% (58/120) vs 14% (222/1558) global, +34pp
#         SUB 1: 'NO' - 49% (59/120) vs 85% (1332/1558) global, -36pp
#
#      6. pmj001:
#         SOBRE 1: 'SI' - 40% (48/120) vs 6% (99/1558) global, +34pp
#         SUB 1: 'NO' - 57% (69/120) vs 93% (1456/1558) global, -36pp
#
#      7. pcd020:
#         SOBRE 1: 'SI' - 38% (45/120) vs 6% (94/1558) global, +31pp
#         SUB 1: 'NO' - 60% (72/120) vs 94% (1461/1558) global, -34pp
#
#      8. pcd013:
#         SOBRE 1: 'SI' - 33% (40/120) vs 3% (47/1558) global, +30pp
#         SUB 1: 'NO' - 64% (77/120) vs 97% (1508/1558) global, -33pp
#
#      9. pcd039:
#         SOBRE 1: 'SI' - 33% (40/120) vs 3% (52/1558) global, +30pp
#         SUB 1: 'NO' - 64% (77/120) vs 96% (1503/1558) global, -32pp
#
#     10. pmd001:
#         SOBRE 1: 'SI' - 72% (86/120) vs 43% (667/1558) global, +29pp
#         SUB 1: 'NO' - 27% (32/120) vs 57% (889/1558) global, -30pp
#
#     11. pmd012:
#         SOBRE 1: 'SI' - 56% (67/120) vs 28% (437/1558) global, +28pp
#         SUB 1: 'NO' - 42% (51/120) vs 72% (1119/1558) global, -29pp
#
#     12. pcd015:
#         SOBRE 1: 'SI' - 34% (41/120) vs 9% (142/1558) global, +25pp
#         SUB 1: 'NO' - 63% (76/120) vs 91% (1413/1558) global, -27pp
#
#     13. pod003:
#         SOBRE 1: 'SI' - 53% (64/120) vs 29% (457/1558) global, +24pp
#         SUB 1: 'NO' - 43% (52/120) vs 70% (1097/1558) global, -27pp
#
#     14. pcd002:
#         SOBRE 1: 'SI' - 27% (32/120) vs 4% (65/1558) global, +22pp
#         SUB 1: 'NO' - 71% (85/120) vs 96% (1490/1558) global, -25pp
#
#     15. pod005:
#         SOBRE 1: 'SI' - 43% (52/120) vs 24% (371/1558) global, +20pp
#         SUB 1: 'NO' - 53% (64/120) vs 76% (1183/1558) global, -23pp
#
#     16. pcd029:
#         SOBRE 1: 'SI' - 22% (27/120) vs 2% (27/1558) global, +21pp
#         SUB 1: 'NO' - 76% (91/120) vs 98% (1529/1558) global, -22pp
#
#     17. pcd028:
#         SOBRE 1: 'SI' - 23% (28/120) vs 3% (53/1558) global, +20pp
#         SUB 1: 'NO' - 74% (89/120) vs 96% (1502/1558) global, -22pp
#
#     18. pcd021:
#         SOBRE 1: 'SI' - 26% (31/120) vs 8% (120/1558) global, +18pp
#         SUB 1: 'NO' - 72% (86/120) vs 92% (1434/1558) global, -20pp
#
#     19. pod010:
#         SOBRE 1: 'SI' - 24% (29/120) vs 9% (134/1558) global, +16pp
#         SUB 1: 'NO' - 72% (87/120) vs 91% (1420/1558) global, -19pp
#
#     20. pod007:
#         SOBRE 1: 'SI' - 59% (71/120) vs 42% (656/1558) global, +17pp
#         SUB 1: 'NO' - 39% (47/120) vs 58% (900/1558) global, -19pp
#
#     21. pmd022:
#         SOBRE 1: 'SI' - 20% (24/120) vs 6% (92/1558) global, +14pp
#         SUB 1: 'NO' - 77% (92/120) vs 94% (1462/1558) global, -17pp
#
#     22. psz013:
#         SOBRE 1: 'SI' - 12% (15/120) vs 1% (15/1558) global, +12pp
#         SUB 1: 'NO' - 84% (101/120) vs 99% (1539/1558) global, -15pp
#
#     23. pcd019:
#         SOBRE 1: 'SI' - 12% (14/120) vs 1% (14/1558) global, +11pp
#         SUB 1: 'NO' - 86% (103/120) vs 99% (1541/1558) global, -13pp
#
#     24. pmd021:
#         SUB 1: 'NO' - 80% (96/120) vs 93% (1449/1558) global, -13pp
#
# #### Perfil general:
# La **Clase 2** representa el subgrupo más pequeño pero clínicamente más grave (n=120, ~8% de la muestra) y muestra un **perfil de alta severidad externalizante con comorbilidad internalizante**, caracterizado por múltiples problemas conductuales graves, consumo de sustancias y sintomatología depresiva.
#
# #### Hallazgos principales:
#
# ##### **Consumo de sustancias extremadamente elevado:**
# - **`pni001`**: 70% ha fumado cigarrillos (vs 20% global) → **+50pp**
# - **`pal001`**: 74% ha consumido alcohol (vs 25% global) → **+50pp**
# - **`pmj001`**: 40% ha usado marihuana (vs 6% global) → **+34pp**
#
# ##### **Conducta agresiva y antisocial grave:**
# - **`pcd027`**: 62% ha estado en peleas físicas con lesiones (vs 15% global) → **+48pp**
# - **`pcd029`**: 22% ha herido a alguien con arma (vs 2% global) → **+21pp**
# - **`pcd028`**: 23% ha intentado lastimar gravemente a alguien (vs 3% global) → **+20pp**
# - **`pcd019`**: 12% ha cometido allanamiento (vs 1% global) → **+11pp**
#
# ##### **Transgresiones múltiples y problemas con la autoridad:**
# - **`pcd012`**: 48% tuvo problemas por incumplir toque de queda (vs 10% global) → **+38pp**
# - **`pcd014`**: 48% ha mentido para obtener dinero/beneficios (vs 14% global) → **+34pp**
# - **`pcd020`**: 38% ha cometido vandalismo (vs 6% global) → **+31pp**
# - **`pcd013`**: 33% problemas tempranos por llegar tarde (vs 3% global) → **+30pp**
# - **`pcd039`**: 33% ha tenido problemas con la policía (vs 3% global) → **+30pp**
#
# ##### **Sintomatología depresiva severa:**
# - **`pmd001`**: 72% ha tenido períodos de gran malestar/depresión (vs 43% global) → **+29pp**
# - **`pmd012`**: 56% reporta menos energía (vs 28% global) → **+28pp**
# - **`pmd022`**: 20% ha intentado suicidio (vs 6% global) → **+14pp**
#
# ##### **Comportamiento oposicionista y disruptivo:**
# - **`pod003`**: 53% desobediencia intencional (vs 29% global) → **+24pp**
# - **`pod005`**: 43% molesta a otros intencionalmente (vs 24% global) → **+20pp**
# - **`pod007`**: 59% irritabilidad/mal humor (vs 42% global) → **+17pp**
#
# #### Variables más distintivas (diferencias >30pp):
#
# | Variable | Descripción | % Clase 2 | % Global | Diferencia |
# |----------|-------------|-----------|----------|------------|
# | **pni001** | Tabaquismo | 70% | 20% | **+50pp** |
# | **pal001** | Consumo alcohol | 74% | 25% | **+50pp** |
# | **pcd027** | Peleas físicas con lesiones | 62% | 15% | **+48pp** |
# | **pcd012** | Problemas por toque de queda | 48% | 10% | **+38pp** |
# | **pcd014** | Mentir para obtener beneficios | 48% | 14% | **+34pp** |
#
# #### Síntesis interpretativa:
#
# La **Clase 2** representa un **perfil de externalización grave con alta comorbilidad** que se caracteriza por:
#
# 1. **Consumo de sustancias muy elevado** (tabaco, alcohol, marihuana)
# 2. **Violencia física y agresión grave** (armas, peleas con lesiones)
# 3. **Múltiples transgresiones y problemas con la autoridad**
# 4. **Sintomatología depresiva severa** con riesgo suicida
# 5. **Comportamiento oposicionista y disruptivo** significativo
#
# **Comparación con otras clases en k=3:**
# - Más grave que la Clase 0 (externalización moderada)
# - Claramente más patológica que la Clase 1 (baja psicopatología)
# - Representa el **perfil de mayor riesgo** en esta clasificación
#
# Este patrón sugiere un **subgrupo de muy alta necesidad clínica** que probablemente requiere:
# - Intervenciones intensivas para el consumo de sustancias
# - Manejo de la agresión y control de impulsos
# - Tratamiento para la depresión y prevención del suicidio
# - Intervenciones legales y de justicia juvenil
# - Apoyo familiar y psicosocial integral
#
# **Nota**: Es importante considerar que, aunque la representatividad de este subgrupo es cuestionable, por tener un tamaño de menos del 10% de la muestra general, esto es natural dada la gravedad de los síntomas detectados.
#
# ## Síntesis de Diferenciación de Clases (k=3)
#
# | **Criterio** | **Clase 0 (Externalización Moderada)** | **Clase 1 (Bajo Riesgo)** | **Clase 2 (Alta Severidad Externalizante)** |
# | :--- | :--- | :--- | :--- |
# | **Tamaño de la Clase** | 470 observaciones (30.2%) | 968 observaciones (62.1%) | 120 observaciones (7.7%) |
# | **Patrón Principal** | **Comorbilidad externalizante-internalizante moderada.** Problemas de conducta disruptiva y oposicionista combinados con sintomatología depresiva. | **Ajuste adaptativo y baja psicopatología.** Ausencia o baja frecuencia de problemas conductuales, emocionales y de consumo. | **Comorbilidad generalizada y severa.** Patrón de alta externalización (agresión, transgresiones, consumo) con sintomatología internalizante severa. |
# | **Núcleo del Perfil** | **Trastorno de oposición desafiante y deshonestidad.** Predominan las conductas oposicionistas, irritabilidad, agresividad relacional (venganza) y transgresiones menores, acompañadas de síntomas depresivos. | **Ausencia de psicopatología significativa.** Se caracteriza por la **sub-representación** de síntomas problemáticos, actuando como grupo de comparación normativo dentro de la muestra. | **Tríada de adicción, agresión y depresión.** Combinación extrema de consumo de sustancias (tabaco, alcohol, marihuana), conducta antisocial grave (violencia, vandalismo, problemas legales) y depresión con riesgo suicida. |
# | **Síntomas más Distintivos (Diferencia >15pp vs. Global)** | 1. **pod003:** Desobediencia (+20pp)<br>2. **pod007:** Irritabilidad (+19pp)<br>3. **pod005:** Molestar a otros (+19pp)<br>4. **pod011:** Conducta vengativa (+17pp) | 1. **pod003:** Baja desobediencia (-13pp)<br>2. **pod005:** Bajo molestar a otros (-12pp)<br>3. **pod007:** Baja irritabilidad (-11pp)<br>4. **pal001:** Bajo consumo de alcohol (+10pp en 'NO') | 1. **pni001:** Tabaquismo (+50pp)<br>2. **pal001:** Consumo de alcohol (+50pp)<br>3. **pcd027:** Peleas con lesiones (+48pp)<br>4. **pcd012:** Problemas por toque de queda (+38pp)<br>5. **pmj001:** Uso de marihuana (+34pp) |
# | **Riesgo Asociado** | **Moderado.** Riesgo de escalada a trastornos de conducta, problemas legales menores y exacerbación de sintomatología depresiva. | **Muy Bajo.** Representa el perfil de ajuste saludable. El riesgo principal es la posible transición hacia clases problemáticas sin intervenciones preventivas. | **Muy Alto.** Alto riesgo de cronicidad, deterioro psicosocial, victimización o perpetración de violencia, conducta suicida y complicaciones legales severas. |
# | **Abordaje Sugerido** | **Intervención temprana y focalizada.** Programas para manejo de la ira, regulación emocional, habilidades parentales y prevención de la deshonestidad. Tratamiento breve para síntomas depresivos. | **Prevención universal y promoción de la salud.** Educación psico-social para mantener factores protectores y detectar precozmente la aparición de problemas. | **Tratamiento especializado, intensivo y multidisciplinario.** Requiere abordaje integral simultáneo para: adicciones (desintoxicación y rehabilitación), control de impulsos y agresión, tratamiento de la depresión con riesgo suicida, e intervenciones legales/judiciales. |
#
# ---

# %% [markdown]
# # Clasificación LCA k = 4
#
# ## Variables más discriminatorias:
#
# | Variable | Cramér's V | p-value | χ² | Discriminación |
# |----------|------------|---------|----|----------------|
# | pcd019 | 0.4739 | 1.00e-147 | 699 | 0.992 |
# | pmj001 | 0.4371 | 3.32e-125 | 595 | 0.992 |
# | pcd029 | 0.4131 | 2.84e-57 | 266 | 1.000 |
# | pcd039 | 0.3837 | 8.15e-96 | 458 | 0.992 |
# | pni001 | 0.3685 | 3.95e-88 | 423 | 0.990 |
# | pcd013 | 0.3663 | 4.62e-87 | 418 | 0.992 |
# | pcd027 | 0.3531 | 1.03e-80 | 388 | 0.992 |
# | pal001 | 0.3464 | 1.52e-77 | 373 | 0.992 |
# | pcd012 | 0.3337 | 8.37e-72 | 347 | 0.992 |
# | pcd020 | 0.3271 | 6.97e-69 | 333 | 0.992 |
# | pcd015 | 0.3031 | 8.87e-59 | 286 | 0.992 |
# | pod011 | 0.2990 | 3.69e-57 | 278 | 0.991 |
# | psu011 | 0.2989 | 4.25e-57 | 278 | 0.992 |
# | pmd012 | 0.2982 | 8.71e-30 | 138 | 1.000 |
# | pcd014 | 0.2837 | 3.13e-51 | 251 | 0.992 |
# | pod007 | 0.2807 | 2.16e-26 | 123 | 1.000 |
# | pod010 | 0.2769 | 1.16e-48 | 239 | 0.991 |
# | pcd028 | 0.2758 | 2.82e-48 | 237 | 0.992 |
# | pcd003 | 0.2732 | 2.61e-47 | 232 | 0.992 |
# | pcd021 | 0.2731 | 2.63e-47 | 232 | 0.992 |
# | pcd009 | 0.2727 | 3.66e-47 | 232 | 0.992 |
# | pcd008 | 0.2727 | 3.66e-47 | 232 | 0.992 |
# | pcd007 | 0.2727 | 3.66e-47 | 232 | 0.992 |
# | pmd009 | 0.2709 | 1.40e-24 | 114 | 1.000 |
# | psz014 | 0.2703 | 2.68e-46 | 227 | 0.991 |

# %%
variables = ["pcd019","pmj001","pcd029","pcd039","pni001","pcd013","pcd027","pal001","pcd012","pcd020", "pcd015","pod011","psu011","pmd012","pcd014","pod007","pod010","pcd028","pcd003","pcd021","pcd009","pcd008","pcd007","pmd009","psz014"
]
ut.imprimir_etiquetas(variables, df_etiquetas)
# Out:
# ...
# LISTADO DE ETIQUETAS (25 variables)
# ...
#   1. [pcd019] - Ever broken into a house/building/c ar
#   2. [pmj001] - Ever in whole life used marijuana
#   3. [pcd029] - Ever hurt someone with a weapon (like a bat/brick/knife/g un)
#   4. [pcd039] - Ever been in trouble with the police
#   5. [pni001] - Ever smoked a cigarette
#   6. [pcd013] - Age when first got into trouble for staying out too late
#   7. [pcd027] - Ever been in a physical fight in which someone was hurt/could have been hurt
#   8. [pal001] - Not including sips from other peoples, ever had even one drink
#   9. [pcd012] - Ever gotten into trouble for staying out 2 hours past curfew
#  10. [pcd020] - Broken something/mes sed up a place on purpose (like breaking windows)
#  11. [pcd015] - Ever lied to not pay back money or to get out of doing something important
#  12. [pod011] - Gotten even with people in past year by messing up their things/hurting them/te
# ...

# %% [markdown]
# ## Hallazgos principales:
#
# ### Variables más discriminantes:
# - **`pcd019`** – *"Ever broken into a house/building/car"*
#     - **Cramér's V = 0.4739** (el más alto)
#     - **p = 1.00e-147**
# - **`pmj001`** – *"Ever in whole life used marijuana"*
#     - **Cramér's V = 0.4371**
#     - **p = 3.32e-125**
# - **`pcd029`** – *"Ever hurt someone with a weapon"*
#     - **Cramér's V = 0.4131**
#     - **p = 2.84e-57**
#
# ### Dimensiones temáticas predominantes:
#
# #### **Conducta antisocial y delictiva:**
# - `pcd019` – Allanamiento de vivienda/edificio/auto
# - `pcd029` – Herir a alguien con un arma
# - `pcd039` – Problemas con la policía
# - `pcd027` – Participar en peleas físicas con lesiones
# - `pcd012` – Problemas por llegar tarde al toque de queda
# - `pcd020` – Vandalismo (romper cosas a propósito)
# - `pcd003` – Robar cuando nadie está mirando
# - `pcd009` – Amenazar para robar
# - `pcd008` – Atacar con intención de robar
# - `pcd007` – Arrebatar bolso o joyas
#
# #### **Consumo de sustancias:**
# - `pmj001` – Uso de marihuana
# - `pni001` – Tabaquismo
# - `pal001` – Consumo de alcohol
# - `psu011` – Uso de otras drogas no preguntadas
#
# #### **Agresión y violencia interpersonal:**
# - `pcd028` – Intentar lastimar gravemente a alguien
# - `pod011` – Vengarse de personas dañando sus cosas/hiriéndolas
# - `pod010` – Hacer cosas malas a personas a propósito
# - `pcd021` – Romper/dañar cosas ajenas a propósito
#
# #### **Engaño y fraudes:**
# - `pcd015` – Mentir para no pagar dinero o evitar responsabilidades
# - `pcd014` – Mentir para obtener dinero u otras cosas
#
# #### **Sintomatología diversa:**
# - `pmd012` – Menos energía en el último año (síntoma depresivo)
# - `pod007` – Irritable/fácilmente molesto en el último año
# - `pmd009` – Dormir más durante el día de lo habitual
# - `psz014` – Convencido/a de estar bajo control de algún poder/fuerza (síntoma psicótico)

# %% [markdown]
# ## Categorías Sub y Sobre-Representadas
#
# ### Clase 0 (k = 4)
#  458 observaciones (29.4%)
#
#   ---
#   Variables distintivas:
#
#      1. pod007:
#         SOBRE 1: 'SI' - 59% (271/458) vs 42% (656/1558) global, +17pp
#         SUB 1: 'NO' - 41% (187/458) vs 58% (900/1558) global, -17pp
#
#      2. pod011:
#         SOBRE 1: 'SI' - 26% (118/458) vs 9% (139/1558) global, +17pp
#         SUB 1: 'NO' - 74% (340/458) vs 91% (1415/1558) global, -17pp
#
#      3. pod010:
#         SOBRE 1: 'SI' - 21% (97/458) vs 9% (134/1558) global, +13pp
#         SUB 1: 'NO' - 79% (361/458) vs 91% (1420/1558) global, -12pp
#
#      4. pcd015:
#         SOBRE 1: 'SI' - 20% (90/458) vs 9% (142/1558) global, +11pp
#         SUB 1: 'NO' - 80% (368/458) vs 91% (1413/1558) global, -10pp
#
#      5. pcd021:
#         SOBRE 1: 'SI' - 18% (82/458) vs 8% (120/1558) global, +10pp
#         SUB 1: 'NO' - 82% (375/458) vs 92% (1434/1558) global, -10pp
#
# #### Perfil general:
# La **Clase 0** muestra un **perfil de moderada externalización conductual con predominio de irritabilidad y conductas agresivas leves**, caracterizado por problemas de regulación emocional y comportamientos antisociales de baja a moderada severidad.
#
# #### Hallazgos principales:
#
# ##### **Alta prevalencia de irritabilidad y agresión interpersonal:**
# - **`pod007`**: 59% reporta estar "irritable/fácilmente molesto" (vs 42% global) → **+17pp**
# - **`pod011`**: 26% se ha "vengado de personas dañando sus cosas/hiriéndolas" (vs 9% global) → **+17pp**
# - **`pod010`**: 21% ha "hecho cosas malas a personas a propósito" (vs 9% global) → **+13pp**
#
# ##### **Comportamientos engañosos y daño a propiedad:**
# - **`pcd015`**: 20% ha "mentido para no pagar dinero o evitar responsabilidades" (vs 9% global) → **+11pp**
# - **`pcd021`**: 18% ha "roto/dañado cosas ajenas a propósito" (vs 8% global) → **+10pp**
#
# #### Variables más distintivas (diferencias >10pp):
#
# | Variable | Descripción | % Clase 0 | % Global | Diferencia |
# |----------|-------------|-----------|----------|------------|
# | **pod007** | Irritable/fácilmente molesto | 59% | 42% | **+17pp** |
# | **pod011** | Vengarse dañando cosas/hiriendo | 26% | 9% | **+17pp** |
# | **pod010** | Hacer cosas malas a propósito | 21% | 9% | **+13pp** |
# | **pcd015** | Mentir para evitar pagos/responsabilidades | 20% | 9% | **+11pp** |
# | **pcd021** | Dañar cosas ajenas a propósito | 18% | 8% | **+10pp** |
#
# #### Síntesis interpretativa:
#
# La **Clase 0** representa un **perfil de externalización moderada** caracterizado por:
#
# 1. **Alta irritabilidad y labilidad emocional**
# 2. **Conductas agresivas y vengativas** de baja intensidad
# 3. **Tendencia al engaño** en contextos instrumentales
# 4. **Daño a propiedad ajena** como expresión de agresión
# 5. **Ausencia de conductas delictivas graves** (allanamiento, uso de armas)
# 6. **Ausencia de consumo problemático de sustancias** (no aparecen en variables distintivas)
# 7. **Ausencia de sintomatología psicótica significativa**
#
# Este patrón sugiere un **subgrupo con problemas de regulación emocional y conductual** que probablemente se beneficiaría de intervenciones tempranas centradas en:
# - Manejo de la irritabilidad y regulación emocional
# - Habilidades de resolución de conflictos sin agresión
# - Desarrollo de empatía y responsabilidad social
# - Estrategias para manejar la frustración
# - Prevención de escalada hacia conductas más graves
#
# ### Clase 1 (k = 4)
#
# 147 observaciones (9.4%)
#
#   ---
#   Variables distintivas:
#
#      1. pni001:
#         SOBRE 1: 'SI' - 76% (112/147) vs 20% (313/1558) global, +56pp
#         SUB 1: 'NO' - 23% (34/147) vs 80% (1240/1558) global, -56pp
#
#      2. pal001:
#         SOBRE 1: 'SI' - 77% (113/147) vs 25% (382/1558) global, +52pp
#         SUB 1: 'NO' - 23% (34/147) vs 75% (1173/1558) global, -52pp
#
#      3. pmj001:
#         SOBRE 1: 'SI' - 48% (71/147) vs 6% (99/1558) global, +42pp
#         SUB 1: 'NO' - 52% (76/147) vs 93% (1456/1558) global, -42pp
#
#      4. pcd027:
#         SOBRE 1: 'SI' - 53% (78/147) vs 15% (233/1558) global, +38pp
#         SUB 1: 'NO' - 47% (69/147) vs 85% (1322/1558) global, -38pp
#
#      5. pcd012:
#         SOBRE 1: 'SI' - 42% (62/147) vs 10% (151/1558) global, +32pp
#         SUB 1: 'NO' - 58% (85/147) vs 90% (1404/1558) global, -32pp
#
#      6. pmd009:
#         SOBRE 1: 'SI' - 56% (83/147) vs 27% (415/1558) global, +30pp
#         SUB 1: 'NO' - 44% (64/147) vs 73% (1141/1558) global, -30pp
#
#      7. pmd012:
#         SOBRE 1: 'SI' - 57% (84/147) vs 28% (437/1558) global, +29pp
#         SUB 1: 'NO' - 43% (63/147) vs 72% (1119/1558) global, -29pp
#
#      8. pcd039:
#         SOBRE 1: 'SI' - 29% (43/147) vs 3% (52/1558) global, +26pp
#         SUB 1: 'NO' - 71% (104/147) vs 96% (1503/1558) global, -26pp
#
#      9. pcd014:
#         SOBRE 1: 'SI' - 40% (59/147) vs 14% (222/1558) global, +26pp
#         SUB 1: 'NO' - 60% (88/147) vs 85% (1332/1558) global, -26pp
#
#     10. pcd013:
#         SOBRE 1: 'SI' - 27% (39/147) vs 3% (47/1558) global, +24pp
#         SUB 1: 'NO' - 73% (108/147) vs 97% (1508/1558) global, -23pp
#
#     11. pcd020:
#         SOBRE 1: 'SI' - 26% (38/147) vs 6% (94/1558) global, +20pp
#         SUB 1: 'NO' - 74% (109/147) vs 94% (1461/1558) global, -20pp
#
#     12. pcd015:
#         SOBRE 1: 'SI' - 28% (41/147) vs 9% (142/1558) global, +19pp
#         SUB 1: 'NO' - 72% (106/147) vs 91% (1413/1558) global, -19pp
#
#     13. pod007:
#         SOBRE 1: 'SI' - 58% (85/147) vs 42% (656/1558) global, +16pp
#         SUB 1: 'NO' - 42% (62/147) vs 58% (900/1558) global, -16pp
#
#     14. pcd003:
#         SOBRE 1: 'SI' - 21% (31/147) vs 7% (110/1558) global, +14pp
#         SUB 1: 'NO' - 79% (116/147) vs 93% (1445/1558) global, -14pp
#
#     15. psz014:
#         SOBRE 1: 'SI' - 15% (22/147) vs 2% (25/1558) global, +13pp
#         SUB 1: 'NO' - 84% (124/147) vs 98% (1529/1558) global, -14pp
#
#     16. pcd028:
#         SOBRE 1: 'SI' - 16% (23/147) vs 3% (53/1558) global, +12pp
#         SUB 1: 'NO' - 84% (124/147) vs 96% (1502/1558) global, -12pp
#
#     17. pod010:
#         SOBRE 1: 'SI' - 20% (30/147) vs 9% (134/1558) global, +12pp
#         SUB 1: 'NO' - 79% (116/147) vs 91% (1420/1558) global, -12pp
#
# #### Perfil general:
# La **Clase 1** muestra un **perfil de alta severidad caracterizado por consumo problemático de sustancias, conducta antisocial grave y sintomatología internalizante**.
#
# #### Hallazgos principales:
#
# ##### **Consumo de sustancias muy elevado:**
# - **`pni001`**: 76% ha fumado cigarrillos (vs 20% global) → **+56pp**
# - **`pal001`**: 77% ha consumido alcohol (vs 25% global) → **+52pp**
# - **`pmj001`**: 48% ha usado marihuana (vs 6% global) → **+42pp**
#
# ##### **Conducta antisocial y delictiva grave:**
# - **`pcd027`**: 53% ha estado en peleas físicas con lesiones (vs 15% global) → **+38pp**
# - **`pcd012`**: 42% tuvo problemas por llegar tarde al toque de queda (vs 10% global) → **+32pp**
# - **`pcd039`**: 29% ha tenido problemas con la policía (vs 3% global) → **+26pp**
# - **`pcd014`**: 40% ha mentido para obtener dinero/beneficios (vs 14% global) → **+26pp**
# - **`pcd013`**: 27% tuvo problemas tempranos por llegar tarde (vs 3% global) → **+24pp**
# - **`pcd020`**: 26% ha cometido vandalismo (vs 6% global) → **+20pp**
#
# ##### **Sintomatología internalizante significativa:**
# - **`pmd009`**: 56% duerme más durante el día de lo habitual (vs 27% global) → **+30pp**
# - **`pmd012`**: 57% reporta menos energía (vs 28% global) → **+29pp**
#
# ##### **Irritabilidad y agresión interpersonal:**
# - **`pod007`**: 58% está irritable/fácilmente molesto (vs 42% global) → **+16pp**
# - **`pod010`**: 20% hace cosas malas a personas a propósito (vs 9% global) → **+12pp**
#
# ##### **Experiencias psicóticas:**
# - **`psz014`**: 15% se siente bajo control de algún poder/fuerza (vs 2% global) → **+13pp**
#
# #### Variables más distintivas (diferencias >30pp):
#
# | Variable | Descripción | % Clase 1 | % Global | Diferencia |
# |----------|-------------|-----------|----------|------------|
# | **pni001** | Tabaquismo | 76% | 20% | **+56pp** |
# | **pal001** | Consumo alcohol | 77% | 25% | **+52pp** |
# | **pmj001** | Uso de marihuana | 48% | 6% | **+42pp** |
# | **pcd027** | Peleas físicas con lesiones | 53% | 15% | **+38pp** |
# | **pcd012** | Problemas por llegar tarde | 42% | 10% | **+32pp** |
#
# #### Síntesis interpretativa:
#
# La **Clase 1** representa un perfil caracterizado por:
#
# 1. **Consumo problemático de múltiples sustancias** (tabaco, alcohol, marihuana)
# 2. **Conducta antisocial grave y diversa** (violencia, problemas legales, vandalismo)
# 3. **Sintomatología depresiva significativa** (fatiga, hipersomnia)
# 4. **Irritabilidad y tendencias agresivas**
# 5. **Algunas experiencias psicóticas** en menor medida
#
# Este patrón sugiere un **subgrupo de muy alta necesidad clínica** que probablemente requeriría intervenciones intensivas e integradas que aborden simultáneamente:
#
# - **Tratamiento de adicciones** con enfoque en policonsumo
# - **Manejo de la conducta antisocial** y prevención de reincidencia
# - **Tratamiento de síntomas depresivos** y regulación del sueño
# - **Evaluación y manejo de síntomas psicóticos** emergentes
# - **Desarrollo de habilidades de regulación emocional** y control de impulsos
#
# ### Clase 2 (k = 4)
#
# 918 observaciones (58.9%)
#
#   ---
#
#   Variables distintivas:
#
#      1. pal001:
#         SOBRE 1: 'NO' - 87% (801/918) vs 75% (1173/1558) global, +12pp
#         SUB 1: 'SI' - 13% (117/918) vs 25% (382/1558) global, -12pp
#
#      2. pni001:
#         SOBRE 1: 'NO' - 91% (838/918) vs 80% (1240/1558) global, +12pp
#         SUB 1: 'SI' - 9% (79/918) vs 20% (313/1558) global, -11pp
#
#      3. pod007:
#         SOBRE 1: 'NO' - 69% (637/918) vs 58% (900/1558) global, +12pp
#         SUB 1: 'SI' - 31% (281/918) vs 42% (656/1558) global, -11pp
#
# #### Perfil general:
# La **Clase 2** representa el subgrupo más numeroso del modelo (n=918, ~58.9% de la muestra) y muestra un **perfil de bajo riesgo o resiliente**, caracterizado por una menor prevalencia de conductas problemáticas en comparación con la muestra global.
#
# #### Hallazgos principales:
#
# ##### **Bajo consumo de sustancias:**
# - **`pal001`**: Solo el 13% ha consumido alcohol (vs 25% global) → **-12pp**
# - **`pni001`**: Solo el 9% ha fumado cigarrillos (vs 20% global) → **-11pp**
#
# ##### **Menor irritabilidad y problemas emocionales:**
# - **`pod007`**: Solo el 31% reporta irritabilidad (vs 42% global) → **-11pp**
#
#
# #### Síntesis interpretativa:
#
# La **Clase 2** representa un **perfil de bajo riesgo o resiliente** caracterizado por:
#
# 1. **Consumo muy bajo de sustancias** (alcohol y tabaco)
# 2. **Menores niveles de irritabilidad y problemas emocionales**
# 3. **Ausencia de conductas antisociales graves** (no aparecen en variables distintivas)
# 4. **Ausencia de sintomatología psicótica o depresiva significativa**
#
# Este patrón sugiere un **subgrupo con buen funcionamiento y adaptación**, que probablemente representa a la población general sin problemas clínicos significativos.
#
# ### Clase 3 (k = 4)
#
# 35 observaciones (2.2%)
#
#   ---
#   Variables distintivas:
#
#      1. pcd027:
#         SOBRE 1: 'SI' - 74% (26/35) vs 15% (233/1558) global, +59pp
#         SUB 1: 'NO' - 17% (6/35) vs 85% (1322/1558) global, -68pp
#
#      2. pcd014:
#         SOBRE 1: 'SI' - 57% (20/35) vs 14% (222/1558) global, +43pp
#         SUB 1: 'NO' - 34% (12/35) vs 85% (1332/1558) global, -51pp
#
#      3. pcd020:
#         SOBRE 1: 'SI' - 49% (17/35) vs 6% (94/1558) global, +43pp
#         SUB 1: 'NO' - 43% (15/35) vs 94% (1461/1558) global, -51pp
#
#      4. pal001:
#         SOBRE 1: 'SI' - 66% (23/35) vs 25% (382/1558) global, +41pp
#         SUB 1: 'NO' - 26% (9/35) vs 75% (1173/1558) global, -50pp
#
#      5. pni001:
#         SOBRE 1: 'SI' - 60% (21/35) vs 20% (313/1558) global, +40pp
#         SUB 1: 'NO' - 31% (11/35) vs 80% (1240/1558) global, -48pp
#
#      6. pcd019:
#         SOBRE 1: 'SI' - 40% (14/35) vs 1% (14/1558) global, +39pp
#         SUB 1: 'NO' - 51% (18/35) vs 99% (1541/1558) global, -47pp
#
#      7. pcd012:
#         SOBRE 1: 'SI' - 49% (17/35) vs 10% (151/1558) global, +39pp
#         SUB 1: 'NO' - 43% (15/35) vs 90% (1404/1558) global, -47pp
#
#      8. pcd021:
#         SOBRE 1: 'SI' - 37% (13/35) vs 8% (120/1558) global, +29pp
#         SUB 1: 'NO' - 54% (19/35) vs 92% (1434/1558) global, -38pp
#
#      9. pcd028:
#         SOBRE 1: 'SI' - 31% (11/35) vs 3% (53/1558) global, +28pp
#         SUB 1: 'NO' - 60% (21/35) vs 96% (1502/1558) global, -36pp
#
#     10. pmj001:
#         SOBRE 1: 'SI' - 34% (12/35) vs 6% (99/1558) global, +28pp
#         SUB 1: 'NO' - 57% (20/35) vs 93% (1456/1558) global, -36pp
#
#     11. pmd012:
#         SOBRE 1: 'SI' - 57% (20/35) vs 28% (437/1558) global, +29pp
#         SUB 1: 'NO' - 37% (13/35) vs 72% (1119/1558) global, -35pp
#
#     12. pcd029:
#         SOBRE 1: 'SI' - 29% (10/35) vs 2% (27/1558) global, +27pp
#         SUB 1: 'NO' - 66% (23/35) vs 98% (1529/1558) global, -32pp
#
#     13. pcd039:
#         SOBRE 1: 'SI' - 26% (9/35) vs 3% (52/1558) global, +22pp
#         SUB 1: 'NO' - 66% (23/35) vs 96% (1503/1558) global, -31pp
#
#     14. pcd015:
#         SOBRE 1: 'SI' - 31% (11/35) vs 9% (142/1558) global, +22pp
#         SUB 1: 'NO' - 60% (21/35) vs 91% (1413/1558) global, -31pp
#
#     15. pcd003:
#         SOBRE 1: 'SI' - 29% (10/35) vs 7% (110/1558) global, +22pp
#         SUB 1: 'NO' - 63% (22/35) vs 93% (1445/1558) global, -30pp
#
#     16. pcd013:
#         SOBRE 1: 'SI' - 23% (8/35) vs 3% (47/1558) global, +20pp
#         SUB 1: 'NO' - 69% (24/35) vs 97% (1508/1558) global, -28pp
#
#     17. pmd009:
#         SOBRE 1: 'SI' - 49% (17/35) vs 27% (415/1558) global, +22pp
#         SUB 1: 'NO' - 46% (16/35) vs 73% (1141/1558) global, -28pp
#
#     18. psu011:
#         SOBRE 1: 'SI' - 14% (5/35) vs 0% (5/1558) global, +14pp
#         SUB 1: 'NO' - 77% (27/35) vs 99% (1550/1558) global, -22pp
#
#     19. pod010:
#         SOBRE 1: 'SI' - 20% (7/35) vs 9% (134/1558) global, +11pp
#         SUB 1: 'NO' - 71% (25/35) vs 91% (1420/1558) global, -20pp
#
#     20. pcd009:
#         SOBRE 1: 'SI' - 11% (4/35) vs 0% (4/1558) global, +11pp
#         SUB 1: 'NO' - 80% (28/35) vs 100% (1551/1558) global, -20pp
#
#     21. pcd008:
#         SOBRE 1: 'SI' - 11% (4/35) vs 0% (4/1558) global, +11pp
#         SUB 1: 'NO' - 80% (28/35) vs 100% (1551/1558) global, -20pp
#
#     22. pcd007:
#         SOBRE 1: 'SI' - 11% (4/35) vs 0% (4/1558) global, +11pp
#         SUB 1: 'NO' - 80% (28/35) vs 100% (1551/1558) global, -20pp
#
#     23. pod007:
#         SOBRE 1: 'SI' - 54% (19/35) vs 42% (656/1558) global, +12pp
#         SUB 1: 'NO' - 40% (14/35) vs 58% (900/1558) global, -18pp
#
#     24. psz014:
#         SUB 1: 'NO' - 83% (29/35) vs 98% (1529/1558) global, -15pp
#
#     25. pod011:
#         SUB 1: 'NO' - 80% (28/35) vs 91% (1415/1558) global, -11pp
#
# #### Perfil general:
# La **Clase 3** representa un subgrupo muy pequeño pero clínicamente extremo (n=35, ~2.2% de la muestra) que muestra un **perfil de severidad máxima**, caracterizado por la presencia simultánea de múltiples conductas antisociales graves, consumo de sustancias y delitos violentos.
#
# #### Hallazgos principales:
#
# ##### **Conducta violenta y agresiva extrema:**
# - **`pcd027`**: 74% ha estado en peleas físicas con lesiones (vs 15% global) → **+59pp**
# - **`pcd029`**: 29% ha herido a alguien con un arma (vs 2% global) → **+27pp**
# - **`pcd028`**: 31% ha intentado lastimar gravemente a alguien (vs 3% global) → **+28pp**
# - **`pcd020`**: 49% ha cometido vandalismo (vs 6% global) → **+43pp**
#
# ##### **Delitos graves y conducta delictiva diversa:**
# - **`pcd019`**: 40% ha cometido allanamiento (vs 1% global) → **+39pp**
# - **`pcd009`**: 11% ha amenazado para robar (vs >1% global) → **+11pp**
# - **`pcd008`**: 11% ha atacado con intención de robar (vs >1% global) → **+11pp**
# - **`pcd007`**: 11% ha arrebatado bolso o joyas (vs >1% global) → **+11pp**
# - **`pcd003`**: 29% ha robado cuando nadie miraba (vs 7% global) → **+22pp**
#
# ##### **Consumo de sustancias elevado:**
# - **`pal001`**: 66% ha consumido alcohol (vs 25% global) → **+41pp**
# - **`pni001`**: 60% ha fumado cigarrillos (vs 20% global) → **+40pp**
# - **`pmj001`**: 34% ha usado marihuana (vs 6% global) → **+28pp**
# - **`psu011`**: 14% ha usado otras drogas no preguntadas (vs >1% global) → **+14pp**
#
# ##### **Engaño y fraudes:**
# - **`pcd014`**: 57% ha mentido para obtener dinero/beneficios (vs 14% global) → **+43pp**
# - **`pcd015`**: 31% ha mentido para evitar pagos/responsabilidades (vs 9% global) → **+22pp**
#
# ##### **Problemas conductuales tempranos y legales:**
# - **`pcd012`**: 49% tuvo problemas por llegar tarde al toque de queda (vs 10% global) → **+39pp**
# - **`pcd013`**: 23% tuvo problemas tempranos por llegar tarde (vs 3% global) → **+20pp**
# - **`pcd039`**: 26% ha tenido problemas con la policía (vs 3% global) → **+22pp**
#
# ##### **Sintomatología internalizante:**
# - **`pmd012`**: 57% reporta menos energía (vs 28% global) → **+29pp**
# - **`pmd009`**: 49% duerme más durante el día (vs 27% global) → **+22pp**
#
# ##### **Irritabilidad y agresión interpersonal:**
# - **`pod007`**: 54% está irritable/fácilmente molesto (vs 42% global) → **+12pp**
# - **`pod010`**: 20% hace cosas malas a personas a propósito (vs 9% global) → **+11pp**
#
# #### Variables más distintivas (diferencias >40pp):
#
# | Variable | Descripción | % Clase 3 | % Global | Diferencia |
# |----------|-------------|-----------|----------|------------|
# | **pcd027** | Peleas físicas con lesiones | 74% | 15% | **+59pp** |
# | **pcd014** | Mentir para obtener dinero | 57% | 14% | **+43pp** |
# | **pcd020** | Vandalismo | 49% | 6% | **+43pp** |
# | **pal001** | Consumo alcohol | 66% | 25% | **+41pp** |
# | **pni001** | Tabaquismo | 60% | 20% | **+40pp** |
# | **pcd019** | Allanamiento | 40% | 1% | **+39pp** |
# | **pcd012** | Problemas por llegar tarde | 49% | 10% | **+39pp** |
#
# #### Síntesis interpretativa:
#
# La **Clase 3** representa un **perfil de máxima severidad y peligrosidad** caracterizado por:
#
# 1. **Violencia extrema y variada** (peleas, uso de armas, crueldad física)
# 2. **Criminalidad diversa y grave** (allanamiento, robos con violencia, amenazas)
# 3. **Consumo problemático de múltiples sustancias** (alcohol, tabaco, marihuana, otras drogas)
# 4. **Patrones extensos de engaño y fraude**
# 5. **Inicio temprano de problemas conductuales**
# 6. **Significativos problemas legales** (policía, sistema judicial)
# 7. **Sintomatología depresiva concurrente**
#
# Este patrón sugiere un **subgrupo de extrema necesidad clínica y riesgo social** que probablemente representa a individuos con **trastorno de conducta severo y posible psicopatía emergente**. La combinación de violencia, criminalidad y consumo de sustancias indica un pronóstico reservado y alta probabilidad de reincidencia.
#
# **Intervenciones necesarias:**
# - **Manejo especializado en justicia juvenil/penal**
# - **Tratamiento intensivo de adicciones**
# - **Terapia conductual especializada para agresión**
# - **Evaluación de riesgo de violencia**
# - **Intervenciones familiares y comunitarias intensivas**
#
# ## Síntesis de Diferenciación de Clases (k=4)
#
# | **Criterio** | **Clase 0 (Externalización Moderada)** | **Clase 1 (Policonsumo & Antisocial)** | **Clase 2 (Bajo Riesgo / Resiliente)** | **Clase 3 (Severidad Máxima & Delictiva)** |
# | :--- | :--- | :--- | :--- | :--- |
# | **Tamaño de la Clase** | 458 observaciones (29.4%) | 147 observaciones (9.4%) | 918 observaciones (58.9%) | 35 observaciones (2.2%) |
# | **Patrón Principal** | **Externalización moderada con irritabilidad.** Problemas de regulación emocional y conductas agresivas leves o instrumentales, sin consumo grave ni delitos mayores. | **Comorbilidad de policonsumo y conducta antisocial grave.** Combinación de consumo problemático de sustancias, transgresiones severas y sintomatología internalizante. | **Ajuste adaptativo y bajo riesgo.** Caracterizada por la sub-representación de problemas conductuales, emocionales y de consumo. Perfil normativo. | **Criminalidad y violencia severa.** Perfil extremo que combina delitos graves, violencia física extrema, consumo de sustancias y conducta antisocial diversa y temprana. |
# | **Núcleo del Perfil** | **Irritabilidad, agresión interpersonal y deshonestidad menor.** Predominan la labilidad emocional (irritabilidad), la venganza, el daño a propiedad y el engaño en contextos instrumentales. | **Tríada de adicción, agresión y depresión.** Consumo de tabaco, alcohol y marihuana; conducta violenta y fraudulenta; junto a síntomas depresivos (fatiga, hipersomnia). | **Resiliencia y factores protectores.** Se define por la **ausencia** de indicadores problemáticos clave (bajo consumo, baja irritabilidad). Actúa como grupo de referencia saludable. | **Conducta delictiva violenta y versátil.** Núcleo de violencia interpersonal extrema (peleas, armas), delitos contra la propiedad (allanamiento, robos) y patrones extensos de engaño y transgresión. |
# | **Síntomas más Distintivos (Diferencia >10pp vs. Global)** | 1. **pod007:** Irritabilidad (+17pp)<br>2. **pod011:** Vengarse dañando (+17pp)<br>3. **pod010:** Hacer daño a propósito (+13pp)<br>4. **pcd015:** Mentir para evitar responsabilidad (+11pp) | 1. **pni001:** Tabaquismo (+56pp)<br>2. **pal001:** Consumo de alcohol (+52pp)<br>3. **pmj001:** Uso de marihuana (+42pp)<br>4. **pcd027:** Peleas con lesiones (+38pp)<br>5. **pcd012:** Problemas por toque de queda (+32pp) | 1. **pal001:** Bajo consumo de alcohol (-12pp en 'SI')<br>2. **pni001:** Bajo tabaquismo (-11pp en 'SI')<br>3. **pod007:** Baja irritabilidad (-11pp en 'SI') | 1. **pcd027:** Peleas con lesiones (+59pp)<br>2. **pcd014:** Mentir por dinero/beneficios (+43pp)<br>3. **pcd020:** Vandalismo (+43pp)<br>4. **pal001:** Consumo de alcohol (+41pp)<br>5. **pni001:** Tabaquismo (+40pp)<br>6. **pcd019:** Allanamiento (+39pp) |
# | **Riesgo Asociado** | **Moderado.** Riesgo de escalada a trastornos de conducta, conflictos interpersonales crónicos y posible desarrollo de problemas internalizantes por mala regulación emocional. | **Alto.** Riesgo de cronicidad en adicciones, reincidencia delictiva, deterioro funcional y complicaciones por la comorbilidad depresiva. | **Muy Bajo.** Representa el perfil de ajuste saludable. El riesgo principal es la posible transición hacia clases problemáticas sin factores protectores adecuados. | **Muy Alto y Extemo.** Alto riesgo de daño a terceros, encarcelamiento, cronicidad delictiva, adicciones severas y mortalidad por causas violentas. Pronóstico reservado. |
# | **Abordaje Sugerido** | **Intervención temprana en regulación emocional y conducta.** Programas para manejo de la ira, desarrollo de empatía, solución de conflictos y tratamiento breve para la deshonestidad. | **Tratamiento especializado integrado.** Intervenciones simultáneas para: adicciones (policonsumo), control de impulsos y agresión, tratamiento de síntomas depresivos, y rehabilitación para conducta antisocial. | **Prevención universal y promoción de la salud.** Fortalecimiento de factores protectores (habilidades sociales, manejo del estrés) para mantener el ajuste y prevenir la aparición de problemas. | **Intervención judicial y clínica intensiva especializada.** Manejo en contexto de justicia juvenil/penal con terapia conductual especializada para agresión, desintoxicación, evaluación de riesgo de violencia e intervenciones familiares multidisciplinarias intensivas. |
#
# ---

# %% [markdown]
# # Clasificación LCA k = 5
#
# ## Variables más discriminatorias:
#
# | Variable | Cramér's V | p-value | χ² | Discriminación |
# |----------|------------|---------|----|----------------|
# | pmj001 | 0.4801 | 1.40e-149 | 717 | 0.994 |
# | pcd019 | 0.4668 | 3.88e-141 | 678 | 0.994 |
# | psz011 | 0.4212 | 4.83e-114 | 552 | 0.992 |
# | pal001 | 0.4072 | 2.51e-106 | 516 | 0.994 |
# | pni001 | 0.3987 | 9.81e-102 | 495 | 0.992 |
# | pcd029 | 0.3802 | 1.59e-47 | 225 | 1.000 |
# | pcd027 | 0.3716 | 7.88e-88 | 430 | 0.994 |
# | pcd012 | 0.3710 | 1.64e-87 | 428 | 0.994 |
# | pcd039 | 0.3443 | 8.14e-75 | 369 | 0.994 |
# | pcd013 | 0.3296 | 3.02e-68 | 338 | 0.994 |
# | pcd020 | 0.3208 | 1.94e-64 | 320 | 0.994 |
# | psz014 | 0.3113 | 1.99e-60 | 301 | 0.992 |
# | pcd015 | 0.3064 | 1.89e-58 | 292 | 0.994 |
# | pmd012 | 0.2976 | 8.34e-29 | 138 | 1.000 |
# | psu011 | 0.2943 | 1.18e-53 | 270 | 0.994 |
# | pmd021 | 0.2917 | 1.26e-52 | 265 | 0.992 |
# | pcd014 | 0.2853 | 3.34e-50 | 253 | 0.994 |
# | pod010 | 0.2852 | 3.87e-50 | 253 | 0.992 |
# | psu003 | 0.2839 | 1.13e-49 | 251 | 0.994 |
# | pmd008 | 0.2827 | 6.37e-26 | 124 | 1.000 |
# | pmd009 | 0.2808 | 1.42e-25 | 123 | 1.000 |
# | pod007 | 0.2792 | 2.77e-25 | 121 | 1.000 |
# | pcd028 | 0.2783 | 1.43e-47 | 241 | 0.994 |
# | pcd021 | 0.2738 | 6.11e-46 | 233 | 0.994 |
# | pcd003 | 0.2727 | 1.49e-45 | 231 | 0.994 |

# %%
variables = ["pmj001","pcd019", "psz011","pal001","pni001","pcd029","pcd027","pcd012","pcd039","pcd013","pcd020","psz014","pcd015","pmd012","psu011","pmd021","pcd014","pod010","psu003","pmd008","pmd009","pod007","pcd028","pcd021","pcd003"
]
ut.imprimir_etiquetas(variables, df_etiquetas)
# Out:
# ...
# LISTADO DE ETIQUETAS (25 variables)
# ...
#   1. [pmj001] - Ever in whole life used marijuana
#   2. [pcd019] - Ever broken into a house/building/c ar
#   3. [psz011] - Believe someone was plotting against you/trying to hurt you
#   4. [pal001] - Not including sips from other peoples, ever had even one drink
#   5. [pni001] - Ever smoked a cigarette
#   6. [pcd029] - Ever hurt someone with a weapon (like a bat/brick/knife/g un)
#   7. [pcd027] - Ever been in a physical fight in which someone was hurt/could have been hurt
#   8. [pcd012] - Ever gotten into trouble for staying out 2 hours past curfew
#   9. [pcd039] - Ever been in trouble with the police
#  10. [pcd013] - Age when first got into trouble for staying out too late
#  11. [pcd020] - Broken something/mes sed up a place on purpose (like breaking windows)
#  12. [psz014] - Convinced under the control of some power/force
#  13. [pcd015] - Ever lied to not pay back money or to get out of doing something important
# ...

# %% [markdown]
# ## Hallazgos principales:
#
# ### Variables más discriminantes (Cramér's V > 0.45):
# - **`pmj001`** – *"Ever in whole life used marijuana"*
#     - **Cramér's V = 0.4801**
#     - **p = 1.40e-149**
# - **`pcd019`** – *"Ever broken into a house/building/car"*
#     - **Cramér's V = 0.4668**
#     - **p = 3.88e-141**
#
# ### Dimensiones temáticas predominantes:
#
# #### **Consumo de sustancias:**
# - `pmj001` – Uso de marihuana
# - `pal001` – Consumo de alcohol
# - `pni001` – Tabaquismo
# - `psu011` – Uso de otras drogas para drogarse
# - `psu003` – Uso de cocaína o crack
#
# #### **Conducta antisocial y agresiva:**
# - `pcd019` – Allanamiento de vivienda/edificio/auto
# - `pcd029` – Herir a alguien con un arma
# - `pcd027` – Participar en peleas físicas con lesiones
# - `pcd028` – Intentar lastimar gravemente a alguien
# - `pcd020` – Vandalismo (romper/destruir propiedad)
# - `pcd021` – Dañar propiedades ajenas intencionalmente
# - `pod010` – Hacer cosas malas a personas intencionalmente
#
# #### **Experiencias psicóticas o similares:**
# - `psz011` – Creer que alguien conspiraba en su contra/trataba de lastimarlo
# - `psz014` – Convencido/a de estar bajo control de algún poder/fuerza
#
# #### **Problemas internalizantes y afectivos:**
# - `pmd012` – Menos energía en el último año
# - `pmd021` – Hablado seriamente sobre suicidarse en el último año
# - `pmd008` – Problemas para dormir en el último año
# - `pmd009` – Dormir más durante el día de lo habitual en el último año
# - `pod007` – Mal humor/fácilmente irritable en el último año
#
# #### **Comportamientos delictivos y transgresiones:**
# - `pcd012` – Problemas por llegar tarde más de 2 horas
# - `pcd039` – Problemas con la policía
# - `pcd013` – Edad al primer problema por llegar tarde
# - `pcd014` – Mentir para obtener dinero/algo más
# - `pcd015` – Mentir para no pagar dinero/evitar responsabilidades
# - `pcd003` – Robar de alguien cuando no estaba/nadie miraba

# %% [markdown]
# ## Categorías Sub y Sobre-Representadas
#
# ### Clase 0 (k = 5)
#
#  36 observaciones (2.3%)
#
#   ---
#   Variables distintivas:
#
#      1. pcd027:
#         SOBRE 1: 'SI' - 75% (27/36) vs 15% (233/1558) global, +60pp
#         SUB 1: 'NO' - 17% (6/36) vs 85% (1322/1558) global, -68pp
#
#      2. pcd014:
#         SOBRE 1: 'SI' - 58% (21/36) vs 14% (222/1558) global, +44pp
#         SUB 1: 'NO' - 33% (12/36) vs 85% (1332/1558) global, -52pp
#
#      3. pni001:
#         SOBRE 1: 'SI' - 64% (23/36) vs 20% (313/1558) global, +44pp
#         SUB 1: 'NO' - 28% (10/36) vs 80% (1240/1558) global, -52pp
#
#      4. pcd012:
#         SOBRE 1: 'SI' - 53% (19/36) vs 10% (151/1558) global, +43pp
#         SUB 1: 'NO' - 39% (14/36) vs 90% (1404/1558) global, -51pp
#
#      5. pal001:
#         SOBRE 1: 'SI' - 67% (24/36) vs 25% (382/1558) global, +42pp
#         SUB 1: 'NO' - 25% (9/36) vs 75% (1173/1558) global, -50pp
#
#      6. pcd020:
#         SOBRE 1: 'SI' - 47% (17/36) vs 6% (94/1558) global, +41pp
#         SUB 1: 'NO' - 44% (16/36) vs 94% (1461/1558) global, -49pp
#
#      7. pcd019:
#         SOBRE 1: 'SI' - 39% (14/36) vs 1% (14/1558) global, +38pp
#         SUB 1: 'NO' - 53% (19/36) vs 99% (1541/1558) global, -46pp
#
#      8. pmj001:
#         SOBRE 1: 'SI' - 39% (14/36) vs 6% (99/1558) global, +33pp
#         SUB 1: 'NO' - 53% (19/36) vs 93% (1456/1558) global, -41pp
#
#      9. pcd021:
#         SOBRE 1: 'SI' - 36% (13/36) vs 8% (120/1558) global, +28pp
#         SUB 1: 'NO' - 56% (20/36) vs 92% (1434/1558) global, -36pp
#
#     10. pmd012:
#         SOBRE 1: 'SI' - 61% (22/36) vs 28% (437/1558) global, +33pp
#         SUB 1: 'NO' - 36% (13/36) vs 72% (1119/1558) global, -36pp
#
#     11. pcd028:
#         SOBRE 1: 'SI' - 31% (11/36) vs 3% (53/1558) global, +27pp
#         SUB 1: 'NO' - 61% (22/36) vs 96% (1502/1558) global, -35pp
#
#     12. pmd008:
#         SOBRE 1: 'SI' - 67% (24/36) vs 34% (531/1558) global, +33pp
#         SUB 1: 'NO' - 31% (11/36) vs 66% (1025/1558) global, -35pp
#
#     13. pcd013:
#         SOBRE 1: 'SI' - 28% (10/36) vs 3% (47/1558) global, +25pp
#         SUB 1: 'NO' - 64% (23/36) vs 97% (1508/1558) global, -33pp
#
#     14. pcd039:
#         SOBRE 1: 'SI' - 28% (10/36) vs 3% (52/1558) global, +24pp
#         SUB 1: 'NO' - 64% (23/36) vs 96% (1503/1558) global, -33pp
#
#     15. pcd029:
#         SOBRE 1: 'SI' - 28% (10/36) vs 2% (27/1558) global, +26pp
#         SUB 1: 'NO' - 67% (24/36) vs 98% (1529/1558) global, -31pp
#
#     16. pcd015:
#         SOBRE 1: 'SI' - 31% (11/36) vs 9% (142/1558) global, +21pp
#         SUB 1: 'NO' - 61% (22/36) vs 91% (1413/1558) global, -30pp
#
#     17. pcd003:
#         SOBRE 1: 'SI' - 28% (10/36) vs 7% (110/1558) global, +21pp
#         SUB 1: 'NO' - 64% (23/36) vs 93% (1445/1558) global, -29pp
#
#     18. pmd009:
#         SOBRE 1: 'SI' - 53% (19/36) vs 27% (415/1558) global, +26pp
#         SUB 1: 'NO' - 44% (16/36) vs 73% (1141/1558) global, -29pp
#
#     19. psu003:
#         SOBRE 1: 'SI' - 19% (7/36) vs 1% (12/1558) global, +19pp
#         SUB 1: 'NO' - 72% (26/36) vs 99% (1543/1558) global, -27pp
#
#     20. psu011:
#         SOBRE 1: 'SI' - 14% (5/36) vs 0% (5/1558) global, +14pp
#         SUB 1: 'NO' - 78% (28/36) vs 99% (1550/1558) global, -22pp
#
#     21. pod010:
#         SOBRE 1: 'SI' - 19% (7/36) vs 9% (134/1558) global, +11pp
#         SUB 1: 'NO' - 72% (26/36) vs 91% (1420/1558) global, -19pp
#
#     22. pod007:
#         SOBRE 1: 'SI' - 56% (20/36) vs 42% (656/1558) global, +13pp
#         SUB 1: 'NO' - 39% (14/36) vs 58% (900/1558) global, -19pp
#
#     23. pmd021:
#         SOBRE 1: 'SI' - 19% (7/36) vs 7% (105/1558) global, +13pp
#         SUB 1: 'NO' - 75% (27/36) vs 93% (1449/1558) global, -18pp
#
#     24. psz011:
#         SOBRE 1: 'SI' - 17% (6/36) vs 4% (64/1558) global, +13pp
#         SUB 1: 'NO' - 78% (28/36) vs 96% (1490/1558) global, -18pp
#
#     25. psz014:
#         SOBRE 1: 'SI' - 14% (5/36) vs 2% (25/1558) global, +12pp
#         SUB 1: 'NO' - 81% (29/36) vs 98% (1529/1558) global, -18pp
#
# #### Perfil general:
# La **Clase 0** representa un subgrupo muy pequeño pero extremadamente severo (n=36, 2.3% de la muestra) que exhibe un **perfil de máxima severidad conductual y de riesgo**.
#
# #### Hallazgos principales:
#
# ##### **Conducta externalizante extremadamente elevada:**
# - **`pcd027`**: 75% ha estado en peleas físicas con lesiones (vs 15% global) → **+60pp**
# - **`pcd019`**: 39% ha cometido allanamiento (vs 1% global) → **+38pp**
# - **`pcd020`**: 47% ha cometido vandalismo (vs 6% global) → **+41pp**
# - **`pcd028`**: 31% ha intentado lastimar gravemente a alguien (vs 3% global) → **+27pp**
# - **`pcd029`**: 28% ha herido a alguien con arma (vs 2% global) → **+26pp**
#
# ##### **Consumo de sustancias universal:**
# - **`pal001`**: 67% ha consumido alcohol (vs 25% global) → **+42pp**
# - **`pni001`**: 64% ha fumado cigarrillos (vs 20% global) → **+44pp**
# - **`pmj001`**: 39% ha usado marihuana (vs 6% global) → **+33pp**
# - **`psu003`**: 19% ha usado cocaína/crack (vs 1% global) → **+19pp**
# - **`psu011`**: 14% ha usado otras drogas (vs 0% global) → **+14pp**
#
# ##### **Transgresiones y delitos múltiples:**
# - **`pcd014`**: 58% ha mentido para obtener dinero (vs 14% global) → **+44pp**
# - **`pcd012`**: 53% tuvo problemas por llegar tarde (vs 10% global) → **+43pp**
# - **`pcd015`**: 31% ha mentido para evitar responsabilidades (vs 9% global) → **+21pp**
# - **`pcd003`**: 28% ha robado a alguien (vs 7% global) → **+21pp**
# - **`pcd039`**: 28% ha tenido problemas con la policía (vs 3% global) → **+24pp**
#
# ##### **Sintomatología internalizante severa:**
# - **`pmd012`**: 61% reporta menos energía (vs 28% global) → **+33pp**
# - **`pmd008`**: 67% tiene problemas de sueño (vs 34% global) → **+33pp**
# - **`pmd009`**: 53% duerme más durante el día (vs 27% global) → **+26pp**
# - **`pmd021`**: 19% ha hablado de suicidarse (vs 7% global) → **+13pp**
# - **`pod007`**: 56% es irritable/grumpy (vs 42% global) → **+13pp**
#
# ##### **Experiencias psicóticas presentes:**
# - **`psz011`**: 17% cree que conspiran contra él/ella (vs 4% global) → **+13pp**
# - **`psz014`**: 14% se siente bajo control externo (vs 2% global) → **+12pp**
#
# #### Variables más distintivas (diferencias >30pp):
#
# | Variable | Descripción | % Clase 0 | % Global | Diferencia |
# |----------|-------------|-----------|----------|------------|
# | **pcd027** | Peleas físicas con lesiones | 75% | 15% | **+60pp** |
# | **pcd014** | Mentir para obtener dinero | 58% | 14% | **+44pp** |
# | **pni001** | Tabaquismo | 64% | 20% | **+44pp** |
# | **pcd012** | Problemas por llegar tarde | 53% | 10% | **+43pp** |
# | **pal001** | Consumo de alcohol | 67% | 25% | **+42pp** |
# | **pcd020** | Vandalismo | 47% | 6% | **+41pp** |
# | **pcd019** | Allanamiento | 39% | 1% | **+38pp** |
#
# #### Síntesis interpretativa:
#
# La **Clase 0** representa un **perfil de máxima severidad y polimorfismo psicopatológico** que combina:
#
# 1. **Violencia física extrema** (peleas, armas, crueldad)
# 2. **Criminalidad diversificada** (allanamiento, vandalismo, robos)
# 3. **Policonsumo de sustancias** (alcohol, tabaco, marihuana, cocaína, otras drogas)
# 4. **Patrón generalizado de engaño y transgresión**
# 5. **Sintomatología afectiva severa** (problemas de sueño, energía, ideación suicida)
# 6. **Experiencias psicóticas incipientes** (paranoia, ideas de control)
#
# **Intervenciones recomendadas:**
# 1. **Contención y supervisión intensiva** (posible entorno residencial)
# 2. **Tratamiento integral de adicciones**
# 3. **Terapia conductual para control de impulsos y agresión**
# 4. **Evaluación psiquiátrica completa** (riesgo psicótico, estado de ánimo)
# 5. **Intervenciones legales y de justicia restaurativa**
# 6. **Apoyo familiar y psicoeducación intensiva**
#
#   ### Clase 1 (k = 5)
#
# 111 observaciones (7.1%)
#
#   ---
#   Variables distintivas:
#
#      1. pal001:
#         SOBRE 1: 'SI' - 91% (101/111) vs 25% (382/1558) global, +66pp
#         SUB 1: 'NO' - 9% (10/111) vs 75% (1173/1558) global, -66pp
#
#      2. pni001:
#         SOBRE 1: 'SI' - 84% (93/111) vs 20% (313/1558) global, +64pp
#         SUB 1: 'NO' - 16% (18/111) vs 80% (1240/1558) global, -63pp
#
#      3. pmj001:
#         SOBRE 1: 'SI' - 57% (63/111) vs 6% (99/1558) global, +50pp
#         SUB 1: 'NO' - 43% (48/111) vs 93% (1456/1558) global, -50pp
#
#      4. pcd027:
#         SOBRE 1: 'SI' - 55% (61/111) vs 15% (233/1558) global, +40pp
#         SUB 1: 'NO' - 45% (50/111) vs 85% (1322/1558) global, -40pp
#
#      5. pcd012:
#         SOBRE 1: 'SI' - 43% (48/111) vs 10% (151/1558) global, +34pp
#         SUB 1: 'NO' - 57% (63/111) vs 90% (1404/1558) global, -33pp
#
#      6. pmd009:
#         SOBRE 1: 'SI' - 50% (56/111) vs 27% (415/1558) global, +24pp
#         SUB 1: 'NO' - 50% (55/111) vs 73% (1141/1558) global, -24pp
#
#      7. pcd039:
#         SOBRE 1: 'SI' - 26% (29/111) vs 3% (52/1558) global, +23pp
#         SUB 1: 'NO' - 74% (82/111) vs 96% (1503/1558) global, -23pp
#
#      8. pcd020:
#         SOBRE 1: 'SI' - 26% (29/111) vs 6% (94/1558) global, +20pp
#         SUB 1: 'NO' - 74% (82/111) vs 94% (1461/1558) global, -20pp
#
#      9. pcd014:
#         SOBRE 1: 'SI' - 34% (38/111) vs 14% (222/1558) global, +20pp
#         SUB 1: 'NO' - 66% (73/111) vs 85% (1332/1558) global, -20pp
#
#     10. pcd015:
#         SOBRE 1: 'SI' - 29% (32/111) vs 9% (142/1558) global, +20pp
#         SUB 1: 'NO' - 71% (79/111) vs 91% (1413/1558) global, -20pp
#
#     11. pcd013:
#         SOBRE 1: 'SI' - 23% (25/111) vs 3% (47/1558) global, +20pp
#         SUB 1: 'NO' - 77% (86/111) vs 97% (1508/1558) global, -19pp
#
#     12. pmd012:
#         SOBRE 1: 'SI' - 46% (51/111) vs 28% (437/1558) global, +18pp
#         SUB 1: 'NO' - 54% (60/111) vs 72% (1119/1558) global, -18pp
#
#     13. pcd028:
#         SOBRE 1: 'SI' - 17% (19/111) vs 3% (53/1558) global, +14pp
#         SUB 1: 'NO' - 83% (92/111) vs 96% (1502/1558) global, -14pp
#
#     14. pcd003:
#         SOBRE 1: 'SI' - 17% (19/111) vs 7% (110/1558) global, +10pp
#
# #### Perfil general:
# La **Clase 1** representa un subgrupo de tamaño moderado (n=111, 7.1% de la muestra) que exhibe un **perfil de alto consumo de sustancias y conducta externalizante**, caracterizado por el uso casi universal de alcohol y tabaco, junto con comportamientos agresivos y transgresiones frecuentes.
#
# #### Hallazgos principales:
#
# ##### **Consumo de sustancias extremadamente elevado:**
# - **`pal001`**: 91% ha consumido alcohol (vs 25% global) → **+66pp**
# - **`pni001`**: 84% ha fumado cigarrillos (vs 20% global) → **+64pp**
# - **`pmj001`**: 57% ha usado marihuana (vs 6% global) → **+50pp**
#
# ##### **Conducta externalizante frecuente:**
# - **`pcd027`**: 55% ha estado en peleas físicas con lesiones (vs 15% global) → **+40pp**
# - **`pcd012`**: 43% tuvo problemas por llegar tarde (vs 10% global) → **+34pp**
# - **`pcd020`**: 26% ha cometido vandalismo (vs 6% global) → **+20pp**
# - **`pcd028`**: 17% ha intentado lastimar gravemente a alguien (vs 3% global) → **+14pp**
#
# ##### **Transgresiones y problemas conductuales:**
# - **`pcd014`**: 34% ha mentido para obtener dinero (vs 14% global) → **+20pp**
# - **`pcd015`**: 29% ha mentido para evitar responsabilidades (vs 9% global) → **+20pp**
# - **`pcd013`**: 23% tuvo problemas por llegar tarde (edad temprana) (vs 3% global) → **+20pp**
# - **`pcd039`**: 26% ha tenido problemas con la policía (vs 3% global) → **+23pp**
# - **`pcd003`**: 17% ha robado a alguien (vs 7% global) → **+10pp**
#
# ##### **Sintomatología internalizante:**
# - **`pmd009`**: 50% duerme más durante el día (vs 27% global) → **+24pp**
# - **`pmd012`**: 46% reporta menos energía (vs 28% global) → **+18pp**
#
# #### Variables más distintivas (diferencias >30pp):
#
# | Variable | Descripción | % Clase 1 | % Global | Diferencia |
# |----------|-------------|-----------|----------|------------|
# | **pal001** | Consumo de alcohol | 91% | 25% | **+66pp** |
# | **pni001** | Tabaquismo | 84% | 20% | **+64pp** |
# | **pmj001** | Uso de marihuana | 57% | 6% | **+50pp** |
# | **pcd027** | Peleas físicas con lesiones | 55% | 15% | **+40pp** |
# | **pcd012** | Problemas por llegar tarde | 43% | 10% | **+34pp** |
#
# #### Síntesis interpretativa:
#
# La **Clase 1** representa un **perfil de policonsumo de sustancias y conducta externalizante** que se caracteriza por:
#
# 1. **Consumo casi universal de alcohol y tabaco**, y elevado de marihuana
# 2. **Comportamiento agresivo frecuente** (peleas, vandalismo, intentos de daño)
# 3. **Historial de transgresiones y problemas disciplinarios** (mentiras, robos, problemas con la policía)
# 4. **Algunos síntomas internalizantes** (somnolencia diurna, falta de energía)
#
# Este patrón sugiere un **subgrupo con trastorno por uso de sustancias y trastorno de conducta**:
# - **Abuso/dependencia de múltiples sustancias** (especialmente alcohol, tabaco y marihuana)
# - **Comportamiento antisocial no extremo** pero significativo
# - **Posible afectación del funcionamiento diario** (sueño, energía)
#
# **Intervenciones recomendadas:**
# 1. **Tratamiento para el consumo de sustancias** (prevención de recaídas, reducción de daños)
# 2. **Intervenciones en habilidades de manejo de ira y resolución de conflictos**
# 3. **Manejo de problemas de sueño y energía** (higiene del sueño, activación conductual)
# 4. **Orientación vocacional y de actividades prosociales** para canalizar la energía
# 5. **Psicoeducación familiar** sobre el consumo de sustancias y conducta de riesgo
#
# ### Clase 2 (k = 5)
# 386 observaciones (24.8%)
#
#   ---
#   Variables distintivas:
#
#      1. pod007:
#         SOBRE 1: 'SI' - 61% (235/386) vs 42% (656/1558) global, +19pp
#         SUB 1: 'NO' - 39% (151/386) vs 58% (900/1558) global, -19pp
#
#      2. pod010:
#         SOBRE 1: 'SI' - 24% (91/386) vs 9% (134/1558) global, +15pp
#         SUB 1: 'NO' - 76% (295/386) vs 91% (1420/1558) global, -15pp
#
#      3. pmd021:
#         SOBRE 1: 'SI' - 18% (70/386) vs 7% (105/1558) global, +11pp
#         SUB 1: 'NO' - 82% (316/386) vs 93% (1449/1558) global, -11pp
#
#      4. pcd021:
#         SOBRE 1: 'SI' - 18% (70/386) vs 8% (120/1558) global, +10pp
#         SUB 1: 'NO' - 82% (315/386) vs 92% (1434/1558) global, -10pp
#
# #### Perfil general:
# La **Clase 2**  exhibe un **perfil de sintomatología internalizante con componentes externalizantes leves**, caracterizado principalmente por mal humor, irritabilidad y algunos comportamientos agresivos sutiles.
#
# #### Hallazgos principales:
#
# ##### **Sintomatología internalizante predominante:**
# - **`pod007`**: 61% reporta mal humor/fácil irritabilidad (vs 42% global) → **+19pp**
# - **`pmd021`**: 18% ha hablado seriamente sobre suicidarse (vs 7% global) → **+11pp**
#
# ##### **Comportamientos externalizantes leves:**
# - **`pod010`**: 24% ha hecho cosas malas a personas a propósito (vs 9% global) → **+15pp**
# - **`pcd021`**: 18% ha dañado propiedades ajenas intencionalmente (vs 8% global) → **+10pp**
#
# #### Síntesis interpretativa:
#
# La **Clase 2** representa un **perfil predominantemente internalizante con externalización leve** que se caracteriza por:
#
# 1. **Alta irritabilidad y mal humor** como síntoma principal
# 2. **Ideación suicida** en una proporción significativa
# 3. **Comportamientos agresivos indirectos o pasivos** (hacer cosas malas a propósito, dañar propiedades)
# 4. **Ausencia de consumo de sustancias o conducta antisocial grave**
#
# Este patrón sugiere un **subgrupo con afectación emocional y regulación deficiente del afecto**, que podría corresponder a:
# - **Problemas del estado de ánimo** (depresión, distimia) con irritabilidad
# - **Trastornos de adaptación** con componentes mixtos de ansiedad y depresión
# - **Dificultades en el manejo de la ira** y expresión emocional
#
# **Intervenciones recomendadas:**
# 1. **Evaluación del riesgo suicida** y seguimiento adecuado
# 2. **Terapia para regulación emocional** (terapia dialéctica-conductual, terapia cognitivo-conductual)
# 3. **Entrenamiento en habilidades de comunicación y manejo de la ira**
# 4. **Psicoeducación sobre salud mental y estrategias de afrontamiento**
# 5. **Fomento de actividades prosociales** para redirigir la energía negativa
#
# ### Clase 3 (k = 5)
#  101 observaciones (6.5%)
#
#   ---
#   Variables distintivas:
#
#      1. psz011:
#         SOBRE 1: 'SI' - 47% (47/101) vs 4% (64/1558) global, +42pp
#         SUB 1: 'NO' - 51% (52/101) vs 96% (1490/1558) global, -44pp
#
#      2. pal001:
#         SOBRE 1: 'SI' - 62% (63/101) vs 25% (382/1558) global, +38pp
#         SUB 1: 'NO' - 38% (38/101) vs 75% (1173/1558) global, -38pp
#
#      3. pmd008:
#         SOBRE 1: 'SI' - 68% (69/101) vs 34% (531/1558) global, +34pp
#         SUB 1: 'NO' - 31% (31/101) vs 66% (1025/1558) global, -35pp
#
#      4. pmd012:
#         SOBRE 1: 'SI' - 58% (59/101) vs 28% (437/1558) global, +30pp
#         SUB 1: 'NO' - 41% (41/101) vs 72% (1119/1558) global, -31pp
#
#      5. pni001:
#         SOBRE 1: 'SI' - 50% (51/101) vs 20% (313/1558) global, +30pp
#         SUB 1: 'NO' - 49% (49/101) vs 80% (1240/1558) global, -31pp
#
#      6. pmd009:
#         SOBRE 1: 'SI' - 52% (53/101) vs 27% (415/1558) global, +26pp
#         SUB 1: 'NO' - 47% (47/101) vs 73% (1141/1558) global, -27pp
#
#      7. pcd027:
#         SOBRE 1: 'SI' - 41% (41/101) vs 15% (233/1558) global, +26pp
#         SUB 1: 'NO' - 59% (60/101) vs 85% (1322/1558) global, -25pp
#
#      8. pcd014:
#         SOBRE 1: 'SI' - 38% (38/101) vs 14% (222/1558) global, +23pp
#         SUB 1: 'NO' - 62% (63/101) vs 85% (1332/1558) global, -23pp
#
#      9. pmd021:
#         SOBRE 1: 'SI' - 28% (28/101) vs 7% (105/1558) global, +21pp
#         SUB 1: 'NO' - 70% (71/101) vs 93% (1449/1558) global, -23pp
#
#     10. pcd012:
#         SOBRE 1: 'SI' - 31% (31/101) vs 10% (151/1558) global, +21pp
#         SUB 1: 'NO' - 69% (70/101) vs 90% (1404/1558) global, -21pp
#
#     11. pod007:
#         SOBRE 1: 'SI' - 62% (63/101) vs 42% (656/1558) global, +20pp
#         SUB 1: 'NO' - 38% (38/101) vs 58% (900/1558) global, -20pp
#
#     12. psz014:
#         SOBRE 1: 'SI' - 20% (20/101) vs 2% (25/1558) global, +18pp
#         SUB 1: 'NO' - 78% (79/101) vs 98% (1529/1558) global, -20pp
#
#     13. pcd015:
#         SOBRE 1: 'SI' - 27% (27/101) vs 9% (142/1558) global, +18pp
#         SUB 1: 'NO' - 73% (74/101) vs 91% (1413/1558) global, -17pp
#
#     14. pmj001:
#         SOBRE 1: 'SI' - 22% (22/101) vs 6% (99/1558) global, +15pp
#         SUB 1: 'NO' - 78% (79/101) vs 93% (1456/1558) global, -15pp
#
#     15. pcd003:
#         SOBRE 1: 'SI' - 22% (22/101) vs 7% (110/1558) global, +15pp
#         SUB 1: 'NO' - 78% (79/101) vs 93% (1445/1558) global, -15pp
#
#     16. pod010:
#         SOBRE 1: 'SI' - 20% (20/101) vs 9% (134/1558) global, +11pp
#         SUB 1: 'NO' - 79% (80/101) vs 91% (1420/1558) global, -12pp
#
#     17. pcd021:
#         SOBRE 1: 'SI' - 19% (19/101) vs 8% (120/1558) global, +11pp
#         SUB 1: 'NO' - 81% (82/101) vs 92% (1434/1558) global, -11pp
#
# #### Perfil general:
# La **Clase 3** representa un subgrupo de tamaño moderado (n=101, 6.5% de la muestra) que exhibe un **perfil mixto con síntomas psicóticos prominentes, alteraciones del estado de ánimo y consumo de sustancias**, caracterizado por la presencia de ideación paranoide junto con sintomatología depresiva y conductas externalizantes moderadas.
#
# #### Hallazgos principales:
#
# ##### **Experiencias psicóticas significativas:**
# - **`psz011`**: 47% cree que conspiran en su contra/tratan de lastimarlo (vs 4% global) → **+42pp**
# - **`psz014`**: 20% se siente bajo control externo (vs 2% global) → **+18pp**
#
# ##### **Sintomatología internalizante severa:**
# - **`pmd008`**: 68% tiene problemas de sueño (vs 34% global) → **+34pp**
# - **`pmd012`**: 58% reporta menos energía (vs 28% global) → **+30pp**
# - **`pmd009`**: 52% duerme más durante el día (vs 27% global) → **+26pp**
# - **`pmd021`**: 28% ha hablado seriamente de suicidarse (vs 7% global) → **+21pp**
# - **`pod007`**: 62% reporta mal humor/irritabilidad (vs 42% global) → **+20pp**
#
# ##### **Consumo de sustancias elevado:**
# - **`pal001`**: 62% ha consumido alcohol (vs 25% global) → **+38pp**
# - **`pni001`**: 50% ha fumado cigarrillos (vs 20% global) → **+30pp**
# - **`pmj001`**: 22% ha usado marihuana (vs 6% global) → **+15pp**
#
# ##### **Conducta externalizante moderada:**
# - **`pcd027`**: 41% ha estado en peleas físicas con lesiones (vs 15% global) → **+26pp**
# - **`pcd012`**: 31% tuvo problemas por llegar tarde (vs 10% global) → **+21pp**
# - **`pcd014`**: 38% ha mentido para obtener dinero (vs 14% global) → **+23pp**
# - **`pcd015`**: 27% ha mentido para evitar responsabilidades (vs 9% global) → **+18pp**
# - **`pod010`**: 20% ha hecho cosas malas a propósito (vs 9% global) → **+11pp**
# - **`pcd021`**: 19% ha dañado propiedades ajenas (vs 8% global) → **+11pp**
# - **`pcd003`**: 22% ha robado a alguien (vs 7% global) → **+15pp**
#
# #### Variables más distintivas (diferencias >30pp):
#
# | Variable | Descripción | % Clase 3 | % Global | Diferencia |
# |----------|-------------|-----------|----------|------------|
# | **psz011** | Creer que conspiran contra uno | 47% | 4% | **+42pp** |
# | **pal001** | Consumo de alcohol | 62% | 25% | **+38pp** |
# | **pmd008** | Problemas de sueño | 68% | 34% | **+34pp** |
# | **pmd012** | Menos energía | 58% | 28% | **+30pp** |
# | **pni001** | Tabaquismo | 50% | 20% | **+30pp** |
#
# #### Síntesis interpretativa:
#
# La **Clase 3** representa un **perfil con síntomas psicóticos y afectivos** que se caracteriza por:
#
# 1. **Ideación paranoide significativa** como síntoma psicótico principal
# 2. **Sintomatología depresiva severa** con alteraciones del sueño, energía e ideación suicida
# 3. **Consumo de sustancias** (alcohol, tabaco, marihuana) por encima de la media
# 4. **Comportamientos externalizantes moderados** (agresión física, mentiras, robos)
# 5. **Alta irritabilidad y mal humor**
#
# Este patrón sugiere un **subgrupo con posible trastorno psicótico incipiente o trastorno del estado de ánimo con características psicóticas**, que podría corresponder a:
# - **Trastorno depresivo mayor con síntomas psicóticos**
# - **Trastorno de ansiedad con ideación paranoide**
# - **Fase prodrómica de un trastorno psicótico**
# - **Trastorno por uso de sustancias con síntomas psicóticos inducidos**
#
# **Intervenciones recomendadas:**
# 1. **Manejo de la ideación suicida** y seguimiento de seguridad
# 2. **Tratamiento farmacológico** para síntomas psicóticos y depresivos
# 3. **Intervenciones en el consumo de sustancias** (puede exacerbar síntomas psicóticos)
#
# ### Clase 4 (k = 5)
#  924 observaciones (59.3%)
#
#   ---
#   Variables distintivas:
#
#      1. pal001:
#         SOBRE 1: 'NO' - 89% (820/924) vs 75% (1173/1558) global, +13pp
#         SUB 1: 'SI' - 11% (104/924) vs 25% (382/1558) global, -13pp
#
#      2. pni001:
#         SOBRE 1: 'NO' - 92% (852/924) vs 80% (1240/1558) global, +13pp
#         SUB 1: 'SI' - 8% (71/924) vs 20% (313/1558) global, -12pp
#
#      3. pod007:
#         SOBRE 1: 'NO' - 69% (635/924) vs 58% (900/1558) global, +11pp
#         SUB 1: 'SI' - 31% (289/924) vs 42% (656/1558) global, -11pp
#
#      4. pcd027:
#         SOBRE 1: 'NO' - 96% (883/924) vs 85% (1322/1558) global, +11pp
#
# #### Perfil general:
# La **Clase 4** representa el grupo mayoritario y más saludable (n=924, 59.3% de la muestra) que exhibe un **perfil de bajo riesgo y mínima psicopatología**, caracterizado por la notable ausencia de conductas problemáticas y consumo de sustancias en comparación con la población general.
#
# #### Hallazgos principales:
#
# ##### **Consumo de sustancias muy bajo:**
# - **`pal001`**: Solo 11% ha consumido alcohol (vs 25% global) → **-13pp**
# - **`pni001`**: Solo 8% ha fumado cigarrillos (vs 20% global) → **-12pp**
#
# ##### **Sintomatología internalizante reducida:**
# - **`pod007`**: Solo 31% reporta mal humor/irritabilidad (vs 42% global) → **-11pp**
#
# ##### **Conducta externalizante mínima:**
# - **`pcd027`**: Solo ~4% ha estado en peleas físicas con lesiones (vs 15% global) → **-11pp**
#
# #### Variables más distintivas (diferencias >10pp):
#
# | Variable | Descripción | % Clase 4 | % Global | Diferencia |
# |----------|-------------|-----------|----------|------------|
# | **pal001** | Consumo de alcohol | 11% | 25% | **-13pp** |
# | **pni001** | Tabaquismo | 8% | 20% | **-12pp** |
# | **pod007** | Mal humor/irritabilidad | 31% | 42% | **-11pp** |
# | **pcd027** | Peleas físicas con lesiones | ~4% | 15% | **-11pp** |
#
# #### Síntesis interpretativa:
#
# La **Clase 4** representa un **perfil de bajo riesgo** que se caracteriza por:
#
# 1. **Consumo mínimo de sustancias** (alcohol y tabaco muy por debajo del promedio)
# 2. **Baja irritabilidad y mal humor** en comparación con otros grupos
# 3. **Ausencia casi total de conducta violenta** (peleas físicas extremadamente raras)
# 4. **Presencia probable de factores protectores** que mitigan los riesgos observados en otras clases
#
#
# ## Síntesis de Diferenciación de Clases (k=5)
#
# | **Criterio** | **Clase 0 (Máxima Severidad)** | **Clase 1 (Alto Consumo/Externalización)** | **Clase 2 (Internalización Leve)** | **Clase 3 (Psicótico-Afectivo)** | **Clase 4 (Bajo Riesgo)** |
# | :--- | :--- | :--- | :--- | :--- | :--- |
# | **Tamaño de la Clase** | 36 observaciones (2.3%) | 111 observaciones (7.1%) | 386 observaciones (24.8%) | 101 observaciones (6.5%) | 924 observaciones (59.3%) |
# | **Patrón Principal** | **Polimorfismo psicopatológico severo.** Combinación extrema de violencia, criminalidad, policonsumo de sustancias, sintomatología afectiva grave y experiencias psicóticas. | **Policonsumo de sustancias con conducta externalizante.** Uso casi universal de alcohol/tabaco, uso elevado de marihuana, y comportamiento agresivo y transgresor frecuente. | **Sintomatología internalizante con externalización leve.** Predominio de irritabilidad, mal humor e ideación suicida, con conductas agresivas indirectas ocasionales. | **Síntomas psicóticos y afectivos con consumo moderado.** Presencia prominente de ideación paranoide, sintomatología depresiva severa y consumo de sustancias, con externalización moderada. | **Ajuste adaptativo y bajo riesgo.** Notable ausencia de conductas problemáticas y consumo de sustancias.  |
# | **Núcleo del Perfil** | **Tríada de violencia extrema, adicción y desregulación generalizada.** Perfil de máxima severidad que agrupa agresión física grave, delitos diversos, uso de múltiples sustancias, alteraciones del estado de ánimo y rasgos psicóticos. | **Trastorno por uso de sustancias con trastorno de conducta.** El consumo elevado de alcohol, tabaco y marihuana es el núcleo, asociado a un patrón de agresividad física, vandalismo y problemas disciplinarios. | **Trastorno del estado de ánimo con irritabilidad.** El mal humor crónico y la irritabilidad son centrales, acompañados de ideación suicida y expresiones menores de agresión pasiva o indirecta. | **Síndrome psicótico-afectivo mixto.** La ideación paranoide (conspiración) se combina con un cuadro depresivo claro (sueño, energía, suicidio) y consumo de sustancias, generando un perfil clínicamente complejo. | **Ausencia de psicopatología significativa.** Se caracteriza por la **sub-representación** de casi todos los síntomas problemáticos, reflejando un funcionamiento adaptativo y presencia de factores protectores. |
# | **Síntomas más Distintivos (Diferencia >15pp vs. Global)** | 1. **pcd027:** Peleas con lesiones (+60pp)<br>2. **pcd014:** Mentir por dinero (+44pp)<br>3. **pni001:** Tabaquismo (+44pp)<br>4. **pcd012:** Problemas por llegar tarde (+43pp)<br>5. **pcd020:** Vandalismo (+41pp) | 1. **pal001:** Consumo de alcohol (+66pp)<br>2. **pni001:** Tabaquismo (+64pp)<br>3. **pmj001:** Uso de marihuana (+50pp)<br>4. **pcd027:** Peleas con lesiones (+40pp)<br>5. **pcd012:** Problemas por llegar tarde (+34pp) | 1. **pod007:** Irritabilidad/Mal humor (+19pp)<br>2. **pod010:** Hacer cosas malas a propósito (+15pp)<br>3. **pmd021:** Hablar de suicidarse (+11pp)<br>4. **pcd021:** Dañar propiedad (+10pp) | 1. **psz011:** Creer que conspiran contra uno (+42pp)<br>2. **pal001:** Consumo de alcohol (+38pp)<br>3. **pmd008:** Problemas de sueño (+34pp)<br>4. **pmd012:** Menos energía (+30pp)<br>5. **pni001:** Tabaquismo (+30pp) | 1. **pal001:** Bajo consumo de alcohol (-13pp en 'SI')<br>2. **pni001:** Bajo tabaquismo (-12pp en 'SI')<br>3. **pod007:** Baja irritabilidad (-11pp en 'SI')<br>4. **pcd027:** Bajas peleas con lesiones (-11pp en 'SI') |
# | **Riesgo Asociado** | **Muy Alto y Crítico.** Alto riesgo de cronicidad, daño a terceros, encarcelamiento, conducta suicida y deterioro psicosocial severo. Requiere intervención inmediata. | **Alto.** Riesgo de dependencia a sustancias, problemas legales, victimización/perpetración de violencia, y afectación del rendimiento académico/laboral. | **Moderado.** Principalmente riesgo de cronificación de sintomatología depresiva, autolesiones y aislamiento social. La externalización leve puede generar conflictos interpersonales. | **Alto.** Riesgo de evolución hacia un trastorno psicótico completo, conducta suicida, y exacerbación de síntomas por consumo de sustancias. Alta complejidad clínica. | **Muy Bajo.** Representa el perfil de ajuste saludable. El riesgo principal es la transición hacia clases problemáticas sin intervenciones preventivas universales. |
# | **Abordaje Sugerido** | **Intervención especializada, intensiva y multidisciplinaria.** Contención supervisada (ej., residencial), tratamiento integral de adicciones, terapia para control de impulsos/agresión, evaluación psiquiátrica completa e intervenciones legales restaurativas. | **Tratamiento focalizado en adicciones y conducta.** Programas de prevención de recaídas y reducción de daños, entrenamiento en manejo de ira, psicoeducación familiar sobre consumo, y fomento de actividades prosociales. | **Intervención en salud mental centrada en el estado de ánimo.** Evaluación y seguimiento del riesgo suicida, terapia para regulación emocional (ej., TCC, DBT), entrenamiento en habilidades sociales y de comunicación. | **Manejo clínico integral de síntomas psicóticos y afectivos.** Priorizar seguridad (riesgo suicida), tratamiento farmacológico (antipsicóticos/antidepresivos), intervención en consumo de sustancias y psicoterapia de apoyo. | **Prevención universal y promoción de la salud.** Fortalecimiento de factores protectores (ej., habilidades socioemocionales, apoyo familiar), psicoeducación para la detección temprana de problemas y mantenimiento de estilos de vida saludables. |
#
#   ---

# %% [markdown]
# # Clasificación LCA k = 6
#
# ## Variables más discriminatorias:
#
# | Variable | Cramér's V | p-value | χ² | Discriminación |
# |----------|------------|---------|----|----------------|
# | pcd020 | 0.4306 | 1.40e-117 | 577 | 0.993 |
# | pcd012 | 0.4263 | 4.34e-115 | 565 | 0.993 |
# | pmd022 | 0.4188 | 7.48e-111 | 546 | 0.987 |
# | pcd028 | 0.3989 | 4.95e-100 | 495 | 0.993 |
# | pal001 | 0.3887 | 9.80e-95 | 470 | 0.993 |
# | pcd039 | 0.3860 | 2.65e-93 | 464 | 0.993 |
# | psz009 | 0.3856 | 4.08e-93 | 463 | 0.987 |
# | pni001 | 0.3818 | 3.32e-91 | 454 | 0.991 |
# | pcd029 | 0.3788 | 2.98e-46 | 223 | 1.000 |
# | pmj001 | 0.3787 | 1.22e-89 | 446 | 0.993 |
# | pcd027 | 0.3765 | 1.62e-88 | 441 | 0.993 |
# | pcd013 | 0.3653 | 5.50e-83 | 415 | 0.993 |
# | psz013 | 0.3590 | 5.42e-80 | 401 | 0.987 |
# | pod011 | 0.3527 | 5.41e-77 | 387 | 0.987 |
# | psz014 | 0.3488 | 3.42e-75 | 379 | 0.987 |
# | psz010 | 0.3365 | 1.20e-69 | 352 | 0.987 |
# | pod010 | 0.3352 | 4.69e-69 | 350 | 0.987 |
# | pmd021 | 0.3334 | 2.85e-68 | 346 | 0.987 |
# | pmd012 | 0.3311 | 5.61e-35 | 171 | 1.000 |
# | psz011 | 0.3308 | 4.17e-67 | 340 | 0.987 |
# | pmd015 | 0.3250 | 1.30e-64 | 329 | 0.987 |
# | pod003 | 0.3204 | 1.14e-62 | 320 | 0.987 |
# | pcd015 | 0.3168 | 3.68e-61 | 312 | 0.993 |
# | pmd008 | 0.3102 | 1.49e-30 | 150 | 1.000 |
# | psz012 | 0.3100 | 2.43e-58 | 299 | 0.987 |

# %%
variables = ["pcd020","pcd012","pmd022","pcd028","pal001","pcd039","psz009","pni001","pcd029","pmj001","pcd027","pcd013","psz013","pod011","psz014","psz010","pod010","pmd021","pmd012","psz011","pmd015","pod003","pcd015","pmd008","psz012"
]
ut.imprimir_etiquetas(variables, df_etiquetas)
# Out:
# ...
# LISTADO DE ETIQUETAS (25 variables)
# ...
#   1. [pcd020] - Broken something/mes sed up a place on purpose (like breaking windows)
#   2. [pcd012] - Ever gotten into trouble for staying out 2 hours past curfew
#   3. [pmd022] - Ever in whole life made a suicide attempt
#   4. [pcd028] - Ever tried to hurt someone badly/been physically cruel to someone
#   5. [pal001] - Not including sips from other peoples, ever had even one drink
#   6. [pcd039] - Ever been in trouble with the police
#   7. [psz009] - Believe people were spying on you
#   8. [pni001] - Ever smoked a cigarette
#   9. [pcd029] - Ever hurt someone with a weapon (like a bat/brick/knife/g un)
#  10. [pmj001] - Ever in whole life used marijuana
#  11. [pcd027] - Ever been in a physical fight in which someone was hurt/could have been hurt
#  12. [pcd013] - Age when first got into trouble for staying out too late
#  13. [psz013] - Believe you alone were sent special messages through TV/radio
# ...

# %% [markdown]
# # Caracterización de la clasificación LCA con k=6
#
# ## Hallazgos principales:
#
# ### Variables más discriminantes:
# - **`pcd020`** – *"Broken something/messed up a place on purpose (like breaking windows)"*
#     - **Cramér's V = 0.4306** (el más alto)
#     - **p = 1.40e-117**
# - **`pcd012`** – *"Ever gotten into trouble for staying out 2 hours past curfew"*
#     - **Cramér's V = 0.4263** (segundo más alto)
#     - **p = 4.34e-115**
# - **`pmd022`** – *"Ever in whole life made a suicide attempt"*
#     - **Cramér's V = 0.4188** (tercero más alto)
#     - **p = 7.48e-111**
#
# ### Dimensiones temáticas predominantes:
#
# #### **Conducta externalizante y antisocial:**
# - `pcd020` – Vandalismo (romper cosas a propósito)
# - `pcd012` – Problemas por llegar tarde (toque de queda)
# - `pcd028` – Intentar lastimar gravemente a alguien/crueldad física
# - `pcd039` – Problemas con la policía
# - `pcd029` – Herir a alguien con un arma
# - `pcd027` – Participar en peleas físicas con lesiones
# - `pcd015` – Mentir para evitar pagar deudas o responsabilidades
# - `pod011` – Vengarse de personas dañando sus cosas/hiriéndolas
# - `pod010` – Hacer cosas malas a personas a propósito
# - `pod003` – Desobedecer a propósito a los cuidadores
#
# #### **Consumo de sustancias:**
# - `pal001` – Consumo de alcohol
# - `pni001` – Tabaquismo
# - `pmj001` – Uso de marihuana
#
# #### **Experiencias psicóticas o similares:**
# - `psz009` – Creer que lo espiaban
# - `psz013` – Creer que recibía mensajes especiales a través de TV/radio
# - `psz014` – Convencido/a de estar bajo control de algún poder/fuerza
# - `psz010` – Pensamientos de que la gente habla/se ríe de uno
# - `psz011` – Creer que alguien conspiraba contra uno/intentaba hacer daño
# - `psz012` – Convencido de que se le introdujeron pensamientos extraños
#
# #### **Sintomatología internalizante y afectiva:**
# - `pmd022` – Intentos de suicidio
# - `pmd021` – Hablar seriamente de suicidarse
# - `pmd015` – Autorreproches por eventos pasados
# - `pmd012` – Falta de energía
# - `pmd008` – Problemas de sueño
#
# #### **Otros comportamientos de riesgo:**
# - `pcd013` – Edad temprana de problemas por llegar tarde

# %% [markdown]
# ### Clase 0 (k = 6)
#
# 216 observaciones (13.9%)
#
#   ---
#   Variables distintivas:
#
#      1. psz010:
#         SOBRE 1: 'SI' - 49% (106/216) vs 21% (321/1558) global, +28pp
#         SUB 1: 'NO' - 51% (110/216) vs 79% (1233/1558) global, -28pp
#
#      2. pmd015:
#         SOBRE 1: 'SI' - 51% (111/216) vs 25% (383/1558) global, +27pp
#         SUB 1: 'NO' - 49% (105/216) vs 75% (1171/1558) global, -27pp
#
#      3. pmd008:
#         SOBRE 1: 'SI' - 60% (129/216) vs 34% (531/1558) global, +26pp
#         SUB 1: 'NO' - 40% (87/216) vs 66% (1025/1558) global, -26pp
#
#      4. psz009:
#         SOBRE 1: 'SI' - 37% (80/216) vs 12% (181/1558) global, +25pp
#         SUB 1: 'NO' - 63% (136/216) vs 88% (1373/1558) global, -25pp
#
#      5. pal001:
#         SOBRE 1: 'SI' - 49% (106/216) vs 25% (382/1558) global, +25pp
#         SUB 1: 'NO' - 51% (110/216) vs 75% (1173/1558) global, -24pp
#
#      6. pmd012:
#         SOBRE 1: 'SI' - 51% (111/216) vs 28% (437/1558) global, +23pp
#         SUB 1: 'NO' - 49% (105/216) vs 72% (1119/1558) global, -23pp
#
#      7. pcd012:
#         SOBRE 1: 'SI' - 31% (68/216) vs 10% (151/1558) global, +22pp
#         SUB 1: 'NO' - 69% (148/216) vs 90% (1404/1558) global, -22pp
#
#      8. pmd022:
#         SOBRE 1: 'SI' - 26% (57/216) vs 6% (92/1558) global, +20pp
#         SUB 1: 'NO' - 74% (159/216) vs 94% (1462/1558) global, -20pp
#
#      9. pni001:
#         SOBRE 1: 'SI' - 39% (85/216) vs 20% (313/1558) global, +19pp
#         SUB 1: 'NO' - 61% (131/216) vs 80% (1240/1558) global, -19pp
#
#     10. psz011:
#         SOBRE 1: 'SI' - 19% (42/216) vs 4% (64/1558) global, +15pp
#         SUB 1: 'NO' - 81% (174/216) vs 96% (1490/1558) global, -15pp
#
#     11. pmd021:
#         SOBRE 1: 'SI' - 21% (45/216) vs 7% (105/1558) global, +14pp
#         SUB 1: 'NO' - 79% (171/216) vs 93% (1449/1558) global, -14pp
#
#     12. pcd015:
#         SOBRE 1: 'SI' - 20% (44/216) vs 9% (142/1558) global, +11pp
#         SUB 1: 'NO' - 80% (172/216) vs 91% (1413/1558) global, -11pp
#
#     13. pod003:
#         SOBRE 1: 'SI' - 40% (87/216) vs 29% (457/1558) global, +11pp
#         SUB 1: 'NO' - 60% (129/216) vs 70% (1097/1558) global, -11pp
#
# ### Clase 1 (k = 6)
# 64 observaciones (4.1%)
#
#   ---
#   Variables distintivas:
#
#      1. pni001:
#         SOBRE 1: 'SI' - 69% (44/64) vs 20% (313/1558) global, +49pp
#         SUB 1: 'NO' - 30% (19/64) vs 80% (1240/1558) global, -50pp
#
#      2. pal001:
#         SOBRE 1: 'SI' - 72% (46/64) vs 25% (382/1558) global, +47pp
#         SUB 1: 'NO' - 28% (18/64) vs 75% (1173/1558) global, -47pp
#
#      3. pcd027:
#         SOBRE 1: 'SI' - 55% (35/64) vs 15% (233/1558) global, +40pp
#         SUB 1: 'NO' - 45% (29/64) vs 85% (1322/1558) global, -40pp
#
#      4. psz010:
#         SOBRE 1: 'SI' - 56% (36/64) vs 21% (321/1558) global, +36pp
#         SUB 1: 'NO' - 44% (28/64) vs 79% (1233/1558) global, -35pp
#
#      5. psz009:
#         SOBRE 1: 'SI' - 47% (30/64) vs 12% (181/1558) global, +35pp
#         SUB 1: 'NO' - 53% (34/64) vs 88% (1373/1558) global, -35pp
#
#      6. pmd015:
#         SOBRE 1: 'SI' - 56% (36/64) vs 25% (383/1558) global, +32pp
#         SUB 1: 'NO' - 44% (28/64) vs 75% (1171/1558) global, -31pp
#
#      7. pmd022:
#         SOBRE 1: 'SI' - 38% (24/64) vs 6% (92/1558) global, +32pp
#         SUB 1: 'NO' - 62% (40/64) vs 94% (1462/1558) global, -31pp
#
#      8. pcd020:
#         SOBRE 1: 'SI' - 34% (22/64) vs 6% (94/1558) global, +28pp
#         SUB 1: 'NO' - 66% (42/64) vs 94% (1461/1558) global, -28pp
#
#      9. pmd012:
#         SOBRE 1: 'SI' - 55% (35/64) vs 28% (437/1558) global, +27pp
#         SUB 1: 'NO' - 45% (29/64) vs 72% (1119/1558) global, -27pp
#
#     10. pcd012:
#         SOBRE 1: 'SI' - 36% (23/64) vs 10% (151/1558) global, +26pp
#         SUB 1: 'NO' - 64% (41/64) vs 90% (1404/1558) global, -26pp
#
#     11. pcd013:
#         SOBRE 1: 'SI' - 27% (17/64) vs 3% (47/1558) global, +24pp
#         SUB 1: 'NO' - 73% (47/64) vs 97% (1508/1558) global, -23pp
#
#     12. pmd021:
#         SOBRE 1: 'SI' - 30% (19/64) vs 7% (105/1558) global, +23pp
#         SUB 1: 'NO' - 70% (45/64) vs 93% (1449/1558) global, -23pp
#
#     13. pmd008:
#         SOBRE 1: 'SI' - 56% (36/64) vs 34% (531/1558) global, +22pp
#         SUB 1: 'NO' - 44% (28/64) vs 66% (1025/1558) global, -22pp
#
#     14. pmj001:
#         SOBRE 1: 'SI' - 28% (18/64) vs 6% (99/1558) global, +22pp
#         SUB 1: 'NO' - 72% (46/64) vs 93% (1456/1558) global, -22pp
#
#     15. pod003:
#         SOBRE 1: 'SI' - 50% (32/64) vs 29% (457/1558) global, +21pp
#         SUB 1: 'NO' - 50% (32/64) vs 70% (1097/1558) global, -20pp
#
#     16. psz013:
#         SOBRE 1: 'SI' - 20% (13/64) vs 1% (15/1558) global, +19pp
#         SUB 1: 'NO' - 80% (51/64) vs 99% (1539/1558) global, -19pp
#
#     17. pcd015:
#         SOBRE 1: 'SI' - 28% (18/64) vs 9% (142/1558) global, +19pp
#         SUB 1: 'NO' - 72% (46/64) vs 91% (1413/1558) global, -19pp
#
#     18. pcd039:
#         SOBRE 1: 'SI' - 22% (14/64) vs 3% (52/1558) global, +19pp
#         SUB 1: 'NO' - 78% (50/64) vs 96% (1503/1558) global, -18pp
#
#     19. pcd028:
#         SOBRE 1: 'SI' - 19% (12/64) vs 3% (53/1558) global, +15pp
#         SUB 1: 'NO' - 81% (52/64) vs 96% (1502/1558) global, -15pp
#
#     20. pod010:
#         SOBRE 1: 'SI' - 22% (14/64) vs 9% (134/1558) global, +13pp
#         SUB 1: 'NO' - 78% (50/64) vs 91% (1420/1558) global, -13pp
#
#     21. psz012:
#         SOBRE 1: 'SI' - 17% (11/64) vs 4% (61/1558) global, +13pp
#         SUB 1: 'NO' - 83% (53/64) vs 96% (1493/1558) global, -13pp
#
# #### Perfil general:
# La **Clase 1** (n=216, 13.9% de la muestra) representa un subgrupo con un **perfil clínico moderado-alto**, caracterizado por una combinación de sintomatología internalizante, experiencias psicóticas leves y consumo de sustancias. A diferencia de perfiles más graves, muestra menos conducta externalizante severa pero mayor afectación emocional.
#
# #### Hallazgos principales:
#
# ##### **Alta prevalencia de sintomatología internalizante y afectiva:**
# - **`pmd008`**: 60% reporta problemas de sueño (vs 34% global) → **+26pp**
# - **`pmd015`**: 51% se autorreprocha por eventos pasados (vs 25% global) → **+27pp**
# - **`pmd012`**: 51% tiene menos energía (vs 28% global) → **+23pp**
# - **`pmd022`**: 26% ha intentado suicidio (vs 6% global) → **+20pp**
# - **`pmd021`**: 21% ha hablado seriamente de suicidarse (vs 7% global) → **+14pp**
#
# ##### **Experiencias psicóticas o similares a psicosis:**
# - **`psz010`**: 49% tiene pensamientos de que la gente habla/se ríe de él/ella (vs 21% global) → **+28pp**
# - **`psz009`**: 37% cree que lo espiaban (vs 12% global) → **+25pp**
# - **`psz011`**: 19% cree que alguien conspiraba contra él/ella (vs 4% global) → **+15pp**
#
# ##### **Consumo de sustancias:**
# - **`pal001`**: 49% ha consumido alcohol (vs 25% global) → **+25pp**
# - **`pni001`**: 39% ha fumado cigarrillos (vs 20% global) → **+19pp**
#
# ##### **Problemas conductuales y de cumplimiento:**
# - **`pcd012`**: 31% tuvo problemas por llegar tarde (toque de queda) (vs 10% global) → **+22pp**
# - **`pod003`**: 40% desobedeció a propósito a cuidadores (vs 29% global) → **+11pp**
# - **`pcd015`**: 20% mintió para evitar pagar deudas/responsabilidades (vs 9% global) → **+11pp**
#
# #### Variables más distintivas (diferencias >20pp):
#
# | Variable | Descripción | % Clase 1 | % Global | Diferencia |
# |----------|-------------|-----------|----------|------------|
# | **pmd015** | Autorreproches por eventos pasados | 51% | 25% | **+27pp** |
# | **pmd008** | Problemas de sueño | 60% | 34% | **+26pp** |
# | **pal001** | Consumo de alcohol | 49% | 25% | **+25pp** |
# | **psz009** | Creencia de ser espiado | 37% | 12% | **+25pp** |
# | **pmd012** | Falta de energía | 51% | 28% | **+23pp** |
# | **pcd012** | Problemas por toque de queda | 31% | 10% | **+22pp** |
#
# #### Síntesis interpretativa:
#
# La **Clase 1** representa un **perfil mixto con predominio internalizante** que combina:
#
# 1. **Sintomatología afectiva significativa**: problemas de sueño, falta de energía, autorreproches
# 2. **Riesgo suicida moderado**: intentos e ideación suicida
# 3. **Experiencias psicóticas leves**: principalmente ideas de referencia y paranoia
# 4. **Consumo de sustancias**: alcohol y tabaco
# 5. **Problemas conductuales menores**: desobediencia, problemas de cumplimiento
#
# Este patrón sugiere un **subgrupo con distress psicológico significativo** que podría beneficiarse de:
# - Intervenciones para síntomas depresivos y ansiosos
# - Evaluación y seguimiento del riesgo suicida
# - Psicoeducación sobre consumo de alcohol
# - Estrategias para mejorar la regulación emocional
# - Apoyo en habilidades de afrontamiento
#
# ### Clase 2 (k = 6)
# 886 observaciones (56.9%)
#
#   ---
#   Variables distintivas:
#
#      1. pod003:
#         SOBRE 1: 'NO' - 84% (747/886) vs 70% (1097/1558) global, +14pp
#         SUB 1: 'SI' - 16% (139/886) vs 29% (457/1558) global, -14pp
#
#      2. pal001:
#         SOBRE 1: 'NO' - 89% (789/886) vs 75% (1173/1558) global, +14pp
#         SUB 1: 'SI' - 11% (97/886) vs 25% (382/1558) global, -14pp
#
#      3. pni001:
#         SOBRE 1: 'NO' - 93% (821/886) vs 80% (1240/1558) global, +13pp
#         SUB 1: 'SI' - 7% (64/886) vs 20% (313/1558) global, -13pp
#
#      4. psz010:
#         SOBRE 1: 'NO' - 90% (798/886) vs 79% (1233/1558) global, +11pp
#         SUB 1: 'SI' - 10% (88/886) vs 21% (321/1558) global, -11pp
#
#      5. pmd012:
#         SOBRE 1: 'NO' - 83% (731/886) vs 72% (1119/1558) global, +11pp
#         SUB 1: 'SI' - 17% (155/886) vs 28% (437/1558) global, -11pp
#
#      6. pcd027:
#         SOBRE 1: 'NO' - 95% (846/886) vs 85% (1322/1558) global, +11pp
#
#      7. pmd008:
#         SOBRE 1: 'NO' - 76% (673/886) vs 66% (1025/1558) global, +10pp
#         SUB 1: 'SI' - 24% (213/886) vs 34% (531/1558) global, -10pp
#
#      8. pmd015:
#         SOBRE 1: 'NO' - 85% (755/886) vs 75% (1171/1558) global, +10pp
#
# #### Perfil general:
# La **Clase 2** representa el grupo más numeroso (n=886, 56.9% de la muestra) y constituye un **perfil de bajo riesgo o normativo**, caracterizado por la ausencia o baja frecuencia de problemas psicológicos, conductuales y de consumo de sustancias en comparación con la muestra total.
#
# #### Hallazgos principales:
#
# ##### **Baja prevalencia de problemas de conducta y cumplimiento:**
# - **`pod003`**: 84% NO desobedeció a propósito a cuidadores (vs 70% global) → **+14pp**
# - **`pcd027`**: 95% NO participó en peleas físicas con lesiones (vs 85% global) → **+11pp**
#
# ##### **Bajo consumo de sustancias:**
# - **`pal001`**: 89% NO ha consumido alcohol (vs 75% global) → **+14pp**
# - **`pni001`**: 93% NO ha fumado cigarrillos (vs 80% global) → **+13pp**
#
# ##### **Baja sintomatología internalizante:**
# - **`pmd015`**: 85% NO se autorreprocha por eventos pasados (vs 75% global) → **+10pp**
# - **`pmd012`**: 83% NO tiene menos energía (vs 72% global) → **+11pp**
# - **`pmd008`**: 76% NO tiene problemas de sueño (vs 66% global) → **+10pp**
#
# ##### **Ausencia de experiencias psicóticas:**
# - **`psz010`**: 90% NO tiene pensamientos de que la gente habla/se ríe de él/ella (vs 79% global) → **+11pp**
#
# #### Variables más distintivas (diferencias >10pp):
#
# | Variable | Descripción | % Clase 2 (NO) | % Global (NO) | Diferencia |
# |----------|-------------|----------------|---------------|------------|
# | **pod003** | No desobedecer a cuidadores | 84% | 70% | **+14pp** |
# | **pal001** | No consumo de alcohol | 89% | 75% | **+14pp** |
# | **pni001** | No tabaquismo | 93% | 80% | **+13pp** |
# | **psz010** | No pensamientos de que se ríen | 90% | 79% | **+11pp** |
# | **pmd012** | No falta de energía | 83% | 72% | **+11pp** |
# | **pcd027** | No peleas físicas con lesiones | 95% | 85% | **+11pp** |
#
# #### Síntesis interpretativa:
#
# La **Clase 2** representa un **perfil normativo o de bajo riesgo** que se caracteriza por:
#
# 1. **Buen comportamiento y cumplimiento**: menor desobediencia y casi nula participación en peleas físicas
# 2. **Bajo consumo de sustancias**: mínimo uso de alcohol y tabaco
# 3. **Baja sintomatología internalizante**: menos problemas de sueño, falta de energía y autorreproches
# 4. **Ausencia de experiencias psicóticas**: muy pocos pensamientos de referencia o paranoia
#
#
# ### Clase 3 (k = 6)
# 27 observaciones (1.7%)
#
#   ---
#   Variables distintivas:
#
#      1. pal001:
#         SOBRE 1: 'SI' - 74% (20/27) vs 25% (382/1558) global, +50pp
#         SUB 1: 'NO' - 15% (4/27) vs 75% (1173/1558) global, -60pp
#
#      2. pmd015:
#         SOBRE 1: 'SI' - 70% (19/27) vs 25% (383/1558) global, +46pp
#         SUB 1: 'NO' - 15% (4/27) vs 75% (1171/1558) global, -60pp
#
#      3. pni001:
#         SOBRE 1: 'SI' - 67% (18/27) vs 20% (313/1558) global, +47pp
#         SUB 1: 'NO' - 22% (6/27) vs 80% (1240/1558) global, -57pp
#
#      4. psz009:
#         SOBRE 1: 'SI' - 52% (14/27) vs 12% (181/1558) global, +40pp
#         SUB 1: 'NO' - 33% (9/27) vs 88% (1373/1558) global, -55pp
#
#      5. pmd008:
#         SOBRE 1: 'SI' - 81% (22/27) vs 34% (531/1558) global, +47pp
#         SUB 1: 'NO' - 11% (3/27) vs 66% (1025/1558) global, -55pp
#
#      6. pmd012:
#         SOBRE 1: 'SI' - 74% (20/27) vs 28% (437/1558) global, +46pp
#         SUB 1: 'NO' - 19% (5/27) vs 72% (1119/1558) global, -53pp
#
#      7. pmd022:
#         SOBRE 1: 'SI' - 41% (11/27) vs 6% (92/1558) global, +35pp
#         SUB 1: 'NO' - 44% (12/27) vs 94% (1462/1558) global, -49pp
#
#      8. pcd027:
#         SOBRE 1: 'SI' - 52% (14/27) vs 15% (233/1558) global, +37pp
#         SUB 1: 'NO' - 37% (10/27) vs 85% (1322/1558) global, -48pp
#
#      9. psz014:
#         SOBRE 1: 'SI' - 33% (9/27) vs 2% (25/1558) global, +32pp
#         SUB 1: 'NO' - 52% (14/27) vs 98% (1529/1558) global, -46pp
#
#     10. psz012:
#         SOBRE 1: 'SI' - 33% (9/27) vs 4% (61/1558) global, +29pp
#         SUB 1: 'NO' - 52% (14/27) vs 96% (1493/1558) global, -44pp
#
#     11. pcd012:
#         SOBRE 1: 'SI' - 41% (11/27) vs 10% (151/1558) global, +31pp
#         SUB 1: 'NO' - 48% (13/27) vs 90% (1404/1558) global, -42pp
#
#     12. pcd020:
#         SOBRE 1: 'SI' - 33% (9/27) vs 6% (94/1558) global, +27pp
#         SUB 1: 'NO' - 56% (15/27) vs 94% (1461/1558) global, -38pp
#
#     13. pmj001:
#         SOBRE 1: 'SI' - 33% (9/27) vs 6% (99/1558) global, +27pp
#         SUB 1: 'NO' - 56% (15/27) vs 93% (1456/1558) global, -38pp
#
#     14. pcd039:
#         SOBRE 1: 'SI' - 30% (8/27) vs 3% (52/1558) global, +26pp
#         SUB 1: 'NO' - 59% (16/27) vs 96% (1503/1558) global, -37pp
#
#     15. psz010:
#         SOBRE 1: 'SI' - 41% (11/27) vs 21% (321/1558) global, +20pp
#         SUB 1: 'NO' - 44% (12/27) vs 79% (1233/1558) global, -35pp
#
#     16. pmd021:
#         SOBRE 1: 'SI' - 26% (7/27) vs 7% (105/1558) global, +19pp
#         SUB 1: 'NO' - 59% (16/27) vs 93% (1449/1558) global, -34pp
#
#     17. psz011:
#         SOBRE 1: 'SI' - 22% (6/27) vs 4% (64/1558) global, +18pp
#         SUB 1: 'NO' - 63% (17/27) vs 96% (1490/1558) global, -33pp
#
#     18. pcd013:
#         SOBRE 1: 'SI' - 22% (6/27) vs 3% (47/1558) global, +19pp
#         SUB 1: 'NO' - 67% (18/27) vs 97% (1508/1558) global, -30pp
#
#     19. pcd028:
#         SOBRE 1: 'SI' - 22% (6/27) vs 3% (53/1558) global, +19pp
#         SUB 1: 'NO' - 67% (18/27) vs 96% (1502/1558) global, -30pp
#
#     20. pcd029:
#         SOBRE 1: 'SI' - 22% (6/27) vs 2% (27/1558) global, +20pp
#         SUB 1: 'NO' - 70% (19/27) vs 98% (1529/1558) global, -28pp
#
#     21. pod003:
#         SUB 1: 'NO' - 48% (13/27) vs 70% (1097/1558) global, -22pp
#
#     22. psz013:
#         SUB 1: 'NO' - 78% (21/27) vs 99% (1539/1558) global, -21pp
#
#     23. pod010:
#         SUB 1: 'NO' - 74% (20/27) vs 91% (1420/1558) global, -17pp
#
#     24. pod011:
#         SUB 1: 'NO' - 74% (20/27) vs 91% (1415/1558) global, -17pp
#
#     25. pcd015:
#         SUB 1: 'NO' - 74% (20/27) vs 91% (1413/1558) global, -17pp
#
# #### Perfil general:
# La **Clase 3** representa un subgrupo muy pequeño pero clínicamente crítico (n=27, 1.7% de la muestra) que muestra un **perfil de extrema severidad psicopatológica**, caracterizado por la co-ocurrencia de múltiples problemas graves en prácticamente todas las dimensiones evaluadas.
#
# #### Hallazgos principales:
#
# ##### **Consumo de sustancias extremadamente elevado:**
# - **`pal001`**: 74% ha consumido alcohol (vs 25% global) → **+50pp**
# - **`pni001`**: 67% ha fumado cigarrillos (vs 20% global) → **+47pp**
# - **`pmj001`**: 33% ha usado marihuana (vs 6% global) → **+27pp**
#
# ##### **Sintomatología internalizante y depresiva severa:**
# - **`pmd008`**: 81% tiene problemas de sueño (vs 34% global) → **+47pp**
# - **`pmd012`**: 74% tiene menos energía (vs 28% global) → **+46pp**
# - **`pmd015`**: 70% se autorreprocha por eventos pasados (vs 25% global) → **+46pp**
# - **`pmd022`**: 41% ha intentado suicidio (vs 6% global) → **+35pp**
# - **`pmd021`**: 26% ha hablado seriamente de suicidarse (vs 7% global) → **+19pp**
#
# ##### **Experiencias psicóticas graves:**
# - **`psz009`**: 52% cree que lo espiaban (vs 12% global) → **+40pp**
# - **`psz014`**: 33% se siente bajo control de algún poder (vs 2% global) → **+32pp**
# - **`psz012`**: 33% cree que se le insertaron pensamientos extraños (vs 4% global) → **+29pp**
# - **`psz011`**: 22% cree que alguien conspiraba contra él/ella (vs 4% global) → **+18pp**
# - **`psz013`**: 22% cree que recibía mensajes especiales (vs 1% global) → **+21pp** (de subrepresentación de "NO")
#
# ##### **Conducta externalizante y antisocial severa:**
# - **`pcd027`**: 52% participó en peleas físicas con lesiones (vs 15% global) → **+37pp**
# - **`pcd012`**: 41% tuvo problemas por llegar tarde (vs 10% global) → **+31pp**
# - **`pcd020`**: 33% cometió vandalismo (vs 6% global) → **+27pp**
# - **`pcd029`**: 22% hirió a alguien con un arma (vs 2% global) → **+20pp**
# - **`pcd028`**: 22% intentó lastimar gravemente a alguien (vs 3% global) → **+19pp**
# - **`pcd039`**: 30% tuvo problemas con la policía (vs 3% global) → **+26pp**
#
# #### Variables más distintivas (diferencias >40pp):
#
# | Variable | Descripción | % Clase 3 | % Global | Diferencia |
# |----------|-------------|-----------|----------|------------|
# | **pal001** | Consumo de alcohol | 74% | 25% | **+50pp** |
# | **pmd008** | Problemas de sueño | 81% | 34% | **+47pp** |
# | **pni001** | Tabaquismo | 67% | 20% | **+47pp** |
# | **pmd015** | Autorreproches | 70% | 25% | **+46pp** |
# | **pmd012** | Falta de energía | 74% | 28% | **+46pp** |
# | **psz009** | Creencia de ser espiado | 52% | 12% | **+40pp** |
#
# #### Síntesis interpretativa:
#
# La **Clase 3** representa un **perfil de comorbilidad extrema y complejidad clínica** que combina:
#
# 1. **Sintomatología psicótica grave**: múltiples delirios y experiencias inusuales
# 2. **Depresión severa con alto riesgo suicida**: intentos e ideación suicida marcada
# 3. **Abuso de sustancias múltiple**: alcohol, tabaco y marihuana
# 4. **Conducta violenta y antisocial**: desde vandalismo hasta uso de armas
# 5. **Problemas regulatorios severos**: insomnio, falta de energía, autorreproches
#
# Este patrón sugiere un **subgrupo de máxima urgencia clínica** que probablemente requiere:
# - Hospitalización o tratamiento residencial intensivo
# - Tratamiento integrado para psicosis y abuso de sustancias
# - Manejo agresivo del riesgo suicida
# - Intervenciones para control de impulsos y agresión
# - Rehabilitación psicosocial prolongada
#
# ### Clase 4 (k = 6)
#   266 observaciones (17.1%)
#
#   ---
#   Variables distintivas:
#
#      1. pod011:
#         SOBRE 1: 'SI' - 31% (83/266) vs 9% (139/1558) global, +22pp
#         SUB 1: 'NO' - 69% (183/266) vs 91% (1415/1558) global, -22pp
#
#      2. pod003:
#         SOBRE 1: 'SI' - 50% (134/266) vs 29% (457/1558) global, +21pp
#         SUB 1: 'NO' - 50% (132/266) vs 70% (1097/1558) global, -21pp
#
#      3. pod010:
#         SOBRE 1: 'SI' - 24% (63/266) vs 9% (134/1558) global, +15pp
#         SUB 1: 'NO' - 76% (203/266) vs 91% (1420/1558) global, -15pp
#
#      4. psz009:
#         SOBRE 1: 'NO' - 100% (266/266) vs 88% (1373/1558) global, +12pp
#
# #### Perfil general:
# La **Clase 4** representa un subgrupo moderado (n=266, 17.1% de la muestra) que muestra un **perfil predominante de problemas de conducta externalizante**, caracterizado por comportamientos de oposición, venganza y acciones deliberadamente dañinas hacia otros, pero sin presencia de experiencias psicóticas.
#
# #### Hallazgos principales:
#
# ##### **Alta prevalencia de conducta oposicionista y agresiva:**
# - **`pod011`**: 31% se vengó de personas dañando sus cosas/hiriéndolas (vs 9% global) → **+22pp**
# - **`pod003`**: 50% hizo cosas a propósito que los cuidadores prohibieron (vs 29% global) → **+21pp**
# - **`pod010`**: 24% hizo cosas malas a personas a propósito (vs 9% global) → **+15pp**
#
# ##### **Ausencia de experiencias psicóticas:**
# - **`psz009`**: 100% NO cree que lo espiaban (vs 88% global) → **+12pp**
#
# #### Variables más distintivas (diferencias >20pp):
#
# | Variable | Descripción | % Clase 4 | % Global | Diferencia |
# |----------|-------------|-----------|----------|------------|
# | **pod011** | Vengarse dañando cosas/hiriendo | 31% | 9% | **+22pp** |
# | **pod003** | Desobedecer a propósito a cuidadores | 50% | 29% | **+21pp** |
#
# #### Síntesis interpretativa:
#
# La **Clase 4** representa un **perfil de problemas de conducta externalizante** que se caracteriza por:
#
# 1. **Conducta oposicionista y desafiante**: desobediencia intencional a figuras de autoridad
# 2. **Comportamientos agresivos y vengativos**: acciones deliberadas para dañar a otros o sus propiedades
# 3. **Ausencia de síntomas psicóticos**: no presentan ideas paranoides o de persecución
#
# Este patrón sugiere un **subgrupo con trastornos de conducta o del comportamiento disruptivo** que podría beneficiarse de:
# - Intervenciones enfocadas en el manejo de la ira y la impulsividad
# - Terapia familiar para mejorar la dinámica y el cumplimiento de normas
# - Programas de habilidades sociales y solución de problemas
# - Enfoques conductuales para reducir la agresión y la venganza
#
#
# ### Clase 5 (k = 6)
#   99 observaciones (6.4%)
#
#
#   ---
#   Variables distintivas:
#
#      1. pcd027:
#         SOBRE 1: 'SI' - 64% (63/99) vs 15% (233/1558) global, +49pp
#         SUB 1: 'NO' - 36% (36/99) vs 85% (1322/1558) global, -48pp
#
#      2. pni001:
#         SOBRE 1: 'SI' - 68% (67/99) vs 20% (313/1558) global, +48pp
#         SUB 1: 'NO' - 32% (32/99) vs 80% (1240/1558) global, -47pp
#
#      3. pal001:
#         SOBRE 1: 'SI' - 72% (71/99) vs 25% (382/1558) global, +47pp
#         SUB 1: 'NO' - 28% (28/99) vs 75% (1173/1558) global, -47pp
#
#      4. pcd020:
#         SOBRE 1: 'SI' - 48% (48/99) vs 6% (94/1558) global, +42pp
#         SUB 1: 'NO' - 52% (51/99) vs 94% (1461/1558) global, -42pp
#
#      5. pcd012:
#         SOBRE 1: 'SI' - 49% (49/99) vs 10% (151/1558) global, +40pp
#         SUB 1: 'NO' - 51% (50/99) vs 90% (1404/1558) global, -40pp
#
#      6. pmj001:
#         SOBRE 1: 'SI' - 40% (40/99) vs 6% (99/1558) global, +34pp
#         SUB 1: 'NO' - 60% (59/99) vs 93% (1456/1558) global, -34pp
#
#      7. pcd028:
#         SOBRE 1: 'SI' - 35% (35/99) vs 3% (53/1558) global, +32pp
#         SUB 1: 'NO' - 65% (64/99) vs 96% (1502/1558) global, -32pp
#
#      8. pcd015:
#         SOBRE 1: 'SI' - 36% (36/99) vs 9% (142/1558) global, +27pp
#         SUB 1: 'NO' - 64% (63/99) vs 91% (1413/1558) global, -27pp
#
#      9. pcd039:
#         SOBRE 1: 'SI' - 30% (30/99) vs 3% (52/1558) global, +27pp
#         SUB 1: 'NO' - 70% (69/99) vs 96% (1503/1558) global, -27pp
#
#     10. pod003:
#         SOBRE 1: 'SI' - 56% (55/99) vs 29% (457/1558) global, +26pp
#         SUB 1: 'NO' - 44% (44/99) vs 70% (1097/1558) global, -26pp
#
#     11. pcd013:
#         SOBRE 1: 'SI' - 24% (24/99) vs 3% (47/1558) global, +21pp
#         SUB 1: 'NO' - 76% (75/99) vs 97% (1508/1558) global, -21pp
#
#     12. pod010:
#         SOBRE 1: 'SI' - 28% (28/99) vs 9% (134/1558) global, +20pp
#         SUB 1: 'NO' - 72% (71/99) vs 91% (1420/1558) global, -19pp
#
#     13. pcd029:
#         SOBRE 1: 'SI' - 15% (15/99) vs 2% (27/1558) global, +13pp
#         SUB 1: 'NO' - 85% (84/99) vs 98% (1529/1558) global, -13pp
#
#     14. pmd012:
#         SOBRE 1: 'SI' - 40% (40/99) vs 28% (437/1558) global, +12pp
#         SUB 1: 'NO' - 60% (59/99) vs 72% (1119/1558) global, -12pp
#
# #### Perfil general:
# La **Clase 5** representa un subgrupo moderado (n=99, 6.4% de la muestra) que muestra un **perfil de conducta externalizante severa y alto consumo de sustancias**, caracterizado por agresividad física, vandalismo, problemas con la ley y uso de múltiples sustancias.
#
# #### Hallazgos principales:
#
# ##### **Conducta agresiva y violenta extrema:**
# - **`pcd027`**: 64% participó en peleas físicas con lesiones (vs 15% global) → **+49pp**
# - **`pcd020`**: 48% cometió vandalismo (vs 6% global) → **+42pp**
# - **`pcd028`**: 35% intentó lastimar gravemente a alguien (vs 3% global) → **+32pp**
# - **`pcd029`**: 15% hirió a alguien con un arma (vs 2% global) → **+13pp**
#
# ##### **Consumo de sustancias muy elevado:**
# - **`pni001`**: 68% ha fumado cigarrillos (vs 20% global) → **+48pp**
# - **`pal001`**: 72% ha consumido alcohol (vs 25% global) → **+47pp**
# - **`pmj001`**: 40% ha usado marihuana (vs 6% global) → **+34pp**
#
# ##### **Problemas conductuales y con la ley:**
# - **`pcd012`**: 49% tuvo problemas por llegar tarde (toque de queda) (vs 10% global) → **+40pp**
# - **`pcd015`**: 36% mintió para evitar pagar deudas/responsabilidades (vs 9% global) → **+27pp**
# - **`pcd039`**: 30% tuvo problemas con la policía (vs 3% global) → **+27pp**
# - **`pod003`**: 56% desobedeció a propósito a cuidadores (vs 29% global) → **+26pp**
# - **`pcd013`**: 24% tuvo problemas por llegar tarde a edad temprana (vs 3% global) → **+21pp**
# - **`pod010`**: 28% hizo cosas malas a personas a propósito (vs 9% global) → **+20pp**
#
# ##### **Sintomatología internalizante moderada:**
# - **`pmd012`**: 40% tiene menos energía (vs 28% global) → **+12pp**
#
# #### Variables más distintivas (diferencias >40pp):
#
# | Variable | Descripción | % Clase 5 | % Global | Diferencia |
# |----------|-------------|-----------|----------|------------|
# | **pcd027** | Peleas físicas con lesiones | 64% | 15% | **+49pp** |
# | **pni001** | Tabaquismo | 68% | 20% | **+48pp** |
# | **pal001** | Consumo de alcohol | 72% | 25% | **+47pp** |
# | **pcd020** | Vandalismo | 48% | 6% | **+42pp** |
# | **pcd012** | Problemas por toque de queda | 49% | 10% | **+40pp** |
#
# #### Síntesis interpretativa:
#
# La **Clase 5** representa un **perfil de conducta externalizante severa con policonsumo de sustancias** que se caracteriza por:
#
# 1. **Violencia interpersonal grave**: peleas, intentos de lastimar y uso de armas
# 2. **Vandalismo y destrucción de propiedad**: daño intencional a objetos o lugares
# 3. **Alto consumo de sustancias**: tabaco, alcohol y marihuana
# 4. **Problemas significativos con la ley y autoridades**: policía, toque de queda, mentiras
# 5. **Comportamiento oposicionista y desafiante**: desobediencia intencional
#
# Este patrón sugiere un **subgrupo con trastorno de conducta severo y posible trastorno por uso de sustancias** que probablemente requiere:
# - Intervenciones intensivas para reducir la agresión y la violencia
# - Tratamiento para el abuso de sustancias
# - Programas de justicia juvenil o intervenciones con el sistema legal
# - Terapia familiar para mejorar la supervisión y el establecimiento de límites
# - Entrenamiento en habilidades de manejo de la ira y solución de problemas
#
# ## Síntesis de Diferenciación de Clases (k=6)
#
# | **Criterio** | **Clase 0 (Perfil Mixto Moderado)** | **Clase 1 (Perfil Mixto Intensificado)** | **Clase 2 (Bajo Riesgo)** | **Clase 3 (Perfil de Comorbilidad Extrema)** | **Clase 4 (Perfil Externalizante)** | **Clase 5 (Perfil Externalizante Severo con Policonsumo)** |
# | :--- | :--- | :--- | :--- | :--- | :--- | :--- |
# | **Tamaño de la Clase** | 216 observaciones (13.9%) | 64 observaciones (4.1%) | 886 observaciones (56.9%) | 27 observaciones (1.7%) | 266 observaciones (17.1%) | 99 observaciones (6.4%) |
# | **Patrón Principal** | **Comorbilidad internalizante-externalizante moderada.** Sintomatología depresiva, experiencias psicóticas leves y consumo de sustancias, con problemas conductuales menores. | **Perfil mixto con mayor intensidad.** Similar a la Clase 0 pero con prevalencias más altas en consumo, sintomatología depresiva y conductual, acercándose a un perfil de mayor severidad. | **Ajuste adaptativo y baja psicopatología.** Ausencia o baja frecuencia de problemas psicológicos, conductuales y de consumo.. | **Comorbilidad generalizada y de extrema severidad.** Co-ocurrencia crítica de síntomas psicóticos graves, depresión severa con riesgo suicida, conducta violenta/antisocial y abuso de múltiples sustancias. | **Problemas de conducta externalizante puros.** Predominio de conducta oposicionista, desafiante, agresiva y vengativa, en ausencia de experiencias psicóticas significativas. | **Externalización severa con alto consumo de sustancias.** Combinación de agresividad física grave, vandalismo, problemas con la ley y policonsumo (tabaco, alcohol, marihuana). |
# | **Núcleo del Perfil** | **Rasgos psicóticos leves y consumo.** Núcleo definido por malestar afectivo (problemas de sueño, autorreproches), ideas de referencia/paranoia leves, y uso de alcohol/tabaco, con problemas de cumplimiento menores. | **Intensificación del perfil mixto.** Mayor penetración del consumo de tabaco y alcohol, síntomas depresivos más marcados y una ampliación de problemas conductuales (vandalismo, problemas con policía) y psicóticos. | **Resiliencia y factores protectores.** Se caracteriza por la **sub-representación** sistemática de síntomas problemáticos en todas las dimensiones, reflejando un funcionamiento adaptativo dentro del contexto muestral. | **Urgencia psiquiátrica compleja.** Confluencia extrema de psicosis, conducta suicida, violencia interpersonal y abuso de sustancias, indicando un deterioro global severo y necesidad de intervención intensiva. | **Trastorno de conducta y oposición desafiante.** Centrado en la desobediencia intencional, la agresión interpersonal (venganza) y acciones dañinas hacia otros, sin componente psicótico evidente. | **Trastorno de conducta severo con adicciones.** Núcleo de violencia física (peleas, lesiones), destrucción de propiedad (vandalismo), transgresiones normativas y consumo elevado de múltiples sustancias. |
# | **Síntomas más Distintivos (Diferencia >20pp vs. Global)** | 1. **psz010:** Pens. de que se ríen/hablan (+28pp)<br>2. **pmd015:** Autorreproches (+27pp)<br>3. **pmd008:** Problemas de sueño (+26pp)<br>4. **psz009:** Creencia de ser espiado (+25pp)<br>5. **pal001:** Consumo de alcohol (+25pp)<br>6. **pmd012:** Falta de energía (+23pp)<br>7. **pcd012:** Probl. por toque de queda (+22pp) | 1. **pni001:** Tabaquismo (+49pp)<br>2. **pal001:** Consumo de alcohol (+47pp)<br>3. **pcd027:** Peleas con lesiones (+40pp)<br>4. **psz010:** Pens. de que se ríen/hablan (+36pp)<br>5. **psz009:** Creencia de ser espiado (+35pp)<br>6. **pmd015:** Autorreproches (+32pp)<br>7. **pmd022:** Intento de suicidio (+32pp)<br>8. **pcd020:** Vandalismo (+28pp) | *Nota: Se distingue por la **baja** frecuencia de síntomas. Diferencias >10pp en "NO":*<br>1. **pod003:** No desobedecer (+14pp)<br>2. **pal001:** No consumo alcohol (+14pp)<br>3. **pni001:** No tabaquismo (+13pp)<br>4. **psz010:** No pens. de que se ríen (+11pp)<br>5. **pmd012:** No falta de energía (+11pp)<br>6. **pcd027:** No peleas con lesiones (+11pp) | 1. **pal001:** Consumo de alcohol (+50pp)<br>2. **pmd008:** Problemas de sueño (+47pp)<br>3. **pni001:** Tabaquismo (+47pp)<br>4. **pmd015:** Autorreproches (+46pp)<br>5. **pmd012:** Falta de energía (+46pp)<br>6. **psz009:** Creencia de ser espiado (+40pp)<br>7. **pcd027:** Peleas con lesiones (+37pp)<br>8. **psz014:** Bajo control de un poder (+32pp) | 1. **pod011:** Vengarse dañando/hiriendo (+22pp)<br>2. **pod003:** Desobedecer a propósito (+21pp)<br>3. **pod010:** Hacer cosas malas a propósito (+15pp) | 1. **pcd027:** Peleas con lesiones (+49pp)<br>2. **pni001:** Tabaquismo (+48pp)<br>3. **pal001:** Consumo de alcohol (+47pp)<br>4. **pcd020:** Vandalismo (+42pp)<br>5. **pcd012:** Probl. por toque de queda (+40pp)<br>6. **pmj001:** Uso de marihuana (+34pp) |
# | **Riesgo Asociado** | **Moderado-Alto.** Riesgo de cronificación del distress emocional, transición a un trastorno depresivo o de ansiedad, y posible escalada en el consumo de sustancias. | **Alto.** Mayor probabilidad de evolucionar hacia perfiles de mayor severidad (como Clase 3), con riesgos significativos asociados a suicidio, conducta violenta y abuso de sustancias. | **Muy Bajo.** Representa el perfil de ajuste saludable dentro de la muestra. El riesgo principal es la posible vulnerabilidad a factores estresantes futuros sin apoyo preventivo. | **Muy Alto y Crítico.** Alto riesgo de mortalidad por suicidio o violencia, de cronicidad psiquiátrica severa, de discapacidad psicosocial permanente y de complicaciones legales graves. | **Moderado-Alto.** Riesgo de consolidación de un trastorno de conducta, problemas de adaptación social y académica/laboral, y posible desarrollo de sintomatología internalizante por conflictos interpersonales. | **Muy Alto.** Riesgo elevado de incurrir en delitos, de dependencia a sustancias, de victimización o perpetración de violencia grave, y de exclusión social. |
# | **Abordaje Sugerido** | **Intervención psicológica temprana.** Terapia para síntomas depresivos/ansiosos, psicoeducación sobre consumo de riesgo, evaluación de riesgo suicida y entrenamiento en regulación emocional y habilidades sociales. | **Intervención especializada e integral.** Requiere evaluación diagnóstica exhaustiva y tratamiento simultáneo para: depresión con riesgo suicida, abuso de sustancias, y manejo de impulsos/agresión. Posible derivación a salud mental. | **Prevención universal y promoción de la salud.** Fortalecimiento de factores protectores (habilidades sociales, apoyo familiar), educación para la salud y vigilancia del bienestar para mantener el ajuste positivo. | **Tratamiento multidisciplinario intensivo y urgente.** Probable necesidad de hospitalización, tratamiento integrado para psicosis y adicciones, manejo agresivo del riesgo suicida, intervenciones legales y rehabilitación psicosocial a largo plazo. | **Intervenciones conductuales y familiares.** Terapia centrada en el manejo de la ira, la obediencia a normas y la solución de conflictos. Programas de habilidades parentales para establecer límites consistentes y reforzar conductas prosociales. | **Tratamiento especializado dual y de justicia juvenil.** Abordaje intensivo para el trastorno de conducta y el abuso de sustancias. Enfoques multimodales que incluyan terapia familiar, entrenamiento en habilidades, supervisión judicial/restringida y posible tratamiento residencial. |
