# %%
import pandas as pd
from lca import *
from utils import build_full_dict, question_list, analisis_estadistico_clusters, analisis_interacciones_variables

# %%
df_sintomas_disc = pd.read_excel(r"C:\Users\Lan_1\Documents\VictorL_TesinaMACI\VictorL_TesinaMACI\Python\data\Sintomas_disc_Infante_Juvenil_n=1558.xlsx")
df_etiquetas = pd.read_excel(r"data\preguntas_disc.xlsx")

# %%
full_dict = build_full_dict(df_sintomas_disc)
q_list = question_list()

# %%
df=df_sintomas_disc.copy()
output_df, prob_df, metric_df = perform_true_lca(
    df=df,
    question_list = q_list,
    id_column='id', 
    n_components_range=range(2, 7)  
)
# Out:
# ======================================================================
# ANÁLISIS DE CLASES LATENTES (LCA) - ALGORITMO EM (OPTIMIZADO)
# ======================================================================
#
# [1] Preparando datos: 1558 observaciones
#
# [3] Aplicando mapeo de códigos...
#     ✓ Mapeo aplicado a 129 columnas
#
# [4] Verificando tipos de datos...
#
# [5] Análisis de valores faltantes...
#     pmd035         :   87 NaNs (  5.58%)
#     pga001         :   45 NaNs (  2.89%)
#     psa002         :   44 NaNs (  2.82%)
#     pga002         :    2 NaNs (  0.13%)
#     pga003         :    2 NaNs (  0.13%)
#     pga004         :    2 NaNs (  0.13%)
#     pga005         :    2 NaNs (  0.13%)
#     pga023         :    2 NaNs (  0.13%)
#     pga024         :    2 NaNs (  0.13%)
#     pga025         :    2 NaNs (  0.13%)
#     pga026         :    2 NaNs (  0.13%)
#     pga027         :    2 NaNs (  0.13%)
#     pga028         :    2 NaNs (  0.13%)
#     pga029         :    2 NaNs (  0.13%)
#     pmd001         :    2 NaNs (  0.13%)
#     pmd002         :    2 NaNs (  0.13%)
#     pmd003         :    2 NaNs (  0.13%)
#     pmd004         :    2 NaNs (  0.13%)
#     pmd005         :    2 NaNs (  0.13%)
#     pmd006         :    2 NaNs (  0.13%)
#     pmd007         :    2 NaNs (  0.13%)
#     pmd008         :    2 NaNs (  0.13%)
#     pmd009         :    2 NaNs (  0.13%)
#     pmd010         :    2 NaNs (  0.13%)
#     pmd011         :    2 NaNs (  0.13%)
#     pmd012         :    2 NaNs (  0.13%)
#     pmd013         :    2 NaNs (  0.13%)
#     pmd014         :    2 NaNs (  0.13%)
#     pmd015         :    2 NaNs (  0.13%)
#     pmd016         :    2 NaNs (  0.13%)
#     pmd017         :    2 NaNs (  0.13%)
#     pmd018         :    2 NaNs (  0.13%)
#     pmd019         :    2 NaNs (  0.13%)
#     pmd020         :    2 NaNs (  0.13%)
#     pmd021         :    2 NaNs (  0.13%)
#     pmd022         :    2 NaNs (  0.13%)
#     psz001         :    2 NaNs (  0.13%)
#     psz002         :    2 NaNs (  0.13%)
#     psz009         :    2 NaNs (  0.13%)
#     psz010         :    2 NaNs (  0.13%)
#     psz011         :    2 NaNs (  0.13%)
#     psz012         :    2 NaNs (  0.13%)
#     psz013         :    2 NaNs (  0.13%)
#     psz014         :    2 NaNs (  0.13%)
#     pad001         :    2 NaNs (  0.13%)
#     pad002         :    2 NaNs (  0.13%)
#     pad004         :    2 NaNs (  0.13%)
#     pad005         :    2 NaNs (  0.13%)
#     pad006         :    2 NaNs (  0.13%)
#     pad007         :    2 NaNs (  0.13%)
#     pad008         :    2 NaNs (  0.13%)
#     pad009         :    2 NaNs (  0.13%)
#     pad010         :    2 NaNs (  0.13%)
#     pad011         :    2 NaNs (  0.13%)
#     pad022         :    2 NaNs (  0.13%)
#     pad023         :    2 NaNs (  0.13%)
#     pad024         :    2 NaNs (  0.13%)
#     pad025         :    2 NaNs (  0.13%)
#     pad027         :    2 NaNs (  0.13%)
#     pad028         :    2 NaNs (  0.13%)
#     pad029         :    2 NaNs (  0.13%)
#     pad031         :    2 NaNs (  0.13%)
#     pad032         :    2 NaNs (  0.13%)
#     pad033         :    2 NaNs (  0.13%)
#     pad044         :    2 NaNs (  0.13%)
#     pcd001         :    2 NaNs (  0.13%)
#     pcd002         :    2 NaNs (  0.13%)
#     pcd003         :    2 NaNs (  0.13%)
#     pcd004         :    2 NaNs (  0.13%)
#     pcd007         :    2 NaNs (  0.13%)
#     pcd008         :    2 NaNs (  0.13%)
#     pcd009         :    2 NaNs (  0.13%)
#     pcd012         :    2 NaNs (  0.13%)
#     pcd013         :    2 NaNs (  0.13%)
#     pcd014         :    2 NaNs (  0.13%)
#     pcd015         :    2 NaNs (  0.13%)
#     pcd019         :    2 NaNs (  0.13%)
#     pcd020         :    2 NaNs (  0.13%)
#     pcd021         :    2 NaNs (  0.13%)
#     pcd022         :    2 NaNs (  0.13%)
#     pcd023         :    2 NaNs (  0.13%)
#     pcd025         :    2 NaNs (  0.13%)
#     pcd027         :    2 NaNs (  0.13%)
#     pcd028         :    2 NaNs (  0.13%)
#     pcd029         :    2 NaNs (  0.13%)
#     pcd039         :    2 NaNs (  0.13%)
#     pod001         :    2 NaNs (  0.13%)
#     pod002         :    2 NaNs (  0.13%)
#     pod003         :    2 NaNs (  0.13%)
#     pod004         :    2 NaNs (  0.13%)
#     pod005         :    2 NaNs (  0.13%)
#     pod006         :    2 NaNs (  0.13%)
#     pod007         :    2 NaNs (  0.13%)
#     pod008         :    2 NaNs (  0.13%)
#     pod009         :    2 NaNs (  0.13%)
#     pod010         :    2 NaNs (  0.13%)
#     pod011         :    2 NaNs (  0.13%)
#     pod012         :    2 NaNs (  0.13%)
#     pal001         :    2 NaNs (  0.13%)
#     pmj001         :    2 NaNs (  0.13%)
#     psu001         :    2 NaNs (  0.13%)
#     psu002         :    2 NaNs (  0.13%)
#     psu003         :    2 NaNs (  0.13%)
#     psu004         :    2 NaNs (  0.13%)
#     psu005         :    2 NaNs (  0.13%)
#     psu006         :    2 NaNs (  0.13%)
#     psu007         :    2 NaNs (  0.13%)
#     psu008         :    2 NaNs (  0.13%)
#     psu009         :    2 NaNs (  0.13%)
#     psu010         :    2 NaNs (  0.13%)
#     psu011         :    2 NaNs (  0.13%)
#     pni001         :    2 NaNs (  0.13%)
#     pni002         :    2 NaNs (  0.13%)
#     pso001         :    1 NaNs (  0.06%)
#     pso002         :    1 NaNs (  0.06%)
#     pso003         :    1 NaNs (  0.06%)
#     pso004         :    1 NaNs (  0.06%)
#     pso005         :    1 NaNs (  0.06%)
#     psa001         :    1 NaNs (  0.06%)
#     psa003         :    1 NaNs (  0.06%)
#     psa004         :    1 NaNs (  0.06%)
#     psa005         :    1 NaNs (  0.06%)
#     psa006         :    1 NaNs (  0.06%)
#     psa007         :    1 NaNs (  0.06%)
#     psa008         :    1 NaNs (  0.06%)
#     psa009         :    1 NaNs (  0.06%)
#     psa010         :    1 NaNs (  0.06%)
#     psa011         :    1 NaNs (  0.06%)
#     psa012         :    1 NaNs (  0.06%)
#
# [6] Preparando datos para LCA...
#     ✓ Datos preparados: 129 variables categóricas, 1558 observaciones
#     ✓ Categorías por variable: [2, 2, 2, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 2, 3, 3, 3, 2, 2, 2, 2, 2, 2, 3, 3, 3, 2, 2, 2, 3, 3, 2, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 2, 2, 2, 3, 2, 3, 3, 3, 3, 4]
#     ✓ Total categorías: 368 (promedio: 2.9 por variable)
#
# [7] Realizando Análisis de Clases Latentes (EM)...
#
#     k = 2 clases latentes...
#       ✓ BIC: 166915.94, AIC: 164352.74
#       ✓ Log-Likelihood: -81697.37
#       ✓ Certeza promedio: 0.983
#       ✓ Entropía: 0.042
#       ✓ Distribución de clases:
#           Clase 0: 801 (51.4%)
#           Clase 1: 757 (48.6%)
#
#     k = 3 clases latentes...
#       ✓ BIC: 165220.03, AIC: 161372.54
#       ✓ Log-Likelihood: -79967.27
#       ✓ Certeza promedio: 0.966
#       ✓ Entropía: 0.082
#       ✓ Distribución de clases:
#           Clase 0: 485 (31.1%)
#           Clase 1: 375 (24.1%)
#           Clase 2: 698 (44.8%)
#
#     k = 4 clases latentes...
#       ✓ BIC: 164310.00, AIC: 159178.24
#       ✓ Log-Likelihood: -78630.12
#       ✓ Certeza promedio: 0.961
#       ✓ Entropía: 0.098
#       ✓ Distribución de clases:
#           Clase 0: 434 (27.9%)
#           Clase 1: 380 (24.4%)
#           Clase 2: 232 (14.9%)
#           Clase 3: 512 (32.9%)
#
#     k = 5 clases latentes...
#       ✓ BIC: 164202.70, AIC: 157786.66
#       ✓ Log-Likelihood: -77694.33
#       ✓ Certeza promedio: 0.960
#       ✓ Entropía: 0.101
#       ✓ Distribución de clases:
#           Clase 0: 3 (0.2%)
#           Clase 1: 264 (16.9%)
#           Clase 2: 411 (26.4%)
#           Clase 3: 374 (24.0%)
#           Clase 4: 506 (32.5%)
#
#     k = 6 clases latentes...
#       ✓ BIC: 164229.93, AIC: 156529.61
#       ✓ Log-Likelihood: -76825.80
#       ✓ Certeza promedio: 0.956
#       ✓ Entropía: 0.107
#       ✓ Distribución de clases:
#           Clase 0: 279 (17.9%)
#           Clase 1: 212 (13.6%)
#           Clase 2: 507 (32.5%)
#           Clase 3: 2 (0.1%)
#           Clase 4: 347 (22.3%)
#           Clase 5: 211 (13.5%)
#
# [8] Creando DataFrames de salida...
#     ✓ k=2: 2 clases y 2 columnas de probabilidad
#     ✓ k=3: 3 clases y 3 columnas de probabilidad
#     ✓ k=4: 4 clases y 4 columnas de probabilidad
#     ✓ k=5: 5 clases y 5 columnas de probabilidad
#     ✓ k=6: 6 clases y 6 columnas de probabilidad
#
# ======================================================================
# RESUMEN FINAL - LCA OPTIMIZADO
# ======================================================================
#
# DataFrame principal (output_df):
#   • Dimensiones: 1558 filas × 135 columnas
#   • Variables categóricas: 129
#   • Valores NaN mantenidos: Sí
#
# DataFrame de probabilidades (prob_df):
#   • Dimensiones: 1558 filas × 21 columnas
#
# Métricas de modelos:
#  k       BIC       AIC  Log_Likelihood  Convergió  Iteraciones  Certeza_prom  Entropía
#  2 166915.94 164352.74       -81697.37       True           39          0.98      0.04
#  3 165220.03 161372.54       -79967.27       True           48          0.97      0.08
#  4 164310.00 159178.24       -78630.12       True          119          0.96      0.10
#  5 164202.70 157786.66       -77694.33       True           80          0.96      0.10
#  6 164229.93 156529.61       -76825.80       True          146          0.96      0.11
#
#   → Modelo recomendado: k = 5 (menor BIC)
#      • BIC: 164202.70
#      • AIC: 157786.66
#      • Certeza: 0.960
#      • Entropía: 0.101
#      • Modelo guardado en diccionario 'models'
#
# ======================================================================
# PROCESO COMPLETADO
# ======================================================================

# %%
from utils import build_full_dict, question_list, analisis_estadistico_clusters, analisis_interacciones_variables

resultados = analisis_estadistico_clusters(
    final_df=output_df,
    id_column='id',
    cluster_prefix='lca_k',
    df_etiquetas=df_etiquetas,
    col_codigo='Código',
    col_etiqueta='Etiqueta',
    output_pdf='reporte_1558.pdf',
    metrics_df=metric_df
)

excluir = ['id'] + [col for col in output_df.columns if col.startswith('lca_k')]
cramersv_mat, pvalue_mat, chi2_mat = analisis_interacciones_variables(
    df=output_df,
    exclude_cols=excluir
)
# Out:
# ====================================================================================================
# ANÁLISIS ESTADÍSTICO DE CLASES
# ====================================================================================================
#
# COLUMNAS DE CLASE ENCONTRADAS: ['lca_k2', 'lca_k3', 'lca_k4', 'lca_k5', 'lca_k6']
# Total de observaciones: 1558
#
# TOTAL variables para análisis: 129
#   ✓ Se cargaron 815 etiquetas
#
# ====================================================================================================
# INICIANDO ANÁLISIS COMPLETO...
# ====================================================================================================
#
# ================================================================================
# 1. ESTADÍSTICAS DE DISTRIBUCIÓN DE CLASES POR AGRUPACIÓN
# ================================================================================
#
# RESUMEN DE TODAS LAS CLASES:
#
# lca_k2:
#   Número de clases: 2
#   Total observaciones: 1558
#   Tamaño promedio de clase: 779
#   Rango de tamaños: 757 - 801
#   Completitud promedio: 99.8%
#
# lca_k3:
#   Número de clases: 3
#   Total observaciones: 1558
#   Tamaño promedio de clase: 519
#   Rango de tamaños: 375 - 698
#   Completitud promedio: 99.8%
#
# lca_k4:
#   Número de clases: 4
#   Total observaciones: 1558
#   Tamaño promedio de clase: 390
#   Rango de tamaños: 232 - 512
#   Completitud promedio: 99.8%
#
# lca_k5:
#   Número de clases: 5
#   Total observaciones: 1558
#   Tamaño promedio de clase: 312
#   Rango de tamaños: 3 - 506
#   Completitud promedio: 99.7%
#
# lca_k6:
#   Número de clases: 6
#   Total observaciones: 1558
#   Tamaño promedio de clase: 260
#   Rango de tamaños: 2 - 507
#   Completitud promedio: 99.7%
#
# ================================================================================
# 2. IDENTIFICACIÓN SISTEMÁTICA DE VARIABLES CLAVE (TODAS LAS VARIABLES)
# ================================================================================
#
# Analizando 129 variables para lca_k2...
#   Variables significativas encontradas: 109 de 129
#
#   Top 25 variables más discriminantes para lca_k2:
#   ------------------------------------------------------------------------------------------------------------------------
#   Variable                  Etiqueta                                 Cramér's V      p-value         χ² Discriminación
#   ------------------------------------------------------------------------------------------------------------------------
#   pmd003                    Often grouchy and irritable and little t     0.4774     7.56e-78        355        0.999
#   pod007                    Grouchy/easily annoyed in past year          0.4665     2.33e-74        339        0.999
#   pmd018                    Trouble keeping mind on school/other thi     0.4443     2.29e-66        308        0.998
#   pmd016                    Said they couldn't do anything well/were     0.4371     3.13e-64        298        0.998
#   pmd012                    Less energy in the last year                 0.4286     7.11e-63        286        0.999
#   pmd019                    Often hard to make decisions in past yea     0.4228     4.32e-60        279        0.998
#   pmd015                    Blamed self for bad things that happened     0.4189     5.55e-59        273        0.998
#   pmd035                    Seemed sad or depressed a lot of the tim     0.4179     1.10e-58        272        0.942
#   pod008                    Seemed mad at people or things in past y     0.4148     8.22e-58        268        0.998
#   pod009                    Felt things were unfair and got angry in     0.4086     4.18e-56        260        0.997
#   pod002                    Argued/talked back to caretakers in past     0.4050     4.16e-55        256        0.997
#   pmd008                    Trouble sleeping in last year                0.4044     4.60e-56        255        0.999
#   pad011                    Started activities without finishing the     0.4023     2.29e-54        252        0.998
#   pmd017                    Couldn't think as fast or clearly as usu     0.3924     9.76e-52        240        0.997
#   pga023                    Type of person who is tense and finds it     0.3905     3.16e-51        238        0.998
#   pmd001                    A time in past year when often seemed ve     0.3898     4.02e-52        237        0.999
#   pad006                    Trouble finishing homework in past year      0.3848     9.86e-50        231        0.998
#   pmd002                    Nothing fun/disinterested in anything/sa     0.3817     5.16e-50        227        0.999
#   pad009                    Often made a lot of mistakes because it'     0.3811     8.74e-49        226        0.998
#   pmd020                    Often thought about death/people dying/b     0.3781     5.09e-48        223        0.998
#   pga024                    In past year often been worried that the     0.3779     5.94e-48        222        0.998
#   pad001                    Trouble keeping mind on task for more th     0.3680     1.79e-45        211        0.998
#   pad008                    Forgot what they were supposed to do         0.3631     2.93e-44        205        0.997
#   pod004                    Refused to do things that caretakers sai     0.3612     8.42e-44        203        0.997
#   pmd007                    Much hungrier/ate a lot more than usual      0.3582     3.90e-44        200        0.999
#
#   Variables con Cramér's V > 0.3:
#   --------------------------------------------------------------------------------------------------------------
#   Variable                  Etiqueta                                 Cramér's V      p-value         χ²
#   --------------------------------------------------------------------------------------------------------------
#   pmd003                    Often grouchy and irritable and little t     0.4774     7.56e-78        355
#   pod007                    Grouchy/easily annoyed in past year          0.4665     2.33e-74        339
#   pmd018                    Trouble keeping mind on school/other thi     0.4443     2.29e-66        308
#   pmd016                    Said they couldn't do anything well/were     0.4371     3.13e-64        298
#   pmd012                    Less energy in the last year                 0.4286     7.11e-63        286
#   pmd019                    Often hard to make decisions in past yea     0.4228     4.32e-60        279
#   pmd015                    Blamed self for bad things that happened     0.4189     5.55e-59        273
#   pmd035                    Seemed sad or depressed a lot of the tim     0.4179     1.10e-58        272
#   pod008                    Seemed mad at people or things in past y     0.4148     8.22e-58        268
#   pod009                    Felt things were unfair and got angry in     0.4086     4.18e-56        260
#   pod002                    Argued/talked back to caretakers in past     0.4050     4.16e-55        256
#   pmd008                    Trouble sleeping in last year                0.4044     4.60e-56        255
#   pad011                    Started activities without finishing the     0.4023     2.29e-54        252
#   pmd017                    Couldn't think as fast or clearly as usu     0.3924     9.76e-52        240
#   pga023                    Type of person who is tense and finds it     0.3905     3.16e-51        238
#   pmd001                    A time in past year when often seemed ve     0.3898     4.02e-52        237
#   pad006                    Trouble finishing homework in past year      0.3848     9.86e-50        231
#   pmd002                    Nothing fun/disinterested in anything/sa     0.3817     5.16e-50        227
#   pad009                    Often made a lot of mistakes because it'     0.3811     8.74e-49        226
#   pmd020                    Often thought about death/people dying/b     0.3781     5.09e-48        223
#   pga024                    In past year often been worried that the     0.3779     5.94e-48        222
#   pad001                    Trouble keeping mind on task for more th     0.3680     1.79e-45        211
#   pad008                    Forgot what they were supposed to do         0.3631     2.93e-44        205
#   pod004                    Refused to do things that caretakers sai     0.3612     8.42e-44        203
#   pmd007                    Much hungrier/ate a lot more than usual      0.3582     3.90e-44        200
#   pmd013                    Doing even little things was tiring in l     0.3549     2.45e-43        196
#   psz010                    Thoughts of people talking/laughing at y     0.3454     4.76e-40        186
#   pmd009                    Slept more during the day than usual in      0.3449     5.58e-41        185
#   pod001                    Lost temper in past year                     0.3373     3.47e-38        177
#   pmd011                    Restless in past year                        0.3362     6.15e-38        176
#   pad004                    Couldn't keep mind on one thing when oth     0.3331     3.10e-37        173
#   pad007                    Often lost things in last year               0.3329     3.36e-37        173
#   pod005                    Done things just to annoy people/make th     0.3322     4.98e-37        172
#   pad010                    Often didn't listen when people were spe     0.3308     1.00e-36        170
#   pad002                    Often tried to avoid doing things that r     0.3297     1.77e-36        169
#   pga025                    In past year been worried that they made     0.3261     1.12e-35        166
#   pod003                    Done things on purpose that caretakers s     0.3255     1.47e-35        165
#   pmd014                    Arms and legs felt heavy in past year        0.3226     6.37e-35        162
#   pad005                    Disorganized in past year                    0.3213     1.22e-34        161
#   pso004                    Nervous in a roup of children (party/sch     0.3203     2.03e-34        160
#   pmd005                    Loss in apetite or ate a lot less in las     0.3180     6.24e-34        158
#   pmd010                    Seemed to do things like walking/talking     0.3120     1.17e-32        152
#   psa007                    Afraid something might happen to attatch     0.3106     2.25e-32        150
#   pad024                    Left seat (as in at school, movie, resta     0.3017     1.54e-30        142
#
#   Variables con Cramér's V > 0.4:
#   --------------------------------------------------------------------------------------------------------------
#   Variable                  Etiqueta                                 Cramér's V      p-value         χ²
#   --------------------------------------------------------------------------------------------------------------
#   pmd003                    Often grouchy and irritable and little t     0.4774     7.56e-78        355
#   pod007                    Grouchy/easily annoyed in past year          0.4665     2.33e-74        339
#   pmd018                    Trouble keeping mind on school/other thi     0.4443     2.29e-66        308
#   pmd016                    Said they couldn't do anything well/were     0.4371     3.13e-64        298
#   pmd012                    Less energy in the last year                 0.4286     7.11e-63        286
#   pmd019                    Often hard to make decisions in past yea     0.4228     4.32e-60        279
#   pmd015                    Blamed self for bad things that happened     0.4189     5.55e-59        273
#   pmd035                    Seemed sad or depressed a lot of the tim     0.4179     1.10e-58        272
#   pod008                    Seemed mad at people or things in past y     0.4148     8.22e-58        268
#   pod009                    Felt things were unfair and got angry in     0.4086     4.18e-56        260
#   pod002                    Argued/talked back to caretakers in past     0.4050     4.16e-55        256
#   pmd008                    Trouble sleeping in last year                0.4044     4.60e-56        255
#   pad011                    Started activities without finishing the     0.4023     2.29e-54        252
#
#   Variables con Cramér's V > 0.5:
#     No hay variables con Cramér's V > 0.5
#
# Analizando 129 variables para lca_k3...
#   Variables significativas encontradas: 111 de 129
#
#   Top 25 variables más discriminantes para lca_k3:
#   ------------------------------------------------------------------------------------------------------------------------
#   Variable                  Etiqueta                                 Cramér's V      p-value         χ² Discriminación
#   ------------------------------------------------------------------------------------------------------------------------
#   pmd035                    Seemed sad or depressed a lot of the tim     0.3897     4.84e-99        473        0.928
#   pmd015                    Blamed self for bad things that happened     0.3740     5.69e-91        436        0.997
#   pmd016                    Said they couldn't do anything well/were     0.3575     6.78e-83        398        0.997
#   pmd003                    Often grouchy and irritable and little t     0.3568     1.39e-84        397        0.999
#   pmd012                    Less energy in the last year                 0.3564     2.24e-84        396        0.999
#   pmd019                    Often hard to make decisions in past yea     0.3357     8.43e-73        351        0.997
#   pmd008                    Trouble sleeping in last year                0.3351     1.86e-74        350        0.999
#   pod007                    Grouchy/easily annoyed in past year          0.3292     8.02e-72        338        0.999
#   pmd001                    A time in past year when often seemed ve     0.3266     1.13e-70        332        0.999
#   pmd018                    Trouble keeping mind on school/other thi     0.3261     1.51e-68        331        0.998
#   pod002                    Argued/talked back to caretakers in past     0.3237     1.66e-67        327        0.997
#   pod008                    Seemed mad at people or things in past y     0.3218     1.10e-66        323        0.998
#   pmd017                    Couldn't think as fast or clearly as usu     0.3204     4.32e-66        320        0.997
#   pmd002                    Nothing fun/disinterested in anything/sa     0.3139     3.46e-65        307        0.999
#   pmd013                    Doing even little things was tiring in l     0.3046     2.42e-61        289        0.999
#   pmd020                    Often thought about death/people dying/b     0.3035     5.15e-59        287        0.997
#   psz010                    Thoughts of people talking/laughing at y     0.3011     4.54e-58        283        0.997
#   pod009                    Felt things were unfair and got angry in     0.2989     3.37e-57        278        0.997
#   pad011                    Started activities without finishing the     0.2946     1.80e-55        270        0.997
#   pga023                    Type of person who is tense and finds it     0.2940     3.04e-55        269        0.998
#   pmd014                    Arms and legs felt heavy in past year        0.2939     3.19e-55        269        0.997
#   pod004                    Refused to do things that caretakers sai     0.2903     8.32e-54        263        0.997
#   pmd007                    Much hungrier/ate a lot more than usual      0.2883     7.22e-55        259        0.999
#   pmd010                    Seemed to do things like walking/talking     0.2876     9.24e-53        258        0.998
#   psz009                    Believe people were spying on you            0.2874     1.06e-52        257        0.997
#
#   Variables con Cramér's V > 0.3:
#   --------------------------------------------------------------------------------------------------------------
#   Variable                  Etiqueta                                 Cramér's V      p-value         χ²
#   --------------------------------------------------------------------------------------------------------------
#   pmd035                    Seemed sad or depressed a lot of the tim     0.3897     4.84e-99        473
#   pmd015                    Blamed self for bad things that happened     0.3740     5.69e-91        436
#   pmd016                    Said they couldn't do anything well/were     0.3575     6.78e-83        398
#   pmd003                    Often grouchy and irritable and little t     0.3568     1.39e-84        397
#   pmd012                    Less energy in the last year                 0.3564     2.24e-84        396
#   pmd019                    Often hard to make decisions in past yea     0.3357     8.43e-73        351
#   pmd008                    Trouble sleeping in last year                0.3351     1.86e-74        350
#   pod007                    Grouchy/easily annoyed in past year          0.3292     8.02e-72        338
#   pmd001                    A time in past year when often seemed ve     0.3266     1.13e-70        332
#   pmd018                    Trouble keeping mind on school/other thi     0.3261     1.51e-68        331
#   pod002                    Argued/talked back to caretakers in past     0.3237     1.66e-67        327
#   pod008                    Seemed mad at people or things in past y     0.3218     1.10e-66        323
#   pmd017                    Couldn't think as fast or clearly as usu     0.3204     4.32e-66        320
#   pmd002                    Nothing fun/disinterested in anything/sa     0.3139     3.46e-65        307
#   pmd013                    Doing even little things was tiring in l     0.3046     2.42e-61        289
#   pmd020                    Often thought about death/people dying/b     0.3035     5.15e-59        287
#   psz010                    Thoughts of people talking/laughing at y     0.3011     4.54e-58        283
#
#   Variables con Cramér's V > 0.4:
#     No hay variables con Cramér's V > 0.4
#
#   Variables con Cramér's V > 0.5:
#     No hay variables con Cramér's V > 0.5
#
# Analizando 129 variables para lca_k4...
#   Variables significativas encontradas: 114 de 129
#
#   Top 25 variables más discriminantes para lca_k4:
#   ------------------------------------------------------------------------------------------------------------------------
#   Variable                  Etiqueta                                 Cramér's V      p-value         χ² Discriminación
#   ------------------------------------------------------------------------------------------------------------------------
#   pmd012                    Less energy in the last year                 0.3896     5.53e-99        473        0.999
#   pmd003                    Often grouchy and irritable and little t     0.3526     1.39e-80        387        0.999
#   pmd001                    A time in past year when often seemed ve     0.3462     1.39e-77        373        0.999
#   pmd008                    Trouble sleeping in last year                0.3374     1.56e-73        355        0.999
#   pad025                    Often climbed on things/ran around when      0.3337    2.51e-106        520        0.997
#   pod007                    Grouchy/easily annoyed in past year          0.3230     3.49e-67        325        0.999
#   pmd002                    Nothing fun/disinterested in anything/sa     0.3121     1.40e-62        304        0.999
#   pmd035                    Seemed sad or depressed a lot of the tim     0.3121     2.24e-92        455        0.922
#   pmd015                    Blamed self for bad things that happened     0.2999     6.03e-85        420        0.997
#   pmd007                    Much hungrier/ate a lot more than usual      0.2948     1.49e-55        271        0.999
#   pad029                    Often inturrupted others while they were     0.2932     5.83e-81        402        0.997
#   pad024                    Left seat (as in at school, movie, resta     0.2862     6.42e-77        383        0.996
#   pmd013                    Doing even little things was tiring in l     0.2809     3.04e-50        246        0.999
#   pmd009                    Slept more during the day than usual in      0.2799     7.71e-50        244        0.999
#   pod002                    Argued/talked back to caretakers in past     0.2747     1.68e-70        353        0.996
#   pmd019                    Often hard to make decisions in past yea     0.2737     6.07e-70        350        0.997
#   pmd016                    Said they couldn't do anything well/were     0.2727     2.05e-69        348        0.997
#   pad011                    Started activities without finishing the     0.2707     2.54e-68        342        0.997
#   pad023                    Fidgity/ restless in past year               0.2698     7.55e-68        340        0.998
#   pmd017                    Couldn't think as fast or clearly as usu     0.2685     3.80e-67        337        0.996
#   pod003                    Done things on purpose that caretakers s     0.2660     7.43e-66        331        0.997
#   pod004                    Refused to do things that caretakers sai     0.2643     6.02e-65        327        0.997
#   pmd018                    Trouble keeping mind on school/other thi     0.2601     9.82e-63        316        0.998
#   psz010                    Thoughts of people talking/laughing at y     0.2578     1.47e-61        311        0.997
#   pod005                    Done things just to annoy people/make th     0.2564     7.43e-61        307        0.997
#
#   Variables con Cramér's V > 0.3:
#   --------------------------------------------------------------------------------------------------------------
#   Variable                  Etiqueta                                 Cramér's V      p-value         χ²
#   --------------------------------------------------------------------------------------------------------------
#   pmd012                    Less energy in the last year                 0.3896     5.53e-99        473
#   pmd003                    Often grouchy and irritable and little t     0.3526     1.39e-80        387
#   pmd001                    A time in past year when often seemed ve     0.3462     1.39e-77        373
#   pmd008                    Trouble sleeping in last year                0.3374     1.56e-73        355
#   pad025                    Often climbed on things/ran around when      0.3337    2.51e-106        520
#   pod007                    Grouchy/easily annoyed in past year          0.3230     3.49e-67        325
#   pmd002                    Nothing fun/disinterested in anything/sa     0.3121     1.40e-62        304
#   pmd035                    Seemed sad or depressed a lot of the tim     0.3121     2.24e-92        455
#
#   Variables con Cramér's V > 0.4:
#     No hay variables con Cramér's V > 0.4
#
#   Variables con Cramér's V > 0.5:
#     No hay variables con Cramér's V > 0.5
#
# Analizando 129 variables para lca_k5...
#   Variables significativas encontradas: 127 de 129
#
#   Top 25 variables más discriminantes para lca_k5:
#   ------------------------------------------------------------------------------------------------------------------------
#   Variable                  Etiqueta                                 Cramér's V      p-value         χ² Discriminación
#   ------------------------------------------------------------------------------------------------------------------------
#   pod002                    Argued/talked back to caretakers in past     0.6380     0.00e+00       1902        0.999
#   pad028                    Often made much more noise while playing     0.6288     0.00e+00       1848        0.999
#   pmd014                    Arms and legs felt heavy in past year        0.6246     0.00e+00       1824        0.999
#   pad033                    Was in a                                     0.6226     0.00e+00       1812        0.999
#   pga005                    Often worried about having an illness in     0.6120     0.00e+00       1751        0.999
#   pad027                    Often talked a lot more than other child     0.6115     0.00e+00       1748        0.999
#   pod012                    Swore/used dirty language in past year       0.6098     0.00e+00       1738        0.999
#   pga002                    Often seem worried before playing a spor     0.6022     0.00e+00       1695        0.999
#   pga003                    Worried a lot about small mistakes made      0.6010     0.00e+00       1688        0.999
#   pga004                    Often worried about being on time in pas     0.5857     0.00e+00       1604        0.999
#   pad025                    Often climbed on things/ran around when      0.5680     0.00e+00       1508        0.999
#   pmd015                    Blamed self for bad things that happened     0.5611    5.94e-308       1471        0.999
#   pad031                    Blurted out answers before hearing whole     0.5597    2.22e-306       1464        0.999
#   pad029                    Often inturrupted others while they were     0.5540    4.79e-300       1435        0.999
#   pmd016                    Said they couldn't do anything well/were     0.5444    2.18e-289       1385        0.999
#   pmd019                    Often hard to make decisions in past yea     0.5433    3.67e-288       1379        0.999
#   pad011                    Started activities without finishing the     0.5419    1.14e-286       1373        0.999
#   pod003                    Done things on purpose that caretakers s     0.5398    2.31e-284       1362        0.999
#   pod004                    Refused to do things that caretakers sai     0.5366    6.59e-281       1346        0.999
#   pmd020                    Often thought about death/people dying/b     0.5342    2.65e-278       1334        0.999
#   psz010                    Thoughts of people talking/laughing at y     0.5339    4.81e-278       1333        0.999
#   pod005                    Done things just to annoy people/make th     0.5335    1.53e-277       1330        0.999
#   pga024                    In past year often been worried that the     0.5315    2.07e-275       1320        0.999
#   pad002                    Often tried to avoid doing things that r     0.5313    3.39e-275       1319        0.999
#   pad009                    Often made a lot of mistakes because it'     0.5306    2.08e-274       1316        0.999
#
#   Variables con Cramér's V > 0.3:
#   --------------------------------------------------------------------------------------------------------------
#   Variable                  Etiqueta                                 Cramér's V      p-value         χ²
#   --------------------------------------------------------------------------------------------------------------
#   pod002                    Argued/talked back to caretakers in past     0.6380     0.00e+00       1902
#   pad028                    Often made much more noise while playing     0.6288     0.00e+00       1848
#   pmd014                    Arms and legs felt heavy in past year        0.6246     0.00e+00       1824
#   pad033                    Was in a                                     0.6226     0.00e+00       1812
#   pga005                    Often worried about having an illness in     0.6120     0.00e+00       1751
#   pad027                    Often talked a lot more than other child     0.6115     0.00e+00       1748
#   pod012                    Swore/used dirty language in past year       0.6098     0.00e+00       1738
#   pga002                    Often seem worried before playing a spor     0.6022     0.00e+00       1695
#   pga003                    Worried a lot about small mistakes made      0.6010     0.00e+00       1688
#   pga004                    Often worried about being on time in pas     0.5857     0.00e+00       1604
#   pad025                    Often climbed on things/ran around when      0.5680     0.00e+00       1508
#   pmd015                    Blamed self for bad things that happened     0.5611    5.94e-308       1471
#   pad031                    Blurted out answers before hearing whole     0.5597    2.22e-306       1464
#   pad029                    Often inturrupted others while they were     0.5540    4.79e-300       1435
#   pmd016                    Said they couldn't do anything well/were     0.5444    2.18e-289       1385
#   pmd019                    Often hard to make decisions in past yea     0.5433    3.67e-288       1379
#   pad011                    Started activities without finishing the     0.5419    1.14e-286       1373
#   pod003                    Done things on purpose that caretakers s     0.5398    2.31e-284       1362
#   pod004                    Refused to do things that caretakers sai     0.5366    6.59e-281       1346
#   pmd020                    Often thought about death/people dying/b     0.5342    2.65e-278       1334
#   psz010                    Thoughts of people talking/laughing at y     0.5339    4.81e-278       1333
#   pod005                    Done things just to annoy people/make th     0.5335    1.53e-277       1330
#   pga024                    In past year often been worried that the     0.5315    2.07e-275       1320
#   pad002                    Often tried to avoid doing things that r     0.5313    3.39e-275       1319
#   pad009                    Often made a lot of mistakes because it'     0.5306    2.08e-274       1316
#   pod001                    Lost temper in past year                     0.5279    1.32e-271       1303
#   psz009                    Believe people were spying on you            0.5266    3.07e-270       1296
#   psa009                    Afraid being left without family , (kidn     0.5258    2.45e-269       1292
#   pad006                    Trouble finishing homework in past year      0.5254    6.69e-269       1290
#   pod006                    Blamed others for their mistakes or bad      0.5224    9.55e-266       1275
#   pad007                    Often lost things in last year               0.5193    1.84e-262       1260
#   pad010                    Often didn't listen when people were spe     0.5191    2.38e-262       1260
#   pga025                    In past year been worried that they made     0.5183    1.69e-261       1256
#   pmd022                    Ever in whole life made a suicide attemp     0.5111    4.83e-254       1221
#   pod011                    Gotten even with people in past year by      0.5048    1.56e-247       1191
#   pmd021                    Talked seriously about killing self in p     0.5033    4.43e-246       1184
#   pod010                    Done mean things to people in past year      0.5022    5.68e-245       1179
#   psz002                    Heard things other people could not hear     0.5005    3.25e-243       1171
#   pso005                    Nervous when doing things infront of oth     0.4989    1.28e-241       1163
#   psz011                    Believe someone was plotting against you     0.4969    1.26e-239       1154
#   pga028                    Often had stomachaches in the last year      0.4968    1.69e-239       1154
#   psz012                    Convinced that strange thoughts were put     0.4948    1.67e-237       1144
#   pga027                    Often had headaches in the last year         0.4938    1.78e-236       1140
#   pad044                    Taken any medication in past year for be     0.4831    5.32e-226       1091
#   psz014                    Convinced under the control of some powe     0.4825    2.12e-225       1088
#   psz013                    Believe you alone were sent special mess     0.4773    2.09e-220       1065
#   pad024                    Left seat (as in at school, movie, resta     0.4756    8.84e-219       1057
#   pmd017                    Couldn't think as fast or clearly as usu     0.4702    1.34e-213       1033
#   psa008                    Afraid attachment figure might go and ne     0.4686    3.77e-212       1026
#   pad032                    Often had trouble waiting for turns (as      0.4575    8.50e-202        978
#   pod009                    Felt things were unfair and got angry in     0.4547    3.47e-199        966
#   pad008                    Forgot what they were supposed to do         0.4456    5.92e-191        928
#   psa007                    Afraid something might happen to attatch     0.4403    3.07e-186        906
#   pga026                    Been very concerned with being liked by      0.4366    4.91e-183        891
#   pad005                    Disorganized in past year                    0.4361    1.33e-182        889
#   pad023                    Fidgity/ restless in past year               0.4271    8.45e-175        853
#   pod008                    Seemed mad at people or things in past y     0.4229    3.55e-171        836
#   pmd018                    Trouble keeping mind on school/other thi     0.4215    5.29e-170        830
#   pal001                    Not including sips from other peoples, e     0.4148    1.95e-164        804
#   pad001                    Trouble keeping mind on task for more th     0.4128    9.69e-163        796
#   pad022                    Been on the go more active than usual as     0.4107    5.03e-161        788
#   psu008                    Ever use amyl nitrite or "poppers," "whi     0.4085    3.42e-107        520
#   psu006                    Ever use PCP or "angel dust"                 0.4085    3.42e-107        520
#   psu005                    Ever use opiates to get high                 0.4085    3.42e-107        520
#   psu004                    Ever use heroin                              0.4085    3.42e-107        520
#   psz001                    Seen someone or something that others co     0.4020    5.76e-154        755
#   pmd010                    Seemed to do things like walking/talking     0.4002    1.77e-152        749
#   pmd011                    Restless in past year                        0.3977    1.63e-150        739
#   pad004                    Couldn't keep mind on one thing when oth     0.3973    3.59e-150        738
#   pcd012                    Ever gotten into trouble for staying out     0.3966    1.26e-149        735
#   pcd027                    Ever been in a physical fight in which s     0.3928    1.22e-146        721
#   pmd005                    Loss in apetite or ate a lot less in las     0.3921    5.02e-146        718
#   pmd012                    Less energy in the last year                 0.3908     1.10e-97        476
#   pcd015                    Ever lied to not pay back money or to ge     0.3857    4.66e-141        695
#   pmj001                    Ever in whole life used marijuana            0.3765    4.62e-134        663
#   pga001                    Often worried before taking test/handing     0.3712    1.98e-172        859
#   pcd020                    Broken something/mes sed up a place on p     0.3705    1.30e-129        642
#   pcd022                    Ever started a fire without permission       0.3684    4.93e-128        634
#   pga029                    Other aches and pains in last year           0.3675    2.31e-127        631
#   pcd003                    Ever stolen from someone when they weren     0.3670    5.33e-127        629
#   pcd001                    Ever stolen money or                         0.3662    2.04e-126        627
#   pcd025                    Ever bullied someone smaller who wouldn'     0.3610    1.25e-122        609
#   pcd013                    Age when first got into trouble for stay     0.3592    2.32e-121        603
#   pmd003                    Often grouchy and irritable and little t     0.3590     8.39e-82        402
#   pcd039                    Ever been in trouble with the police         0.3588    4.54e-121        602
#   pcd028                    Ever tried to hurt someone badly/been ph     0.3547    3.57e-118        588
#   pcd023                    Ever been physically cruel to an animal      0.3518    4.30e-116        578
#   psa001                    Wanted to say home from school/work with     0.3509    1.73e-115        576
#   pmd001                    A time in past year when often seemed ve     0.3488     5.76e-77        379
#   pcd002                    Ever shoplifted                              0.3479    2.27e-113        566
#   pcd019                    Ever broken into a house/building/c ar       0.3461    3.90e-112        560
#   psu003                    Ever use cocaine or "crack"                  0.3408    1.67e-108        543
#   pcd008                    Ever held someone up or attacked someone     0.3398    7.60e-108        540
#   pcd004                    Faked a name on a check/used someone els     0.3395    1.34e-107        539
#   psu011                    Ever use any other drugs or substances n     0.3383    8.40e-107        535
#   psu001                    Use stimulants or amphetamines to get hi     0.3383    8.50e-107        535
#   pcd007                    Ever snatched purse or jewelry               0.3369    7.33e-106        530
#   pcd009                    Ever threatened someone in order to stea     0.3368    7.66e-106        530
#   pmd008                    Trouble sleeping in last year                0.3368     1.61e-71        354
#   psu009                    Ever use inhalants like glue, cleaning f     0.3367    9.48e-106        530
#   psu007                    Ever use any kind of hallucinogen            0.3345    2.96e-104        523
#   psu010                    Not including those prescribed by a doct     0.3345    2.96e-104        523
#   pod007                    Grouchy/easily annoyed in past year          0.3299     1.90e-68        339
#   pcd014                    Ever lied to get money or something else     0.3202     6.11e-95        479
#   pni001                    Ever smoked a cigarette                      0.3150     1.13e-91        464
#   psa002                    Felt sick                                    0.3129     2.20e-90        458
#   pmd035                    Seemed sad or depressed a lot of the tim     0.3111     2.99e-89        452
#   pmd002                    Nothing fun/disinterested in anything/sa     0.3083     2.72e-59        296
#   pmd007                    Much hungrier/ate a lot more than usual      0.3006     3.54e-56        282
#
#   Variables con Cramér's V > 0.4:
#   --------------------------------------------------------------------------------------------------------------
#   Variable                  Etiqueta                                 Cramér's V      p-value         χ²
#   --------------------------------------------------------------------------------------------------------------
#   pod002                    Argued/talked back to caretakers in past     0.6380     0.00e+00       1902
#   pad028                    Often made much more noise while playing     0.6288     0.00e+00       1848
#   pmd014                    Arms and legs felt heavy in past year        0.6246     0.00e+00       1824
#   pad033                    Was in a                                     0.6226     0.00e+00       1812
#   pga005                    Often worried about having an illness in     0.6120     0.00e+00       1751
#   pad027                    Often talked a lot more than other child     0.6115     0.00e+00       1748
#   pod012                    Swore/used dirty language in past year       0.6098     0.00e+00       1738
#   pga002                    Often seem worried before playing a spor     0.6022     0.00e+00       1695
#   pga003                    Worried a lot about small mistakes made      0.6010     0.00e+00       1688
#   pga004                    Often worried about being on time in pas     0.5857     0.00e+00       1604
#   pad025                    Often climbed on things/ran around when      0.5680     0.00e+00       1508
#   pmd015                    Blamed self for bad things that happened     0.5611    5.94e-308       1471
#   pad031                    Blurted out answers before hearing whole     0.5597    2.22e-306       1464
#   pad029                    Often inturrupted others while they were     0.5540    4.79e-300       1435
#   pmd016                    Said they couldn't do anything well/were     0.5444    2.18e-289       1385
#   pmd019                    Often hard to make decisions in past yea     0.5433    3.67e-288       1379
#   pad011                    Started activities without finishing the     0.5419    1.14e-286       1373
#   pod003                    Done things on purpose that caretakers s     0.5398    2.31e-284       1362
#   pod004                    Refused to do things that caretakers sai     0.5366    6.59e-281       1346
#   pmd020                    Often thought about death/people dying/b     0.5342    2.65e-278       1334
#   psz010                    Thoughts of people talking/laughing at y     0.5339    4.81e-278       1333
#   pod005                    Done things just to annoy people/make th     0.5335    1.53e-277       1330
#   pga024                    In past year often been worried that the     0.5315    2.07e-275       1320
#   pad002                    Often tried to avoid doing things that r     0.5313    3.39e-275       1319
#   pad009                    Often made a lot of mistakes because it'     0.5306    2.08e-274       1316
#   pod001                    Lost temper in past year                     0.5279    1.32e-271       1303
#   psz009                    Believe people were spying on you            0.5266    3.07e-270       1296
#   psa009                    Afraid being left without family , (kidn     0.5258    2.45e-269       1292
#   pad006                    Trouble finishing homework in past year      0.5254    6.69e-269       1290
#   pod006                    Blamed others for their mistakes or bad      0.5224    9.55e-266       1275
#   pad007                    Often lost things in last year               0.5193    1.84e-262       1260
#   pad010                    Often didn't listen when people were spe     0.5191    2.38e-262       1260
#   pga025                    In past year been worried that they made     0.5183    1.69e-261       1256
#   pmd022                    Ever in whole life made a suicide attemp     0.5111    4.83e-254       1221
#   pod011                    Gotten even with people in past year by      0.5048    1.56e-247       1191
#   pmd021                    Talked seriously about killing self in p     0.5033    4.43e-246       1184
#   pod010                    Done mean things to people in past year      0.5022    5.68e-245       1179
#   psz002                    Heard things other people could not hear     0.5005    3.25e-243       1171
#   pso005                    Nervous when doing things infront of oth     0.4989    1.28e-241       1163
#   psz011                    Believe someone was plotting against you     0.4969    1.26e-239       1154
#   pga028                    Often had stomachaches in the last year      0.4968    1.69e-239       1154
#   psz012                    Convinced that strange thoughts were put     0.4948    1.67e-237       1144
#   pga027                    Often had headaches in the last year         0.4938    1.78e-236       1140
#   pad044                    Taken any medication in past year for be     0.4831    5.32e-226       1091
#   psz014                    Convinced under the control of some powe     0.4825    2.12e-225       1088
#   psz013                    Believe you alone were sent special mess     0.4773    2.09e-220       1065
#   pad024                    Left seat (as in at school, movie, resta     0.4756    8.84e-219       1057
#   pmd017                    Couldn't think as fast or clearly as usu     0.4702    1.34e-213       1033
#   psa008                    Afraid attachment figure might go and ne     0.4686    3.77e-212       1026
#   pad032                    Often had trouble waiting for turns (as      0.4575    8.50e-202        978
#   pod009                    Felt things were unfair and got angry in     0.4547    3.47e-199        966
#   pad008                    Forgot what they were supposed to do         0.4456    5.92e-191        928
#   psa007                    Afraid something might happen to attatch     0.4403    3.07e-186        906
#   pga026                    Been very concerned with being liked by      0.4366    4.91e-183        891
#   pad005                    Disorganized in past year                    0.4361    1.33e-182        889
#   pad023                    Fidgity/ restless in past year               0.4271    8.45e-175        853
#   pod008                    Seemed mad at people or things in past y     0.4229    3.55e-171        836
#   pmd018                    Trouble keeping mind on school/other thi     0.4215    5.29e-170        830
#   pal001                    Not including sips from other peoples, e     0.4148    1.95e-164        804
#   pad001                    Trouble keeping mind on task for more th     0.4128    9.69e-163        796
#   pad022                    Been on the go more active than usual as     0.4107    5.03e-161        788
#   psu004                    Ever use heroin                              0.4085    3.42e-107        520
#   psu005                    Ever use opiates to get high                 0.4085    3.42e-107        520
#   psu006                    Ever use PCP or "angel dust"                 0.4085    3.42e-107        520
#   psu008                    Ever use amyl nitrite or "poppers," "whi     0.4085    3.42e-107        520
#   psz001                    Seen someone or something that others co     0.4020    5.76e-154        755
#   pmd010                    Seemed to do things like walking/talking     0.4002    1.77e-152        749
#
#   Variables con Cramér's V > 0.5:
#   --------------------------------------------------------------------------------------------------------------
#   Variable                  Etiqueta                                 Cramér's V      p-value         χ²
#   --------------------------------------------------------------------------------------------------------------
#   pod002                    Argued/talked back to caretakers in past     0.6380     0.00e+00       1902
#   pad028                    Often made much more noise while playing     0.6288     0.00e+00       1848
#   pmd014                    Arms and legs felt heavy in past year        0.6246     0.00e+00       1824
#   pad033                    Was in a                                     0.6226     0.00e+00       1812
#   pga005                    Often worried about having an illness in     0.6120     0.00e+00       1751
#   pad027                    Often talked a lot more than other child     0.6115     0.00e+00       1748
#   pod012                    Swore/used dirty language in past year       0.6098     0.00e+00       1738
#   pga002                    Often seem worried before playing a spor     0.6022     0.00e+00       1695
#   pga003                    Worried a lot about small mistakes made      0.6010     0.00e+00       1688
#   pga004                    Often worried about being on time in pas     0.5857     0.00e+00       1604
#   pad025                    Often climbed on things/ran around when      0.5680     0.00e+00       1508
#   pmd015                    Blamed self for bad things that happened     0.5611    5.94e-308       1471
#   pad031                    Blurted out answers before hearing whole     0.5597    2.22e-306       1464
#   pad029                    Often inturrupted others while they were     0.5540    4.79e-300       1435
#   pmd016                    Said they couldn't do anything well/were     0.5444    2.18e-289       1385
#   pmd019                    Often hard to make decisions in past yea     0.5433    3.67e-288       1379
#   pad011                    Started activities without finishing the     0.5419    1.14e-286       1373
#   pod003                    Done things on purpose that caretakers s     0.5398    2.31e-284       1362
#   pod004                    Refused to do things that caretakers sai     0.5366    6.59e-281       1346
#   pmd020                    Often thought about death/people dying/b     0.5342    2.65e-278       1334
#   psz010                    Thoughts of people talking/laughing at y     0.5339    4.81e-278       1333
#   pod005                    Done things just to annoy people/make th     0.5335    1.53e-277       1330
#   pga024                    In past year often been worried that the     0.5315    2.07e-275       1320
#   pad002                    Often tried to avoid doing things that r     0.5313    3.39e-275       1319
#   pad009                    Often made a lot of mistakes because it'     0.5306    2.08e-274       1316
# ...
#
#   CLASE 1: 380 obs (24.4%)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#   SOBRERREPRESENTADAS: 37 categorías
#     - pad025: SI (+35.2pp)
#     - pad029: SI (+35.0pp)
#     - pad024: SI (+30.4pp)
#     - pad022: SI (+30.2pp)
#     - pad023: SI (+26.6pp)
#     - pad027: SI (+23.7pp)
#     - pad031: SI (+23.0pp)
#     - pod004: SI (+21.3pp)
#     - pod001: SI (+20.1pp)
#     - pod006: SI (+19.7pp)
#   SUBREPRESENTADAS: 34 categorías
#     - pad025: NO (-34.9pp)
#     - pad029: NO (-34.7pp)
#     - pad024: NO (-30.3pp)
#     - pad022: NO (-30.1pp)
#     - pad023: NO (-26.5pp)
#     - pad027: NO (-23.4pp)
#     - pad031: NO (-22.6pp)
#     - pod004: NO (-21.1pp)
#     - pod001: NO (-19.8pp)
#     - pal001: SI (-19.5pp)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   CLASE 2: 232 obs (14.9%)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#   SOBRERREPRESENTADAS: 99 categorías
#     - pmd015: SI (+44.0pp)
#     - pmd008: SI (+40.5pp)
#     - pmd012: SI (+40.5pp)
#     - pmd019: SI (+40.4pp)
#     - pmd001: SI (+39.5pp)
#     - pga024: SI (+37.8pp)
#     - pmd020: SI (+37.8pp)
#     - pmd016: SI (+37.0pp)
#     - pmd007: SI (+36.8pp)
#     - pmd018: SI (+36.5pp)
#   SUBREPRESENTADAS: 98 categorías
#     - pmd015: NO (-44.6pp)
#     - pmd035: NO (-42.1pp)
#     - pmd019: NO (-41.1pp)
#     - pmd008: NO (-40.4pp)
#     - pmd012: NO (-40.4pp)
#     - pmd001: NO (-39.4pp)
#     - pga024: NO (-38.4pp)
#     - pmd020: NO (-38.4pp)
#     - pmd016: NO (-37.6pp)
#     - pmd007: NO (-36.7pp)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   CLASE 3: 512 obs (32.9%)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#   SOBRERREPRESENTADAS: 77 categorías
#     - pmd003: NO (+32.8pp)
#     - pod002: NO (+30.3pp)
#     - pod007: NO (+28.8pp)
#     - pmd018: NO (+27.9pp)
#     - pod004: NO (+27.1pp)
#     - pmd001: NO (+25.8pp)
#     - pod008: NO (+25.7pp)
#     - pad011: NO (+25.3pp)
#     - pod009: NO (+24.9pp)
#     - pad001: NO (+24.6pp)
#   SUBREPRESENTADAS: 61 categorías
#     - pmd003: SI (-33.1pp)
#     - pod002: SI (-30.1pp)
#     - pod007: SI (-28.8pp)
#     - pmd018: SI (-28.1pp)
#     - pod004: SI (-27.0pp)
#     - pmd001: SI (-26.0pp)
#     - pod008: SI (-25.7pp)
#     - pad011: SI (-25.4pp)
#     - pad001: SI (-24.8pp)
#     - pod009: SI (-24.8pp)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# ######################################################################
# PERFILES DETALLADOS PARA LA AGRUPACIÓN: lca_k5
# ######################################################################
# Analizando todas las 129 variables...
#
#   CLASE 0: 3 obs (0.2%)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#   SOBRERREPRESENTADAS: 123 categorías
#     - pga002: NS (+99.8pp)
#     - pga003: NS (+99.8pp)
#     - pga004: NS (+99.8pp)
#     - pga005: NS (+99.8pp)
#     - pmd014: NS (+99.8pp)
#     - pad027: NS (+99.8pp)
#     - pad028: NS (+99.8pp)
#     - pad033: NS (+99.8pp)
#     - pod002: NS (+99.8pp)
#     - pod012: NS (+99.8pp)
#   SUBREPRESENTADAS: 91 categorías
#     - psz013: NO (-65.4pp)
#     - psz014: NO (-64.8pp)
#     - psz012: NO (-62.5pp)
#     - psz011: NO (-62.3pp)
#     - pad044: NO (-61.9pp)
#     - pni002: NO (-61.9pp)
#     - pmd022: NO (-60.5pp)
#     - pmd021: NO (-59.7pp)
#     - psz002: NO (-57.9pp)
#     - pod010: NO (-57.8pp)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   CLASE 1: 264 obs (16.9%)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#   SOBRERREPRESENTADAS: 98 categorías
#     - pmd015: SI (+43.6pp)
#     - pmd012: SI (+39.4pp)
#     - pmd019: SI (+38.9pp)
#     - pmd001: SI (+38.2pp)
#     - pod008: SI (+37.4pp)
#     - pmd008: SI (+37.1pp)
#     - pmd020: SI (+37.1pp)
#     - pmd016: SI (+37.0pp)
#     - pmd018: SI (+36.0pp)
#     - pga024: SI (+35.7pp)
#   SUBREPRESENTADAS: 97 categorías
#     - pmd015: NO (-43.3pp)
#     - pmd035: NO (-40.0pp)
#     - pmd012: NO (-39.2pp)
#     - pmd019: NO (-38.6pp)
#     - pmd001: NO (-38.1pp)
#     - pod008: NO (-37.2pp)
#     - pmd008: NO (-37.0pp)
#     - pmd020: NO (-36.9pp)
#     - pmd016: NO (-36.7pp)
#     - pmd018: NO (-35.8pp)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   CLASE 2: 411 obs (26.4%)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#   SOBRERREPRESENTADAS: 29 categorías
#     - pmd012: SI (+19.4pp)
#     - pmd001: SI (+18.5pp)
#     - pad025: NO (+18.5pp)
#     - pad029: NO (+18.2pp)
#     - pmd003: SI (+17.7pp)
#     - pal001: SI (+17.6pp)
#     - psa007: SI (+16.4pp)
#     - pad027: NO (+15.6pp)
#     - pga001: SI (+15.1pp)
#     - pad031: NO (+14.7pp)
#   SUBREPRESENTADAS: 29 categorías
#     - pmd012: NO (-19.3pp)
#     - pmd001: NO (-18.4pp)
#     - pad029: SI (-18.2pp)
#     - pal001: NO (-17.6pp)
#     - pmd003: NO (-17.5pp)
#     - psa007: NO (-16.2pp)
#     - pad027: SI (-15.5pp)
#     - pad031: SI (-14.6pp)
#     - pmd009: NO (-14.4pp)
#     - pad024: SI (-14.3pp)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   CLASE 3: 374 obs (24.0%)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#   SOBRERREPRESENTADAS: 40 categorías
#     - pad029: SI (+34.9pp)
#     - pad025: SI (+33.4pp)
#     - pad022: SI (+29.7pp)
#     - pad024: SI (+29.5pp)
#     - pad023: SI (+25.2pp)
#     - pad027: SI (+22.8pp)
#     - pad031: SI (+22.3pp)
#     - pod004: SI (+20.2pp)
#     - pod001: SI (+19.9pp)
#     - pal001: NO (+19.4pp)
#   SUBREPRESENTADAS: 38 categorías
#     - pad029: NO (-34.6pp)
#     - pad025: NO (-33.2pp)
#     - pad022: NO (-29.5pp)
#     - pad024: NO (-29.5pp)
#     - pad023: NO (-25.0pp)
#     - pad027: NO (-22.5pp)
#     - pad031: NO (-21.9pp)
#     - pod004: NO (-19.9pp)
#     - pod001: NO (-19.7pp)
#     - pal001: SI (-19.2pp)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   CLASE 4: 506 obs (32.5%)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#   SOBRERREPRESENTADAS: 77 categorías
#     - pmd003: NO (+33.2pp)
#     - pod002: NO (+30.5pp)
#     - pod007: NO (+29.0pp)
#     - pmd018: NO (+27.7pp)
#     - pod004: NO (+27.1pp)
#     - pod008: NO (+25.9pp)
#     - pmd001: NO (+25.5pp)
#     - pad011: NO (+25.5pp)
#     - pod009: NO (+25.4pp)
#     - pad001: NO (+24.6pp)
#   SUBREPRESENTADAS: 61 categorías
#     - pmd003: SI (-33.5pp)
#     - pod002: SI (-30.4pp)
#     - pod007: SI (-29.1pp)
#     - pmd018: SI (-27.9pp)
#     - pod004: SI (-27.1pp)
#     - pod008: SI (-25.9pp)
#     - pmd001: SI (-25.8pp)
#     - pad011: SI (-25.6pp)
#     - pod009: SI (-25.3pp)
#     - pad001: SI (-24.8pp)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# ######################################################################
# PERFILES DETALLADOS PARA LA AGRUPACIÓN: lca_k6
# ######################################################################
# Analizando todas las 129 variables...
#
#   CLASE 0: 279 obs (17.9%)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#   SOBRERREPRESENTADAS: 51 categorías
#     - pmd001: SI (+29.9pp)
#     - pmd003: SI (+26.0pp)
#     - pmd016: SI (+25.2pp)
#     - pmd012: SI (+25.0pp)
#     - pga003: SI (+20.6pp)
#     - pga023: SI (+20.5pp)
#     - pmd019: SI (+20.4pp)
#     - psa002: SI (+20.2pp)
#     - pga025: SI (+20.0pp)
#     - psa007: SI (+20.0pp)
#   SUBREPRESENTADAS: 47 categorías
#     - pmd001: NO (-29.8pp)
#     - pmd003: NO (-25.9pp)
#     - pmd016: NO (-24.9pp)
#     - pmd012: NO (-24.9pp)
#     - pmd035: NO (-23.7pp)
#     - pga023: NO (-20.3pp)
#     - pga003: NO (-20.3pp)
#     - pmd019: NO (-20.1pp)
#     - pga025: NO (-19.8pp)
#     - psa007: NO (-19.7pp)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   CLASE 1: 212 obs (13.6%)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#   SOBRERREPRESENTADAS: 32 categorías
#     - pal001: SI (+51.4pp)
#     - pni001: SI (+47.4pp)
#     - pcd027: SI (+36.9pp)
#     - psa005: NO (+27.4pp)
#     - psa006: SI (+27.4pp)
#     - pod002: SI (+24.0pp)
#     - pcd012: SI (+23.8pp)
#     - psa012: SI (+23.6pp)
#     - pcd014: SI (+22.5pp)
#     - pmd009: SI (+21.0pp)
#   SUBREPRESENTADAS: 29 categorías
#     - pal001: NO (-51.2pp)
#     - pni001: NO (-47.0pp)
#     - pcd027: NO (-36.7pp)
#     - psa005: SI (-27.3pp)
#     - psa006: NO (-27.3pp)
#     - pod002: NO (-23.7pp)
#     - pcd012: NO (-23.6pp)
#     - psa012: NO (-23.5pp)
#     - pcd014: NO (-22.8pp)
#     - pmd009: NO (-20.9pp)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   CLASE 2: 507 obs (32.5%)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#   SOBRERREPRESENTADAS: 78 categorías
#     - pmd003: NO (+32.5pp)
#     - pod002: NO (+31.0pp)
#     - pod007: NO (+28.4pp)
#     - pmd018: NO (+27.1pp)
#     - pod004: NO (+27.0pp)
#     - pad011: NO (+25.5pp)
#     - pod008: NO (+25.1pp)
#     - pmd001: NO (+25.0pp)
#     - pod009: NO (+24.8pp)
#     - pad001: NO (+24.3pp)
#   SUBREPRESENTADAS: 61 categorías
#     - pmd003: SI (-32.7pp)
#     - pod002: SI (-31.1pp)
#     - pod007: SI (-28.5pp)
#     - pmd018: SI (-27.3pp)
#     - pod004: SI (-26.9pp)
#     - pad011: SI (-25.7pp)
#     - pmd001: SI (-25.3pp)
#     - pod008: SI (-25.1pp)
#     - pod009: SI (-24.7pp)
#     - pad001: SI (-24.5pp)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   CLASE 3: 2 obs (0.1%)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#   SOBRERREPRESENTADAS: 126 categorías
#     - pso005: NS (+99.9pp)
#     - pmd015: NS (+99.9pp)
#     - pmd016: NS (+99.9pp)
#     - pmd019: NS (+99.9pp)
#     - pmd020: NS (+99.9pp)
#     - pmd021: NS (+99.9pp)
#     - pmd022: NS (+99.9pp)
#     - psz002: NS (+99.9pp)
#     - psz009: NS (+99.9pp)
#     - psz010: NS (+99.9pp)
#   SUBREPRESENTADAS: 58 categorías
#     - psu004: NO (-49.8pp)
#     - psu005: NO (-49.8pp)
#     - psu006: NO (-49.8pp)
#     - psu008: NO (-49.8pp)
#     - psu007: NO (-49.7pp)
#     - psu010: NO (-49.7pp)
#     - psu009: NO (-49.7pp)
#     - psu001: NO (-49.6pp)
#     - pcd007: NO (-49.6pp)
#     - pcd008: NO (-49.6pp)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   CLASE 4: 347 obs (22.3%)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#   SOBRERREPRESENTADAS: 43 categorías
#     - pad025: SI (+36.8pp)
#     - pad029: SI (+34.8pp)
#     - pad022: SI (+30.2pp)
#     - pad024: SI (+30.1pp)
#     - pad023: SI (+26.4pp)
#     - pal001: NO (+23.6pp)
#     - pad031: SI (+21.7pp)
#     - pad027: SI (+21.5pp)
#     - pod001: SI (+21.0pp)
#     - pni001: NO (+20.1pp)
#   SUBREPRESENTADAS: 39 categorías
#     - pad025: NO (-36.6pp)
#     - pad029: NO (-34.5pp)
#     - pad024: NO (-30.1pp)
#     - pad022: NO (-30.0pp)
#     - pad023: NO (-26.2pp)
#     - pad031: NO (-21.3pp)
#     - pad027: NO (-21.2pp)
#     - pod001: NO (-20.7pp)
#     - pod003: NO (-19.1pp)
#     - pad001: NO (-18.9pp)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   CLASE 5: 211 obs (13.5%)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#   SOBRERREPRESENTADAS: 99 categorías
#     - pmd015: SI (+46.0pp)
#     - pmd019: SI (+42.9pp)
#     - pmd012: SI (+42.6pp)
#     - pmd001: SI (+42.5pp)
#     - pmd008: SI (+41.7pp)
#     - pmd016: SI (+41.7pp)
#     - pmd020: SI (+40.3pp)
#     - pmd007: SI (+40.0pp)
#     - pmd002: SI (+38.5pp)
#     - pod007: SI (+37.5pp)
#   SUBREPRESENTADAS: 98 categorías
#     - pmd015: NO (-45.8pp)
#     - pmd035: NO (-45.2pp)
#     - pmd019: NO (-42.7pp)
#     - pmd012: NO (-42.4pp)
#     - pmd001: NO (-42.4pp)
#     - pmd008: NO (-41.6pp)
#     - pmd016: NO (-41.4pp)
#     - pmd020: NO (-40.1pp)
#     - pmd007: NO (-39.9pp)
#     - pmd002: NO (-38.4pp)
#   ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# ================================================================================
# 5. ANÁLISIS DE JERARQUÍA Y ESTABILIDAD ENTRE AGRUPACIONES
# ================================================================================
#
# Evolución jerárquica de las clases:
#
#   lca_k2 → lca_k3:
#   ------------------------------------------------------------
#   Clase 0 (total=801 obs): 60.5% → 0 (485 obs), 39.5% → 2 (316 obs)
#   Clase 1 (total=757 obs): 50.5% → 2 (382 obs), 49.5% → 1 (375 obs)
#   ------------------------------------------------------------
#
#   Resumen tabular:
#   Clase | Total obs | Distribución principal
#   --------------------------------------------------
#     0   |    801    | 60.5%→0(485), 39.5%→2(316)
#     1   |    757    | 50.5%→2(382), 49.5%→1(375)
#
#   lca_k3 → lca_k4:
#   ------------------------------------------------------------
#   Clase 0 (total=485 obs): 97.1% → 3 (471 obs), 1.9% → 0 (9 obs), 0.6% → 2 (3 obs)
#   Clase 1 (total=375 obs): 61.1% → 2 (229 obs), 31.5% → 0 (118 obs), 7.5% → 1 (28 obs)
#   Clase 2 (total=698 obs): 50.1% → 1 (350 obs), 44.0% → 0 (307 obs), 5.9% → 3 (41 obs)
#   ------------------------------------------------------------
#
#   Resumen tabular:
#   Clase | Total obs | Distribución principal
#   --------------------------------------------------
#     0   |    485    | 97.1%→3(471), 1.9%→0(9)
#     1   |    375    | 61.1%→2(229), 31.5%→0(118)
#     2   |    698    | 50.1%→1(350), 44.0%→0(307)
#
#   lca_k4 → lca_k5:
#   ------------------------------------------------------------
#   Clase 0 (total=434 obs): 94.2% → 2 (409 obs), 5.5% → 1 (24 obs)
#   Clase 1 (total=380 obs): 97.1% → 3 (369 obs), 2.9% → 1 (11 obs)
#   Clase 2 (total=232 obs): 98.7% → 1 (229 obs), 1.3% → 0 (3 obs)
#   Clase 3 (total=512 obs): 98.8% → 4 (506 obs), 0.8% → 3 (4 obs)
#   ------------------------------------------------------------
#
#   Resumen tabular:
#   Clase | Total obs | Distribución principal
#   --------------------------------------------------
#     0   |    434    | 94.2%→2(409), 5.5%→1(24)
#     1   |    380    | 97.1%→3(369), 2.9%→1(11)
#     2   |    232    | 98.7%→1(229), 1.3%→0(3)
#     3   |    512    | 98.8%→4(506), 0.8%→3(4)
#
#   lca_k5 → lca_k6:
#   ------------------------------------------------------------
#   Clase 0 (total=3 obs): 66.7% → 3 (2 obs), 33.3% → 2 (1 obs)
#   Clase 1 (total=264 obs): 77.3% → 5 (204 obs), 13.6% → 1 (36 obs), 8.0% → 0 (21 obs), 1.1% → 4 (3 obs)
#   Clase 2 (total=411 obs): 60.8% → 0 (250 obs), 33.3% → 1 (137 obs), 2.4% → 2 (10 obs), 1.7% → 4 (7 obs), 1.7% → 5 (7 obs)
#   Clase 3 (total=374 obs): 90.1% → 4 (337 obs), 8.0% → 1 (30 obs), 1.9% → 0 (7 obs)
#   Clase 4 (total=506 obs): 98.0% → 2 (496 obs), 1.8% → 1 (9 obs)
#   ------------------------------------------------------------
#
#   Resumen tabular:
#   Clase | Total obs | Distribución principal
#   --------------------------------------------------
#     0   |     3     | 66.7%→3(2), 33.3%→2(1)
#     1   |    264    | 77.3%→5(204), 13.6%→1(36)
#     2   |    411    | 60.8%→0(250), 33.3%→1(137)
#     3   |    374    | 90.1%→4(337), 8.0%→1(30)
#     4   |    506    | 98.0%→2(496), 1.8%→1(9)
#
# ====================================================================================================
# ANÁLISIS COMPLETADO EXITOSAMENTE
# ====================================================================================================
# Error al generar imagen Sankey con write_image:
# Image export using the "kaleido" engine requires the kaleido package,
# which can be installed using pip:
#     $ pip install -U kaleido
#
# Error también con pio.write_image:
# Image export using the "kaleido" engine requires the kaleido package,
# which can be installed using pip:
#     $ pip install -U kaleido
#
# Reporte PDF guardado como: reporte_1558.pdf

# %% [markdown]
# from utils import guardar_df
#
# # Guardar DataFrames principales
# guardar_df(output_df, 'LCA_1558_n', 'LCA_n')
# guardar_df(prob_df, 'LCA_prob_1558_n', 'LCA_prob_n')
# guardar_df(metric_df, 'LCA_metric_1558_n', 'LCA_metric_n')
#
# # Guardar matrices de interacción (son DataFrames cuadrados)
# guardar_df(cramersv_mat, 'cramersv_1558', 'cramers_matrix')
# guardar_df(pvalue_mat, 'pvalue_1558', 'pvalue_matrix')
# guardar_df(chi2_mat, 'chi2_1558', 'resultados_matrix')
#
# for i in range(2, 7):
#     nombre_k = f'lca_k{i}'
#     if nombre_k in resultados['cramers_completos']:
#         df_cramers = resultados['cramers_completos'][nombre_k]
#         guardar_df(df_cramers, f'Cramers_1558_{nombre_k}', 'Cramers_lca')
#     else:
#         print(f"Advertencia: {nombre_k} no encontrado en resultados['cramers_completos']")

# %%
import winsound
duration = 1000  # milisegundos
freq = 700       # Hz
winsound.Beep(freq, duration)
winsound.Beep(freq, duration)
winsound.Beep(freq, duration)
